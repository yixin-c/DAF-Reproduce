# %%
from scipy.io import loadmat
dat_abcd = loadmat('../abcd/new_abcd_cog.mat')

# %%
dat_abcd.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'count_network', 'demographx', 'nih_cogn', 'nih_cogn_colname', 'sub_withnet_id'])

# %%
dat_abcd['sub_withnet_id']
# Out:
# array([[array(['NDAR_INVE843DPZL'], dtype='<U16')],
#        [array(['NDAR_INVYX7ADDMR'], dtype='<U16')],
#        [array(['NDAR_INV1EGW0J5N'], dtype='<U16')],
#        ...,
#        [array(['NDAR_INVV2R0HB8H'], dtype='<U16')],
#        [array(['NDAR_INVL9ADL4ZD'], dtype='<U16')],
#        [array(['NDAR_INV2DPX8P1Y'], dtype='<U16')]], dtype=object)

# %%
from models import *

# %%
device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')
netG_A2B = Generator(input_nc=1, output_nc=1, init_depth=30, s_depth=10, n_residual_blocks=5).to(device)

# %%
inputs = torch.randn(5,1,68,68).to(device)

# %%
netG_A2B(inputs,torch.zeros(5).long().to(device))
# Out:
# torch.Size([5, 110, 17, 17])
# torch.Size([5, 60, 1, 1])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 netG_A2B(inputs,torch.zeros(5).long().to(device))
#
# File ~/anaconda3/envs/daf_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/daf_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
# ...
