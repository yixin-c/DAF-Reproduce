# %%
#!/usr/bin/env python
import sys
import torch
import random
import time
from models import *
from utils import *
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from torch.utils.data.sampler import SubsetRandomSampler
import os
import logging
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import itertools

# Setup logging
logging.basicConfig(filename='./logs/daf-sleep-abcd-modified.log', level=logging.INFO, 
                    format='%(asctime)s - %(levelname)s - %(message)s')

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

def set_seed(seed_value=973028):
    """Set seed for reproducibility."""
    random.seed(seed_value)  # Python random module
    np.random.seed(seed_value)  # Numpy module
    torch.manual_seed(seed_value)  # PyTorch
    os.environ['PYTHONHASHSEED'] = str(seed_value)  # Python hash seed
    
    # CUDA reproducibility
    torch.cuda.manual_seed(seed_value)
    torch.cuda.manual_seed_all(seed_value)  # if use multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed()

# Unsupervised DAF

## Load brain connectome data with sleep information
print("Loading ABCD data with sleep information...")
dat_abcd = loadmat('../abcd/new_abcd_cog_with_sleep_filtered.mat')
tensor_abcd = dat_abcd['count_network']
sleep_domain_numeric = dat_abcd['sleep_domain_numeric']

# whether to apply log transformation to the adjacency matrices
log = True

set_seed(1972014)

# Extract matrices for short sleep (0) and long sleep (1)
net_short_sleep = []
net_long_sleep = []

for i in range(tensor_abcd.shape[2]):
    ith = np.float32(tensor_abcd[:,:,i])
    if log:
        ith = np.log(ith+1)
    ith = ith.reshape(68*68)
    
    # Check sleep domain (0=short, 1=long)
    sleep_value = sleep_domain_numeric[i][0]
    if sleep_value == 0:  # Short sleep
        net_short_sleep.append(ith)
    elif sleep_value == 1:  # Long sleep
        net_long_sleep.append(ith)

n_short = len(net_short_sleep)
n_long = len(net_long_sleep)

print(f'Short sleep: {n_short} subjects')
print(f'Long sleep: {n_long} subjects')

# Combine the data
net_all = net_short_sleep + net_long_sleep

## Preprocess the data
if log:
    # If log transformation was applied, stack the tensors
    net_all = torch.stack([torch.Tensor(i) for i in net_all]).view(-1, 1, 68, 68)
else:
    # If no log transformation, scale data to range [0,1] (default in cycle gan)
    offset = np.max(net_all)/2
    net_all = torch.stack([torch.Tensor((i-offset)/offset) for i in net_all]).view(-1, 1, 68, 68)

# Domain labels: Short Sleep (0), Long Sleep (1)
labels = torch.cat((torch.tensor([0]).expand(n_short, 1), torch.tensor([1]).expand(n_long, 1)))

## Data loader
set_seed(1972034)
nepoch = 300
dataset = utils.TensorDataset(net_all, labels)

# Split train and validation
train_id, test_id = train_test_split(list(range(n_short + n_long)), train_size=0.9, random_state=42)
train_dataset = utils.Subset(dataset, train_id)
test_dataset = utils.Subset(dataset, test_id)
train_loader = utils.DataLoader(train_dataset, batch_size=128, shuffle=True)
test_loader = utils.DataLoader(test_dataset, batch_size=len(test_id), shuffle=False)

## DAF model configuration
# Networks
set_seed(1972014)
netG_A2B = Generator(input_nc=1, output_nc=1, init_depth=48, s_depth=10, n_residual_blocks=5).to(device)
netG_B2A = Generator(input_nc=1, output_nc=1, init_depth=48, s_depth=10, n_residual_blocks=5).to(device)
netD_A = Discriminator(input_nc=1, init_depth=48).to(device)
netD_B = Discriminator(input_nc=1, init_depth=48).to(device)

# Losses
criterion_GAN = torch.nn.MSELoss()
criterion_cycle = torch.nn.L1Loss()

# Optimizers & LR schedulers
optimizer_G = torch.optim.Adam(itertools.chain(netG_A2B.parameters(), netG_B2A.parameters()),
                               lr=0.0002, betas=(0.5, 0.999))
optimizer_D_A = torch.optim.Adam(netD_A.parameters(), lr=0.0002, betas=(0.5, 0.999))
optimizer_D_B = torch.optim.Adam(netD_B.parameters(), lr=0.0002, betas=(0.5, 0.999))

lr_scheduler_G = torch.optim.lr_scheduler.LambdaLR(optimizer_G, lr_lambda=LambdaLR(nepoch, 0, nepoch/2).step)
lr_scheduler_D_A = torch.optim.lr_scheduler.LambdaLR(optimizer_D_A, lr_lambda=LambdaLR(nepoch, 0, nepoch/2).step)
lr_scheduler_D_B = torch.optim.lr_scheduler.LambdaLR(optimizer_D_B, lr_lambda=LambdaLR(nepoch, 0, nepoch/2).step)

## Train
train_G_loss = []
test_G_loss = []
train_DA_loss = []
test_DA_loss = []
train_DB_loss = []
test_DB_loss = []

# New metrics for tracking discriminator accuracy
train_DA_acc = []
test_DA_acc = []
train_DB_acc = []
test_DB_acc = []

# Frequency to monitor test loss
evaluate_every = 1

# Function to calculate discriminator accuracy
def calculate_accuracy(pred, target, threshold=0.5):
    pred_binary = (pred > threshold).float()
    correct = (pred_binary == target).float().sum()
    accuracy = correct / target.size(0)
    return accuracy.item()

# Modified evaluate function to track discriminator accuracy
def evaluate_with_accuracy(netG_A2B, netG_B2A, netD_A, netD_B, loader, epoch, device, save=False, plot=False, root=None):
    criterion_GAN = torch.nn.MSELoss()
    criterion_cycle = torch.nn.L1Loss()
    netG_A2B.eval()
    netG_B2A.eval()
    netD_A.eval()
    netD_B.eval()

    G_losses = []
    DA_losses = []
    DB_losses = []
    DA_accs = []
    DB_accs = []
    gan = []
    cyc = []
    dep = []

    with torch.no_grad():
        for i, (A, s) in enumerate(loader):
            real_A = A.to(device)
            real_B = A.to(device)
            s = s.to(device)
            bs = real_A.shape[0]

            # Inputs & targets memory allocation
            Tensor = torch.FloatTensor
            target_real = Variable(Tensor(bs, 1).fill_(1.0), requires_grad=False).to(device)
            target_fake = Variable(Tensor(bs, 1).fill_(0.0), requires_grad=False).to(device)

            # Generator evaluation
            fake_B, _ = netG_A2B(real_A, s)
            pred_fake_B = netD_B(fake_B)
            loss_GAN_A2B = criterion_GAN(pred_fake_B, target_real)

            fake_A, _ = netG_B2A(real_B, s)
            pred_fake_A = netD_A(fake_A)
            loss_GAN_B2A = criterion_GAN(pred_fake_A, target_real)

            # Cycle loss
            recovered_A, _ = netG_B2A(fake_B, s)
            loss_cycle_ABA = criterion_cycle(recovered_A, real_A) * 10.0

            recovered_B, _ = netG_A2B(fake_A, s)
            loss_cycle_BAB = criterion_cycle(recovered_B, real_B) * 10.0

            # Dependence loss
            xt = fake_B.view(bs, -1)
            s_view = s.view(bs, 1)
            DLR = dependence(xt, s_view, sig=20, device=device)

            # Total generator loss
            loss_G = loss_GAN_A2B + loss_GAN_B2A + loss_cycle_ABA + loss_cycle_BAB + DLR

            # Discriminator A evaluation
            pred_real_A = netD_A(real_A)
            loss_D_real_A = criterion_GAN(pred_real_A, target_real)
            pred_fake_A = netD_A(fake_A.detach())
            loss_D_fake_A = criterion_GAN(pred_fake_A, target_fake)
            loss_D_A = (loss_D_real_A + loss_D_fake_A) * 0.5

            # Discriminator B evaluation
            pred_real_B = netD_B(real_B)
            loss_D_real_B = criterion_GAN(pred_real_B, target_real)
            pred_fake_B = netD_B(fake_B.detach())
            loss_D_fake_B = criterion_GAN(pred_fake_B, target_fake)
            loss_D_B = (loss_D_real_B + loss_D_fake_B) * 0.5

            # Calculate discriminator accuracies
            acc_real_A = calculate_accuracy(pred_real_A, target_real)
            acc_fake_A = calculate_accuracy(pred_fake_A, target_fake)
            acc_D_A = (acc_real_A + acc_fake_A) / 2.0

            acc_real_B = calculate_accuracy(pred_real_B, target_real)
            acc_fake_B = calculate_accuracy(pred_fake_B, target_fake)
            acc_D_B = (acc_real_B + acc_fake_B) / 2.0

            # Collect metrics
            G_losses.append(loss_G.data.item())
            DA_losses.append(loss_D_A.data.item())
            DB_losses.append(loss_D_B.data.item())
            DA_accs.append(acc_D_A)
            DB_accs.append(acc_D_B)
            gan.append(loss_GAN_A2B.data.item() + loss_GAN_B2A.data.item())
            cyc.append(loss_cycle_ABA.data.item() + loss_cycle_BAB.data.item())
            dep.append(DLR.data.item())

        # Calculate mean values
        G_loss_epoch = np.mean(G_losses)
        DA_loss_epoch = np.mean(DA_losses)
        DB_loss_epoch = np.mean(DB_losses)
        DA_acc_epoch = np.mean(DA_accs)
        DB_acc_epoch = np.mean(DB_accs)
        gan_epoch = np.mean(gan)
        cyc_epoch = np.mean(cyc)
        dep_epoch = np.mean(dep)

    if save:
        if not os.path.exists(root):
            # Create the directory
            os.makedirs(root)
            print(f"Directory '{root}' was created.")
            
        torch.save(netG_A2B.state_dict(), root+'G_A2B_e'+str(epoch)+'_G'+str(np.round(G_loss_epoch,3))\
                   +'_gan'+str(np.round(gan_epoch,3)) + '_cyc'+str(np.round(cyc_epoch)) + '_dep'+ str(np.round(dep_epoch*100,3)) + '.pth')
        torch.save(netG_B2A.state_dict(), root+'G_B2A_e'+str(epoch)+'_G'+str(np.round(G_loss_epoch,3))\
                   +'_gan'+str(np.round(gan_epoch,3)) + '_cyc'+str(np.round(cyc_epoch)) + '_dep'+ str(np.round(dep_epoch*100,3)) + '.pth')
        torch.save(netD_A.state_dict(), root+'D_A_e'+str(epoch)+'_'+str(np.round(DA_loss_epoch,3))+'.pth')
        torch.save(netD_B.state_dict(), root+'D_B_e'+str(epoch)+'_'+str(np.round(DB_loss_epoch,3))+'.pth')
        
    if plot:
        with torch.no_grad():
            for i, (x, s) in enumerate(loader):
                x, s = x.to(device), s.to(device)
                xt, _ = netG_A2B(x, s)
                recov, _ = netG_B2A(xt, s)

        x = x.detach().cpu()
        xt = xt.detach().cpu()
        recov = recov.detach().cpu()
        s = s.detach().cpu() 
        output_root = root+'figs/'
        if not os.path.exists(output_root):
            # Create the directory
            os.makedirs(output_root)
            print(f"Directory '{output_root}' was created.")
        img_grid_eval(epoch, x, xt, recov, s, file = output_root+'e'+str(epoch)+'.png', nrow=3, ncol=6)
    
    return G_loss_epoch, DA_loss_epoch, DB_loss_epoch, DA_acc_epoch, DB_acc_epoch, gan_epoch, cyc_epoch, dep_epoch

# Training loop
for epoch in range(0, nepoch):
    G_losses = []
    DA_losses = []
    DB_losses = []
    DA_accs = []
    DB_accs = []
    gan = []
    cyc = []
    dep = []

    tic = time.perf_counter()
    netG_A2B.train()
    netG_B2A.train()
    netD_A.train()
    netD_B.train()
    
    for i, (A, s) in enumerate(train_loader):
        # Set model input
        real_A = A.to(device)
        real_B = A.to(device)
        s = s.to(device)
        bs = real_A.shape[0]
        
        # Inputs & targets memory allocation
        Tensor = torch.FloatTensor
        target_real = Variable(Tensor(bs,1).fill_(1.0), requires_grad=False).to(device)
        target_fake = Variable(Tensor(bs,1).fill_(0.0), requires_grad=False).to(device)
        
        ###### Generators A2B and B2A ######
        optimizer_G.zero_grad()
        
        # GAN loss 
        fake_B, _ = netG_A2B(real_A, s)
        pred_fake_B = netD_B(fake_B)
        loss_GAN_A2B = criterion_GAN(pred_fake_B, target_real)
        
        fake_A, _ = netG_B2A(real_B, s)
        pred_fake_A = netD_A(fake_A)
        loss_GAN_B2A = criterion_GAN(pred_fake_A, target_real)
        
        # Cycle loss
        recovered_A, _ = netG_B2A(fake_B, s)
        loss_cycle_ABA = criterion_cycle(recovered_A, real_A) * 10.0

        recovered_B, _ = netG_A2B(fake_A, s)
        loss_cycle_BAB = criterion_cycle(recovered_B, real_B) * 10.0
        
        # Dependence loss - makes sure the transformed features are independent of domain 
        xt = fake_B.view(bs, -1)
        s_view = s.view(bs, 1)
        DLR = dependence(xt, s_view, sig=20, device=device) 

        # Total generator loss
        loss_G = loss_GAN_A2B + loss_GAN_B2A + loss_cycle_ABA + loss_cycle_BAB + DLR
        loss_G.backward()
        optimizer_G.step()
        
        ###### Discriminator A ######
        optimizer_D_A.zero_grad()

        # Real loss
        pred_real_A = netD_A(real_A)
        loss_D_real_A = criterion_GAN(pred_real_A, target_real)

        # Fake loss
        pred_fake_A = netD_A(fake_A.detach())
        loss_D_fake_A = criterion_GAN(pred_fake_A, target_fake)

        # Total loss
        loss_D_A = (loss_D_real_A + loss_D_fake_A) * 0.5
        loss_D_A.backward()
        optimizer_D_A.step()
        
        # Calculate Discriminator A accuracy
        acc_real_A = calculate_accuracy(pred_real_A, target_real)
        acc_fake_A = calculate_accuracy(pred_fake_A, target_fake)
        acc_D_A = (acc_real_A + acc_fake_A) / 2.0

        ###### Discriminator B ######
        optimizer_D_B.zero_grad()

        # Real loss
        pred_real_B = netD_B(real_B)
        loss_D_real_B = criterion_GAN(pred_real_B, target_real)
        
        # Fake loss
        pred_fake_B = netD_B(fake_B.detach())
        loss_D_fake_B = criterion_GAN(pred_fake_B, target_fake)

        # Total loss
        loss_D_B = (loss_D_real_B + loss_D_fake_B) * 0.5
        loss_D_B.backward()
        optimizer_D_B.step()
        
        # Calculate Discriminator B accuracy
        acc_real_B = calculate_accuracy(pred_real_B, target_real)
        acc_fake_B = calculate_accuracy(pred_fake_B, target_fake)
        acc_D_B = (acc_real_B + acc_fake_B) / 2.0
        
        # Collect metrics
        G_losses.append(loss_G.data.item())
        DA_losses.append(loss_D_A.data.item())
        DB_losses.append(loss_D_B.data.item())
        DA_accs.append(acc_D_A)
        DB_accs.append(acc_D_B)
        gan.append(loss_GAN_A2B.data.item() + loss_GAN_B2A.data.item())
        cyc.append(loss_cycle_ABA.data.item() + loss_cycle_BAB.data.item())
        dep.append(DLR.data.item())
        
    # Update learning rates
    lr_scheduler_G.step()
    lr_scheduler_D_A.step()
    lr_scheduler_D_B.step()
    
    # Calculate training metrics
    G_loss_epoch = torch.mean(torch.FloatTensor(G_losses))
    DA_loss_epoch = torch.mean(torch.FloatTensor(DA_losses))
    DB_loss_epoch = torch.mean(torch.FloatTensor(DB_losses))
    DA_acc_epoch = np.mean(DA_accs)
    DB_acc_epoch = np.mean(DB_accs)
    gan_epoch = torch.mean(torch.FloatTensor(gan))
    cyc_epoch = torch.mean(torch.FloatTensor(cyc))
    dep_epoch = torch.mean(torch.FloatTensor(dep))
    
    toc = time.perf_counter()
    print(f"Trained epoch {epoch+1} in {toc - tic:0.4f} seconds") 
    
    # Evaluate model
    if (epoch + 1) % evaluate_every == 0:
        G_loss_test, DA_loss_test, DB_loss_test, DA_acc_test, DB_acc_test, gan_test, cyc_test, dep_test = evaluate_with_accuracy(
            netG_A2B, netG_B2A, netD_A, netD_B, test_loader, epoch, device, 
            save=True, plot=True, root='./saved_model/sleep_daf/')
    
    # Log and print training results
    logging.info('-'*15+'train metrics'+'-'*15)    
    logging.info(f"Epoch: {epoch + 1}/{nepoch}, loss_D_A: {DA_loss_epoch:.3f}, loss_D_B: {DB_loss_epoch:.3f}, loss_G: {G_loss_epoch:.3f}")
    logging.info(f"Epoch: {epoch + 1}/{nepoch}, acc_D_A: {DA_acc_epoch:.3f}, acc_D_B: {DB_acc_epoch:.3f}")
    logging.info(f"Epoch: {epoch + 1}/{nepoch}, loss_gan: {gan_epoch:.3f}, loss_cyc: {cyc_epoch:.3f}, loss_dep: {dep_epoch:.3f}")
    logging.info('-'*15+' test metrics'+'-'*15)   
    logging.info(f"Epoch: {epoch + 1}/{nepoch}, loss_D_A: {DA_loss_test:.3f}, loss_D_B: {DB_loss_test:.3f}, loss_G: {G_loss_test:.3f}")
    logging.info(f"Epoch: {epoch + 1}/{nepoch}, acc_D_A: {DA_acc_test:.3f}, acc_D_B: {DB_acc_test:.3f}")
    logging.info(f"Epoch: {epoch + 1}/{nepoch}, loss_gan: {gan_test:.3f}, loss_cyc: {cyc_test:.3f}, loss_dep: {dep_test:.3f}")
    logging.info('*'*40)

    print('-'*15+'train metrics'+'-'*15)    
    print(f"Epoch: {epoch + 1}/{nepoch}, loss_D_A: {DA_loss_epoch:.3f}, loss_D_B: {DB_loss_epoch:.3f}, loss_G: {G_loss_epoch:.3f}")
    print(f"Epoch: {epoch + 1}/{nepoch}, acc_D_A: {DA_acc_epoch:.3f}, acc_D_B: {DB_acc_epoch:.3f}")
    print(f"Epoch: {epoch + 1}/{nepoch}, loss_gan: {gan_epoch:.3f}, loss_cyc: {cyc_epoch:.3f}, loss_dep: {dep_epoch:.3f}")
    print('-'*15+' test metrics'+'-'*15)   
    print(f"Epoch: {epoch + 1}/{nepoch}, loss_D_A: {DA_loss_test:.3f}, loss_D_B: {DB_loss_test:.3f}, loss_G: {G_loss_test:.3f}")
    print(f"Epoch: {epoch + 1}/{nepoch}, acc_D_A: {DA_acc_test:.3f}, acc_D_B: {DB_acc_test:.3f}")
    print(f"Epoch: {epoch + 1}/{nepoch}, loss_gan: {gan_test:.3f}, loss_cyc: {cyc_test:.3f}, loss_dep: {dep_test:.3f}")
    print('*'*40)
    
    # Store metrics for plotting
    train_G_loss.append(G_loss_epoch.item())
    test_G_loss.append(G_loss_test)
    train_DA_loss.append(DA_loss_epoch.item())
    test_DA_loss.append(DA_loss_test)
    train_DB_loss.append(DB_loss_epoch.item())
    test_DB_loss.append(DB_loss_test)
    train_DA_acc.append(DA_acc_epoch)
    test_DA_acc.append(DA_acc_test)
    train_DB_acc.append(DB_acc_epoch)
    test_DB_acc.append(DB_acc_test)

# Plot loss curves
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 1)
plt.plot(range(nepoch), train_G_loss, label='Train G')
plt.plot(range(nepoch), train_DA_loss, label='Train D_A')
plt.plot(range(nepoch), train_DB_loss, label='Train D_B')
plt.title('Training Losses')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.ylim(0, 3)

plt.subplot(2, 2, 2)
plt.plot(range(nepoch), test_G_loss, label='Test G')
plt.plot(range(nepoch), test_DA_loss, label='Test D_A')
plt.plot(range(nepoch), test_DB_loss, label='Test D_B')
plt.title('Testing Losses')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.ylim(0, 3)

# Plot accuracy curves
plt.subplot(2, 2, 3)
plt.plot(range(nepoch), train_DA_acc, label='Train D_A')
plt.plot(range(nepoch), train_DB_acc, label='Train D_B')
plt.title('Training Accuracies')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.ylim(0, 1)

plt.subplot(2, 2, 4)
plt.plot(range(nepoch), test_DA_acc, label='Test D_A')
plt.plot(range(nepoch), test_DB_acc, label='Test D_B')
plt.title('Testing Accuracies')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.ylim(0, 1)

plt.tight_layout()
plt.savefig('./saved_model/sleep_daf/training_plots.png')
plt.close()

print("Training complete. Results saved to ./saved_model/sleep_daf/")
# Out:
# Loading ABCD data with sleep information...
# Short sleep: 766 subjects
# Long sleep: 860 subjects
# Trained epoch 1 in 7.1324 seconds
# Directory './saved_model/sleep_daf/figs/' was created.
# ---------------train metrics---------------
# Epoch: 1/300, loss_D_A: 0.102, loss_D_B: 0.122, loss_G: 33.658
# Epoch: 1/300, acc_D_A: 0.916, acc_D_B: 0.874
# Epoch: 1/300, loss_gan: 1.373, loss_cyc: 32.206, loss_dep: 0.079
# --------------- test metrics---------------
# Epoch: 1/300, loss_D_A: 0.013, loss_D_B: 0.068, loss_G: 32.122
# Epoch: 1/300, acc_D_A: 1.000, acc_D_B: 0.988
# Epoch: 1/300, loss_gan: 2.150, loss_cyc: 29.889, loss_dep: 0.084
# ****************************************
# Trained epoch 2 in 6.6806 seconds
# ---------------train metrics---------------
# Epoch: 2/300, loss_D_A: 0.122, loss_D_B: 0.040, loss_G: 28.764
# Epoch: 2/300, acc_D_A: 0.946, acc_D_B: 0.997
# Epoch: 2/300, loss_gan: 1.849, loss_cyc: 26.848, loss_dep: 0.067
# --------------- test metrics---------------
# Epoch: 2/300, loss_D_A: 0.007, loss_D_B: 0.006, loss_G: 26.536
# Epoch: 2/300, acc_D_A: 1.000, acc_D_B: 1.000
# Epoch: 2/300, loss_gan: 1.693, loss_cyc: 24.773, loss_dep: 0.070
# ****************************************
# Trained epoch 3 in 6.7177 seconds
# ---------------train metrics---------------
# Epoch: 3/300, loss_D_A: 0.078, loss_D_B: 0.118, loss_G: 23.737
# Epoch: 3/300, acc_D_A: 0.951, acc_D_B: 0.918
# Epoch: 3/300, loss_gan: 1.660, loss_cyc: 22.017, loss_dep: 0.060
# --------------- test metrics---------------
# Epoch: 3/300, loss_D_A: 0.229, loss_D_B: 0.023, loss_G: 22.221
# Epoch: 3/300, acc_D_A: 0.537, acc_D_B: 1.000
# Epoch: 3/300, loss_gan: 2.478, loss_cyc: 19.690, loss_dep: 0.053
# ****************************************
# Trained epoch 4 in 6.7502 seconds
# ---------------train metrics---------------
# Epoch: 4/300, loss_D_A: 0.082, loss_D_B: 0.103, loss_G: 19.943
# Epoch: 4/300, acc_D_A: 0.916, acc_D_B: 0.858
# Epoch: 4/300, loss_gan: 1.585, loss_cyc: 18.304, loss_dep: 0.055
# --------------- test metrics---------------
# Epoch: 4/300, loss_D_A: 0.198, loss_D_B: 0.041, loss_G: 20.071
# Epoch: 4/300, acc_D_A: 0.739, acc_D_B: 1.000
# Epoch: 4/300, loss_gan: 2.409, loss_cyc: 17.615, loss_dep: 0.047
# ****************************************
# Trained epoch 5 in 6.7931 seconds
# ---------------train metrics---------------
# Epoch: 5/300, loss_D_A: 0.053, loss_D_B: 0.171, loss_G: 17.647
# Epoch: 5/300, acc_D_A: 0.938, acc_D_B: 0.833
# Epoch: 5/300, loss_gan: 1.754, loss_cyc: 15.843, loss_dep: 0.049
# --------------- test metrics---------------
# Epoch: 5/300, loss_D_A: 0.211, loss_D_B: 0.086, loss_G: 15.915
# Epoch: 5/300, acc_D_A: 0.500, acc_D_B: 0.991
# Epoch: 5/300, loss_gan: 1.088, loss_cyc: 14.776, loss_dep: 0.051
# ****************************************
# Trained epoch 6 in 6.8294 seconds
# ---------------train metrics---------------
# Epoch: 6/300, loss_D_A: 0.133, loss_D_B: 0.039, loss_G: 15.423
# Epoch: 6/300, acc_D_A: 0.869, acc_D_B: 0.999
# Epoch: 6/300, loss_gan: 1.438, loss_cyc: 13.937, loss_dep: 0.048
# --------------- test metrics---------------
# Epoch: 6/300, loss_D_A: 0.097, loss_D_B: 0.058, loss_G: 15.097
# Epoch: 6/300, acc_D_A: 0.939, acc_D_B: 1.000
# Epoch: 6/300, loss_gan: 1.776, loss_cyc: 13.261, loss_dep: 0.060
# ****************************************
# Trained epoch 7 in 6.8657 seconds
# ---------------train metrics---------------
# Epoch: 7/300, loss_D_A: 0.095, loss_D_B: 0.151, loss_G: 14.330
# Epoch: 7/300, acc_D_A: 0.869, acc_D_B: 0.862
# Epoch: 7/300, loss_gan: 1.400, loss_cyc: 12.872, loss_dep: 0.059
# --------------- test metrics---------------
# Epoch: 7/300, loss_D_A: 0.061, loss_D_B: 0.051, loss_G: 13.149
# Epoch: 7/300, acc_D_A: 1.000, acc_D_B: 1.000
# Epoch: 7/300, loss_gan: 1.126, loss_cyc: 11.968, loss_dep: 0.054
# ****************************************
# Trained epoch 8 in 6.8866 seconds
# ---------------train metrics---------------
# Epoch: 8/300, loss_D_A: 0.110, loss_D_B: 0.046, loss_G: 13.155
# Epoch: 8/300, acc_D_A: 0.859, acc_D_B: 0.996
# Epoch: 8/300, loss_gan: 1.462, loss_cyc: 11.634, loss_dep: 0.060
# --------------- test metrics---------------
# Epoch: 8/300, loss_D_A: 0.052, loss_D_B: 0.414, loss_G: 12.968
# Epoch: 8/300, acc_D_A: 0.997, acc_D_B: 0.500
# Epoch: 8/300, loss_gan: 0.817, loss_cyc: 12.073, loss_dep: 0.078
# ****************************************
# Trained epoch 9 in 6.9061 seconds
# ---------------train metrics---------------
# Epoch: 9/300, loss_D_A: 0.082, loss_D_B: 0.118, loss_G: 13.051
# Epoch: 9/300, acc_D_A: 0.933, acc_D_B: 0.874
# Epoch: 9/300, loss_gan: 1.405, loss_cyc: 11.562, loss_dep: 0.085
# --------------- test metrics---------------
# Epoch: 9/300, loss_D_A: 0.744, loss_D_B: 0.037, loss_G: 12.210
# Epoch: 9/300, acc_D_A: 0.500, acc_D_B: 1.000
# Epoch: 9/300, loss_gan: 0.577, loss_cyc: 11.538, loss_dep: 0.095
# ****************************************
# Trained epoch 10 in 6.9230 seconds
# ---------------train metrics---------------
# Epoch: 10/300, loss_D_A: 0.159, loss_D_B: 0.152, loss_G: 12.310
# Epoch: 10/300, acc_D_A: 0.897, acc_D_B: 0.838
# Epoch: 10/300, loss_gan: 1.244, loss_cyc: 10.949, loss_dep: 0.117
# --------------- test metrics---------------
# Epoch: 10/300, loss_D_A: 0.088, loss_D_B: 0.101, loss_G: 11.943
# Epoch: 10/300, acc_D_A: 0.985, acc_D_B: 0.994
# Epoch: 10/300, loss_gan: 1.042, loss_cyc: 10.771, loss_dep: 0.130
# ****************************************
# Trained epoch 11 in 6.9397 seconds
# ---------------train metrics---------------
# Epoch: 11/300, loss_D_A: 0.217, loss_D_B: 0.209, loss_G: 12.225
# Epoch: 11/300, acc_D_A: 0.797, acc_D_B: 0.831
# Epoch: 11/300, loss_gan: 1.224, loss_cyc: 10.882, loss_dep: 0.120
# --------------- test metrics---------------
# Epoch: 11/300, loss_D_A: 0.113, loss_D_B: 0.140, loss_G: 11.358
# Epoch: 11/300, acc_D_A: 1.000, acc_D_B: 0.979
# Epoch: 11/300, loss_gan: 0.846, loss_cyc: 10.404, loss_dep: 0.108
# ****************************************
# Trained epoch 12 in 6.9508 seconds
# ---------------train metrics---------------
# Epoch: 12/300, loss_D_A: 0.115, loss_D_B: 0.135, loss_G: 11.492
# Epoch: 12/300, acc_D_A: 0.985, acc_D_B: 0.912
# Epoch: 12/300, loss_gan: 0.923, loss_cyc: 10.476, loss_dep: 0.093
# --------------- test metrics---------------
# Epoch: 12/300, loss_D_A: 0.192, loss_D_B: 0.209, loss_G: 11.399
# Epoch: 12/300, acc_D_A: 0.500, acc_D_B: 0.500
# Epoch: 12/300, loss_gan: 0.295, loss_cyc: 11.028, loss_dep: 0.075
# ****************************************
# Trained epoch 13 in 6.9622 seconds
# ---------------train metrics---------------
# Epoch: 13/300, loss_D_A: 0.187, loss_D_B: 0.172, loss_G: 11.553
# Epoch: 13/300, acc_D_A: 0.757, acc_D_B: 0.705
# Epoch: 13/300, loss_gan: 1.033, loss_cyc: 10.460, loss_dep: 0.059
# --------------- test metrics---------------
# Epoch: 13/300, loss_D_A: 0.118, loss_D_B: 0.124, loss_G: 11.340
# Epoch: 13/300, acc_D_A: 1.000, acc_D_B: 0.960
# Epoch: 13/300, loss_gan: 0.930, loss_cyc: 10.354, loss_dep: 0.057
# ****************************************
# Trained epoch 14 in 6.9635 seconds
# ---------------train metrics---------------
# Epoch: 14/300, loss_D_A: 0.229, loss_D_B: 0.237, loss_G: 11.893
# Epoch: 14/300, acc_D_A: 0.798, acc_D_B: 0.773
# Epoch: 14/300, loss_gan: 1.222, loss_cyc: 10.605, loss_dep: 0.066
# --------------- test metrics---------------
# Epoch: 14/300, loss_D_A: 0.187, loss_D_B: 0.093, loss_G: 11.443
# Epoch: 14/300, acc_D_A: 0.500, acc_D_B: 0.975
# Epoch: 14/300, loss_gan: 0.920, loss_cyc: 10.461, loss_dep: 0.063
# ****************************************
# Trained epoch 15 in 6.9714 seconds
# ---------------train metrics---------------
# Epoch: 15/300, loss_D_A: 0.149, loss_D_B: 0.112, loss_G: 11.000
# Epoch: 15/300, acc_D_A: 0.921, acc_D_B: 0.992
# Epoch: 15/300, loss_gan: 0.860, loss_cyc: 10.100, loss_dep: 0.040
# --------------- test metrics---------------
# Epoch: 15/300, loss_D_A: 0.111, loss_D_B: 0.139, loss_G: 11.190
# Epoch: 15/300, acc_D_A: 0.994, acc_D_B: 0.979
# Epoch: 15/300, loss_gan: 0.798, loss_cyc: 10.365, loss_dep: 0.028
# ****************************************
# Trained epoch 16 in 6.9750 seconds
# ---------------train metrics---------------
# Epoch: 16/300, loss_D_A: 0.212, loss_D_B: 0.223, loss_G: 11.250
# Epoch: 16/300, acc_D_A: 0.779, acc_D_B: 0.703
# Epoch: 16/300, loss_gan: 1.044, loss_cyc: 10.172, loss_dep: 0.034
# --------------- test metrics---------------
# Epoch: 16/300, loss_D_A: 0.139, loss_D_B: 0.164, loss_G: 10.718
# Epoch: 16/300, acc_D_A: 1.000, acc_D_B: 0.850
# Epoch: 16/300, loss_gan: 0.606, loss_cyc: 10.084, loss_dep: 0.028
# ****************************************
# Trained epoch 17 in 6.9803 seconds
# ---------------train metrics---------------
# Epoch: 17/300, loss_D_A: 0.159, loss_D_B: 0.139, loss_G: 11.182
# Epoch: 17/300, acc_D_A: 0.760, acc_D_B: 0.954
# Epoch: 17/300, loss_gan: 0.894, loss_cyc: 10.248, loss_dep: 0.040
# --------------- test metrics---------------
# Epoch: 17/300, loss_D_A: 0.109, loss_D_B: 0.133, loss_G: 11.565
# Epoch: 17/300, acc_D_A: 0.920, acc_D_B: 0.963
# Epoch: 17/300, loss_gan: 1.154, loss_cyc: 10.368, loss_dep: 0.044
# ****************************************
# Trained epoch 18 in 6.9840 seconds
# ---------------train metrics---------------
# Epoch: 18/300, loss_D_A: 0.189, loss_D_B: 0.303, loss_G: 11.505
# Epoch: 18/300, acc_D_A: 0.711, acc_D_B: 0.660
# Epoch: 18/300, loss_gan: 1.091, loss_cyc: 10.371, loss_dep: 0.043
# --------------- test metrics---------------
# Epoch: 18/300, loss_D_A: 0.092, loss_D_B: 0.160, loss_G: 11.078
# Epoch: 18/300, acc_D_A: 0.972, acc_D_B: 0.994
# Epoch: 18/300, loss_gan: 0.994, loss_cyc: 10.051, loss_dep: 0.033
# ****************************************
# Trained epoch 19 in 6.9865 seconds
# ---------------train metrics---------------
# Epoch: 19/300, loss_D_A: 0.181, loss_D_B: 0.151, loss_G: 11.152
# Epoch: 19/300, acc_D_A: 0.829, acc_D_B: 0.967
# Epoch: 19/300, loss_gan: 1.026, loss_cyc: 10.100, loss_dep: 0.025
# --------------- test metrics---------------
# Epoch: 19/300, loss_D_A: 0.394, loss_D_B: 0.208, loss_G: 10.570
# Epoch: 19/300, acc_D_A: 0.500, acc_D_B: 0.549
# Epoch: 19/300, loss_gan: 0.209, loss_cyc: 10.340, loss_dep: 0.021
# ****************************************
# Trained epoch 20 in 6.9941 seconds
# ---------------train metrics---------------
# Epoch: 20/300, loss_D_A: 0.168, loss_D_B: 0.238, loss_G: 10.892
# Epoch: 20/300, acc_D_A: 0.849, acc_D_B: 0.654
# Epoch: 20/300, loss_gan: 0.783, loss_cyc: 10.081, loss_dep: 0.028
# --------------- test metrics---------------
# Epoch: 20/300, loss_D_A: 0.169, loss_D_B: 0.184, loss_G: 11.531
# Epoch: 20/300, acc_D_A: 0.877, acc_D_B: 0.540
# Epoch: 20/300, loss_gan: 1.037, loss_cyc: 10.458, loss_dep: 0.036
# ****************************************
# Trained epoch 21 in 6.9968 seconds
# ---------------train metrics---------------
# Epoch: 21/300, loss_D_A: 0.211, loss_D_B: 0.166, loss_G: 11.148
# Epoch: 21/300, acc_D_A: 0.703, acc_D_B: 0.837
# Epoch: 21/300, loss_gan: 0.897, loss_cyc: 10.214, loss_dep: 0.037
# --------------- test metrics---------------
# Epoch: 21/300, loss_D_A: 0.334, loss_D_B: 0.174, loss_G: 10.780
# Epoch: 21/300, acc_D_A: 0.500, acc_D_B: 0.798
# Epoch: 21/300, loss_gan: 0.469, loss_cyc: 10.284, loss_dep: 0.027
# ****************************************
# Trained epoch 22 in 6.9966 seconds
# ---------------train metrics---------------
# Epoch: 22/300, loss_D_A: 0.159, loss_D_B: 0.240, loss_G: 10.987
# Epoch: 22/300, acc_D_A: 0.892, acc_D_B: 0.668
# Epoch: 22/300, loss_gan: 0.834, loss_cyc: 10.129, loss_dep: 0.024
# --------------- test metrics---------------
# Epoch: 22/300, loss_D_A: 0.149, loss_D_B: 0.185, loss_G: 11.582
# Epoch: 22/300, acc_D_A: 0.684, acc_D_B: 0.736
# Epoch: 22/300, loss_gan: 1.140, loss_cyc: 10.417, loss_dep: 0.025
# ****************************************
# Trained epoch 23 in 7.0059 seconds
# ---------------train metrics---------------
# Epoch: 23/300, loss_D_A: 0.197, loss_D_B: 0.179, loss_G: 10.947
# Epoch: 23/300, acc_D_A: 0.688, acc_D_B: 0.770
# Epoch: 23/300, loss_gan: 0.904, loss_cyc: 10.012, loss_dep: 0.030
# --------------- test metrics---------------
# Epoch: 23/300, loss_D_A: 0.125, loss_D_B: 0.279, loss_G: 11.512
# Epoch: 23/300, acc_D_A: 0.908, acc_D_B: 0.500
# Epoch: 23/300, loss_gan: 0.650, loss_cyc: 10.838, loss_dep: 0.025
# ****************************************
# Trained epoch 24 in 7.0202 seconds
# ---------------train metrics---------------
# Epoch: 24/300, loss_D_A: 0.198, loss_D_B: 0.234, loss_G: 11.064
# Epoch: 24/300, acc_D_A: 0.665, acc_D_B: 0.666
# Epoch: 24/300, loss_gan: 0.923, loss_cyc: 10.114, loss_dep: 0.027
# --------------- test metrics---------------
# Epoch: 24/300, loss_D_A: 0.309, loss_D_B: 0.173, loss_G: 10.858
# Epoch: 24/300, acc_D_A: 0.497, acc_D_B: 0.914
# Epoch: 24/300, loss_gan: 0.423, loss_cyc: 10.403, loss_dep: 0.031
# ****************************************
# Trained epoch 25 in 7.0263 seconds
# ---------------train metrics---------------
# Epoch: 25/300, loss_D_A: 0.217, loss_D_B: 0.215, loss_G: 10.739
# Epoch: 25/300, acc_D_A: 0.622, acc_D_B: 0.677
# Epoch: 25/300, loss_gan: 0.731, loss_cyc: 9.980, loss_dep: 0.028
# --------------- test metrics---------------
# Epoch: 25/300, loss_D_A: 0.227, loss_D_B: 0.242, loss_G: 10.935
# Epoch: 25/300, acc_D_A: 0.500, acc_D_B: 0.503
# Epoch: 25/300, loss_gan: 0.992, loss_cyc: 9.918, loss_dep: 0.025
# ****************************************
# Trained epoch 26 in 7.0145 seconds
# ---------------train metrics---------------
# Epoch: 26/300, loss_D_A: 0.216, loss_D_B: 0.221, loss_G: 10.651
# Epoch: 26/300, acc_D_A: 0.584, acc_D_B: 0.621
# Epoch: 26/300, loss_gan: 0.790, loss_cyc: 9.833, loss_dep: 0.027
# --------------- test metrics---------------
# Epoch: 26/300, loss_D_A: 0.157, loss_D_B: 0.208, loss_G: 10.509
# Epoch: 26/300, acc_D_A: 0.972, acc_D_B: 0.801
# Epoch: 26/300, loss_gan: 0.657, loss_cyc: 9.826, loss_dep: 0.026
# ****************************************
# Trained epoch 27 in 7.0203 seconds
# ---------------train metrics---------------
# Epoch: 27/300, loss_D_A: 0.156, loss_D_B: 0.202, loss_G: 10.872
# Epoch: 27/300, acc_D_A: 0.868, acc_D_B: 0.694
# Epoch: 27/300, loss_gan: 0.790, loss_cyc: 10.056, loss_dep: 0.025
# --------------- test metrics---------------
# Epoch: 27/300, loss_D_A: 0.621, loss_D_B: 0.286, loss_G: 11.168
# Epoch: 27/300, acc_D_A: 0.500, acc_D_B: 0.503
# Epoch: 27/300, loss_gan: 1.008, loss_cyc: 10.140, loss_dep: 0.019
# ****************************************
# Trained epoch 28 in 7.0266 seconds
# ---------------train metrics---------------
# Epoch: 28/300, loss_D_A: 0.255, loss_D_B: 0.246, loss_G: 10.871
# Epoch: 28/300, acc_D_A: 0.816, acc_D_B: 0.686
# Epoch: 28/300, loss_gan: 0.978, loss_cyc: 9.869, loss_dep: 0.024
# --------------- test metrics---------------
# Epoch: 28/300, loss_D_A: 0.188, loss_D_B: 0.169, loss_G: 10.469
# Epoch: 28/300, acc_D_A: 0.804, acc_D_B: 0.896
# Epoch: 28/300, loss_gan: 0.708, loss_cyc: 9.745, loss_dep: 0.015
# ****************************************
# Trained epoch 29 in 7.0291 seconds
# ---------------train metrics---------------
# Epoch: 29/300, loss_D_A: 0.164, loss_D_B: 0.196, loss_G: 10.656
# Epoch: 29/300, acc_D_A: 0.806, acc_D_B: 0.726
# Epoch: 29/300, loss_gan: 0.811, loss_cyc: 9.823, loss_dep: 0.022
# --------------- test metrics---------------
# Epoch: 29/300, loss_D_A: 0.138, loss_D_B: 0.141, loss_G: 10.501
# Epoch: 29/300, acc_D_A: 0.975, acc_D_B: 0.994
# Epoch: 29/300, loss_gan: 0.792, loss_cyc: 9.690, loss_dep: 0.019
# ****************************************
# Trained epoch 30 in 7.0266 seconds
# ---------------train metrics---------------
# Epoch: 30/300, loss_D_A: 0.259, loss_D_B: 0.225, loss_G: 10.613
# Epoch: 30/300, acc_D_A: 0.708, acc_D_B: 0.758
# Epoch: 30/300, loss_gan: 0.864, loss_cyc: 9.727, loss_dep: 0.022
# --------------- test metrics---------------
# Epoch: 30/300, loss_D_A: 0.177, loss_D_B: 0.216, loss_G: 10.320
# Epoch: 30/300, acc_D_A: 0.914, acc_D_B: 0.555
# Epoch: 30/300, loss_gan: 0.516, loss_cyc: 9.783, loss_dep: 0.021
# ****************************************
# Trained epoch 31 in 7.0269 seconds
# ---------------train metrics---------------
# Epoch: 31/300, loss_D_A: 0.180, loss_D_B: 0.186, loss_G: 10.440
# Epoch: 31/300, acc_D_A: 0.805, acc_D_B: 0.772
# Epoch: 31/300, loss_gan: 0.706, loss_cyc: 9.714, loss_dep: 0.020
# --------------- test metrics---------------
# Epoch: 31/300, loss_D_A: 0.284, loss_D_B: 0.253, loss_G: 11.170
# Epoch: 31/300, acc_D_A: 0.500, acc_D_B: 0.521
# Epoch: 31/300, loss_gan: 1.140, loss_cyc: 10.010, loss_dep: 0.021
# ****************************************
# Trained epoch 32 in 7.0299 seconds
# ---------------train metrics---------------
# Epoch: 32/300, loss_D_A: 0.201, loss_D_B: 0.245, loss_G: 10.621
# Epoch: 32/300, acc_D_A: 0.650, acc_D_B: 0.671
# Epoch: 32/300, loss_gan: 0.865, loss_cyc: 9.738, loss_dep: 0.018
# --------------- test metrics---------------
# Epoch: 32/300, loss_D_A: 0.180, loss_D_B: 0.244, loss_G: 10.201
# Epoch: 32/300, acc_D_A: 0.874, acc_D_B: 0.598
# Epoch: 32/300, loss_gan: 0.580, loss_cyc: 9.605, loss_dep: 0.016
# ****************************************
# Trained epoch 33 in 7.0338 seconds
# ---------------train metrics---------------
# Epoch: 33/300, loss_D_A: 0.206, loss_D_B: 0.206, loss_G: 10.424
# Epoch: 33/300, acc_D_A: 0.741, acc_D_B: 0.702
# Epoch: 33/300, loss_gan: 0.724, loss_cyc: 9.682, loss_dep: 0.018
# --------------- test metrics---------------
# Epoch: 33/300, loss_D_A: 0.390, loss_D_B: 0.300, loss_G: 11.625
# Epoch: 33/300, acc_D_A: 0.518, acc_D_B: 0.500
# Epoch: 33/300, loss_gan: 1.533, loss_cyc: 10.077, loss_dep: 0.015
# ****************************************
# Trained epoch 34 in 7.0253 seconds
# ---------------train metrics---------------
# Epoch: 34/300, loss_D_A: 0.201, loss_D_B: 0.204, loss_G: 10.520
# Epoch: 34/300, acc_D_A: 0.731, acc_D_B: 0.733
# Epoch: 34/300, loss_gan: 0.820, loss_cyc: 9.684, loss_dep: 0.016
# --------------- test metrics---------------
# Epoch: 34/300, loss_D_A: 0.175, loss_D_B: 0.209, loss_G: 10.400
# Epoch: 34/300, acc_D_A: 0.736, acc_D_B: 0.650
# Epoch: 34/300, loss_gan: 0.738, loss_cyc: 9.642, loss_dep: 0.020
# ****************************************
# Trained epoch 35 in 7.0299 seconds
# ---------------train metrics---------------
# Epoch: 35/300, loss_D_A: 0.208, loss_D_B: 0.235, loss_G: 10.474
# Epoch: 35/300, acc_D_A: 0.640, acc_D_B: 0.577
# Epoch: 35/300, loss_gan: 0.750, loss_cyc: 9.703, loss_dep: 0.022
# --------------- test metrics---------------
# Epoch: 35/300, loss_D_A: 0.212, loss_D_B: 0.178, loss_G: 11.052
# Epoch: 35/300, acc_D_A: 0.561, acc_D_B: 0.844
# Epoch: 35/300, loss_gan: 1.306, loss_cyc: 9.724, loss_dep: 0.022
# ****************************************
# Trained epoch 36 in 7.0319 seconds
# ---------------train metrics---------------
# Epoch: 36/300, loss_D_A: 0.158, loss_D_B: 0.212, loss_G: 10.618
# Epoch: 36/300, acc_D_A: 0.749, acc_D_B: 0.646
# Epoch: 36/300, loss_gan: 0.894, loss_cyc: 9.705, loss_dep: 0.020
# --------------- test metrics---------------
# Epoch: 36/300, loss_D_A: 0.161, loss_D_B: 0.233, loss_G: 13.082
# Epoch: 36/300, acc_D_A: 0.936, acc_D_B: 0.512
# Epoch: 36/300, loss_gan: 1.603, loss_cyc: 11.460, loss_dep: 0.019
# ****************************************
# Trained epoch 37 in 7.0283 seconds
# ---------------train metrics---------------
# Epoch: 37/300, loss_D_A: 0.237, loss_D_B: 0.203, loss_G: 10.674
# Epoch: 37/300, acc_D_A: 0.711, acc_D_B: 0.758
# Epoch: 37/300, loss_gan: 0.913, loss_cyc: 9.743, loss_dep: 0.018
# --------------- test metrics---------------
# Epoch: 37/300, loss_D_A: 0.209, loss_D_B: 0.185, loss_G: 10.962
# Epoch: 37/300, acc_D_A: 0.604, acc_D_B: 0.623
# Epoch: 37/300, loss_gan: 0.868, loss_cyc: 10.082, loss_dep: 0.013
# ****************************************
# Trained epoch 38 in 7.0285 seconds
# ---------------train metrics---------------
# Epoch: 38/300, loss_D_A: 0.167, loss_D_B: 0.206, loss_G: 10.383
# Epoch: 38/300, acc_D_A: 0.753, acc_D_B: 0.634
# Epoch: 38/300, loss_gan: 0.831, loss_cyc: 9.539, loss_dep: 0.013
# --------------- test metrics---------------
# Epoch: 38/300, loss_D_A: 0.356, loss_D_B: 0.233, loss_G: 10.097
# Epoch: 38/300, acc_D_A: 0.500, acc_D_B: 0.500
# Epoch: 38/300, loss_gan: 0.163, loss_cyc: 9.922, loss_dep: 0.012
# ****************************************
# Trained epoch 39 in 7.0324 seconds
# ---------------train metrics---------------
# Epoch: 39/300, loss_D_A: 0.232, loss_D_B: 0.247, loss_G: 10.338
# Epoch: 39/300, acc_D_A: 0.692, acc_D_B: 0.523
# Epoch: 39/300, loss_gan: 0.806, loss_cyc: 9.516, loss_dep: 0.016
# --------------- test metrics---------------
# Epoch: 39/300, loss_D_A: 0.167, loss_D_B: 0.220, loss_G: 10.728
# Epoch: 39/300, acc_D_A: 0.887, acc_D_B: 0.525
# Epoch: 39/300, loss_gan: 1.143, loss_cyc: 9.570, loss_dep: 0.015
# ****************************************
# Trained epoch 40 in 7.0350 seconds
# ---------------train metrics---------------
# Epoch: 40/300, loss_D_A: 0.183, loss_D_B: 0.205, loss_G: 10.546
# Epoch: 40/300, acc_D_A: 0.803, acc_D_B: 0.678
# Epoch: 40/300, loss_gan: 0.888, loss_cyc: 9.641, loss_dep: 0.017
# --------------- test metrics---------------
# Epoch: 40/300, loss_D_A: 0.296, loss_D_B: 0.176, loss_G: 10.313
# Epoch: 40/300, acc_D_A: 0.500, acc_D_B: 0.592
# Epoch: 40/300, loss_gan: 0.755, loss_cyc: 9.546, loss_dep: 0.013
# ****************************************
# Trained epoch 41 in 7.0320 seconds
# ---------------train metrics---------------
# Epoch: 41/300, loss_D_A: 0.142, loss_D_B: 0.220, loss_G: 10.242
# Epoch: 41/300, acc_D_A: 0.882, acc_D_B: 0.626
# Epoch: 41/300, loss_gan: 0.840, loss_cyc: 9.392, loss_dep: 0.011
# --------------- test metrics---------------
# Epoch: 41/300, loss_D_A: 0.092, loss_D_B: 0.198, loss_G: 10.564
# Epoch: 41/300, acc_D_A: 0.936, acc_D_B: 0.558
# Epoch: 41/300, loss_gan: 0.747, loss_cyc: 9.802, loss_dep: 0.015
# ****************************************
# Trained epoch 42 in 7.0338 seconds
# ---------------train metrics---------------
# Epoch: 42/300, loss_D_A: 0.202, loss_D_B: 0.190, loss_G: 10.538
# Epoch: 42/300, acc_D_A: 0.717, acc_D_B: 0.680
# Epoch: 42/300, loss_gan: 0.964, loss_cyc: 9.558, loss_dep: 0.016
# --------------- test metrics---------------
# Epoch: 42/300, loss_D_A: 0.186, loss_D_B: 0.208, loss_G: 10.949
# Epoch: 42/300, acc_D_A: 0.558, acc_D_B: 0.540
# Epoch: 42/300, loss_gan: 1.084, loss_cyc: 9.851, loss_dep: 0.014
# ****************************************
# Trained epoch 43 in 7.0257 seconds
# ---------------train metrics---------------
# Epoch: 43/300, loss_D_A: 0.136, loss_D_B: 0.213, loss_G: 10.310
# Epoch: 43/300, acc_D_A: 0.869, acc_D_B: 0.658
# Epoch: 43/300, loss_gan: 0.856, loss_cyc: 9.440, loss_dep: 0.013
# --------------- test metrics---------------
# Epoch: 43/300, loss_D_A: 0.144, loss_D_B: 0.158, loss_G: 10.543
# Epoch: 43/300, acc_D_A: 0.831, acc_D_B: 0.610
# Epoch: 43/300, loss_gan: 1.074, loss_cyc: 9.458, loss_dep: 0.010
# ****************************************
# Trained epoch 44 in 7.0324 seconds
# ---------------train metrics---------------
# Epoch: 44/300, loss_D_A: 0.163, loss_D_B: 0.223, loss_G: 10.597
# Epoch: 44/300, acc_D_A: 0.767, acc_D_B: 0.657
# Epoch: 44/300, loss_gan: 1.091, loss_cyc: 9.494, loss_dep: 0.012
# --------------- test metrics---------------
# Epoch: 44/300, loss_D_A: 0.096, loss_D_B: 0.220, loss_G: 10.144
# Epoch: 44/300, acc_D_A: 0.926, acc_D_B: 0.727
# Epoch: 44/300, loss_gan: 0.749, loss_cyc: 9.384, loss_dep: 0.011
# ****************************************
# Trained epoch 45 in 7.0325 seconds
# ---------------train metrics---------------
# Epoch: 45/300, loss_D_A: 0.139, loss_D_B: 0.201, loss_G: 10.209
# Epoch: 45/300, acc_D_A: 0.811, acc_D_B: 0.773
# Epoch: 45/300, loss_gan: 0.884, loss_cyc: 9.311, loss_dep: 0.014
# --------------- test metrics---------------
# Epoch: 45/300, loss_D_A: 0.063, loss_D_B: 0.162, loss_G: 11.326
# Epoch: 45/300, acc_D_A: 0.933, acc_D_B: 0.908
# Epoch: 45/300, loss_gan: 1.180, loss_cyc: 10.129, loss_dep: 0.018
# ****************************************
# Trained epoch 46 in 7.0344 seconds
# ---------------train metrics---------------
# Epoch: 46/300, loss_D_A: 0.160, loss_D_B: 0.232, loss_G: 10.531
# Epoch: 46/300, acc_D_A: 0.806, acc_D_B: 0.694
# Epoch: 46/300, loss_gan: 1.064, loss_cyc: 9.453, loss_dep: 0.015
# --------------- test metrics---------------
# Epoch: 46/300, loss_D_A: 0.093, loss_D_B: 0.169, loss_G: 10.367
# Epoch: 46/300, acc_D_A: 0.933, acc_D_B: 0.822
# Epoch: 46/300, loss_gan: 0.909, loss_cyc: 9.446, loss_dep: 0.013
# ****************************************
# Trained epoch 47 in 7.0333 seconds
# ---------------train metrics---------------
# Epoch: 47/300, loss_D_A: 0.104, loss_D_B: 0.188, loss_G: 10.315
# Epoch: 47/300, acc_D_A: 0.907, acc_D_B: 0.712
# Epoch: 47/300, loss_gan: 0.954, loss_cyc: 9.346, loss_dep: 0.014
# --------------- test metrics---------------
# Epoch: 47/300, loss_D_A: 0.083, loss_D_B: 0.182, loss_G: 10.361
# Epoch: 47/300, acc_D_A: 0.933, acc_D_B: 0.699
# Epoch: 47/300, loss_gan: 0.788, loss_cyc: 9.560, loss_dep: 0.012
# ****************************************
# Trained epoch 48 in 7.0361 seconds
# ---------------train metrics---------------
# Epoch: 48/300, loss_D_A: 0.120, loss_D_B: 0.195, loss_G: 10.576
# Epoch: 48/300, acc_D_A: 0.846, acc_D_B: 0.724
# Epoch: 48/300, loss_gan: 1.078, loss_cyc: 9.486, loss_dep: 0.012
# --------------- test metrics---------------
# Epoch: 48/300, loss_D_A: 0.171, loss_D_B: 0.264, loss_G: 10.866
# Epoch: 48/300, acc_D_A: 0.807, acc_D_B: 0.500
# Epoch: 48/300, loss_gan: 1.353, loss_cyc: 9.503, loss_dep: 0.010
# ****************************************
# Trained epoch 49 in 7.0332 seconds
# ---------------train metrics---------------
# Epoch: 49/300, loss_D_A: 0.111, loss_D_B: 0.219, loss_G: 10.293
# Epoch: 49/300, acc_D_A: 0.864, acc_D_B: 0.633
# Epoch: 49/300, loss_gan: 0.993, loss_cyc: 9.289, loss_dep: 0.011
# --------------- test metrics---------------
# Epoch: 49/300, loss_D_A: 0.104, loss_D_B: 0.161, loss_G: 10.725
# Epoch: 49/300, acc_D_A: 0.905, acc_D_B: 0.715
# Epoch: 49/300, loss_gan: 1.173, loss_cyc: 9.541, loss_dep: 0.012
# ****************************************
# Trained epoch 50 in 7.0348 seconds
# ---------------train metrics---------------
# Epoch: 50/300, loss_D_A: 0.161, loss_D_B: 0.215, loss_G: 10.460
# Epoch: 50/300, acc_D_A: 0.806, acc_D_B: 0.711
# Epoch: 50/300, loss_gan: 1.052, loss_cyc: 9.395, loss_dep: 0.013
# --------------- test metrics---------------
# Epoch: 50/300, loss_D_A: 0.154, loss_D_B: 0.188, loss_G: 10.312
# Epoch: 50/300, acc_D_A: 0.920, acc_D_B: 0.865
# Epoch: 50/300, loss_gan: 0.697, loss_cyc: 9.603, loss_dep: 0.012
# ****************************************
# Trained epoch 51 in 7.0344 seconds
# ---------------train metrics---------------
# Epoch: 51/300, loss_D_A: 0.230, loss_D_B: 0.215, loss_G: 10.069
# Epoch: 51/300, acc_D_A: 0.569, acc_D_B: 0.595
# Epoch: 51/300, loss_gan: 0.778, loss_cyc: 9.281, loss_dep: 0.010
# --------------- test metrics---------------
# Epoch: 51/300, loss_D_A: 0.168, loss_D_B: 0.244, loss_G: 9.925
# Epoch: 51/300, acc_D_A: 0.693, acc_D_B: 0.500
# Epoch: 51/300, loss_gan: 0.694, loss_cyc: 9.222, loss_dep: 0.009
# ****************************************
# Trained epoch 52 in 7.0357 seconds
# ---------------train metrics---------------
# Epoch: 52/300, loss_D_A: 0.211, loss_D_B: 0.205, loss_G: 9.866
# Epoch: 52/300, acc_D_A: 0.653, acc_D_B: 0.662
# Epoch: 52/300, loss_gan: 0.671, loss_cyc: 9.186, loss_dep: 0.009
# --------------- test metrics---------------
# Epoch: 52/300, loss_D_A: 0.156, loss_D_B: 0.230, loss_G: 10.088
# Epoch: 52/300, acc_D_A: 0.758, acc_D_B: 0.500
# Epoch: 52/300, loss_gan: 0.693, loss_cyc: 9.386, loss_dep: 0.008
# ****************************************
# Trained epoch 53 in 7.0318 seconds
# ---------------train metrics---------------
# Epoch: 53/300, loss_D_A: 0.240, loss_D_B: 0.215, loss_G: 9.947
# Epoch: 53/300, acc_D_A: 0.601, acc_D_B: 0.587
# Epoch: 53/300, loss_gan: 0.781, loss_cyc: 9.157, loss_dep: 0.009
# --------------- test metrics---------------
# Epoch: 53/300, loss_D_A: 0.193, loss_D_B: 0.190, loss_G: 9.955
# Epoch: 53/300, acc_D_A: 0.893, acc_D_B: 0.905
# Epoch: 53/300, loss_gan: 0.609, loss_cyc: 9.337, loss_dep: 0.009
# ****************************************
# Trained epoch 54 in 7.0192 seconds
# ---------------train metrics---------------
# Epoch: 54/300, loss_D_A: 0.223, loss_D_B: 0.225, loss_G: 9.879
# Epoch: 54/300, acc_D_A: 0.656, acc_D_B: 0.717
# Epoch: 54/300, loss_gan: 0.706, loss_cyc: 9.162, loss_dep: 0.010
# --------------- test metrics---------------
# Epoch: 54/300, loss_D_A: 0.259, loss_D_B: 0.178, loss_G: 10.094
# Epoch: 54/300, acc_D_A: 0.497, acc_D_B: 0.828
# Epoch: 54/300, loss_gan: 0.540, loss_cyc: 9.544, loss_dep: 0.010
# ****************************************
# Trained epoch 55 in 7.0308 seconds
# ---------------train metrics---------------
# Epoch: 55/300, loss_D_A: 0.250, loss_D_B: 0.218, loss_G: 9.978
# Epoch: 55/300, acc_D_A: 0.670, acc_D_B: 0.814
# Epoch: 55/300, loss_gan: 0.768, loss_cyc: 9.202, loss_dep: 0.009
# --------------- test metrics---------------
# Epoch: 55/300, loss_D_A: 0.462, loss_D_B: 0.485, loss_G: 10.574
# Epoch: 55/300, acc_D_A: 0.500, acc_D_B: 0.500
# Epoch: 55/300, loss_gan: 1.409, loss_cyc: 9.158, loss_dep: 0.008
# ****************************************
# Trained epoch 56 in 7.0311 seconds
# ---------------train metrics---------------
# Epoch: 56/300, loss_D_A: 0.228, loss_D_B: 0.219, loss_G: 9.716
# Epoch: 56/300, acc_D_A: 0.655, acc_D_B: 0.696
# Epoch: 56/300, loss_gan: 0.729, loss_cyc: 8.978, loss_dep: 0.009
# --------------- test metrics---------------
# Epoch: 56/300, loss_D_A: 0.178, loss_D_B: 0.199, loss_G: 9.621
# Epoch: 56/300, acc_D_A: 0.807, acc_D_B: 0.653
# Epoch: 56/300, loss_gan: 0.624, loss_cyc: 8.988, loss_dep: 0.009
# ****************************************
# Trained epoch 57 in 7.0319 seconds
# ---------------train metrics---------------
# Epoch: 57/300, loss_D_A: 0.224, loss_D_B: 0.197, loss_G: 9.825
# Epoch: 57/300, acc_D_A: 0.675, acc_D_B: 0.660
# Epoch: 57/300, loss_gan: 0.774, loss_cyc: 9.041, loss_dep: 0.010
# --------------- test metrics---------------
# Epoch: 57/300, loss_D_A: 0.177, loss_D_B: 0.178, loss_G: 9.653
# Epoch: 57/300, acc_D_A: 0.893, acc_D_B: 0.890
# Epoch: 57/300, loss_gan: 0.634, loss_cyc: 9.012, loss_dep: 0.008
# ****************************************
# Trained epoch 58 in 7.0322 seconds
# ---------------train metrics---------------
# Epoch: 58/300, loss_D_A: 0.210, loss_D_B: 0.230, loss_G: 9.757
# Epoch: 58/300, acc_D_A: 0.646, acc_D_B: 0.604
# Epoch: 58/300, loss_gan: 0.716, loss_cyc: 9.033, loss_dep: 0.008
# --------------- test metrics---------------
# Epoch: 58/300, loss_D_A: 0.192, loss_D_B: 0.153, loss_G: 9.895
# Epoch: 58/300, acc_D_A: 0.635, acc_D_B: 0.727
# Epoch: 58/300, loss_gan: 0.809, loss_cyc: 9.077, loss_dep: 0.009
# ****************************************
# Trained epoch 59 in 7.0308 seconds
# ---------------train metrics---------------
# Epoch: 59/300, loss_D_A: 0.228, loss_D_B: 0.223, loss_G: 9.868
# Epoch: 59/300, acc_D_A: 0.680, acc_D_B: 0.736
# Epoch: 59/300, loss_gan: 0.796, loss_cyc: 9.062, loss_dep: 0.010
# --------------- test metrics---------------
# Epoch: 59/300, loss_D_A: 0.203, loss_D_B: 0.167, loss_G: 9.883
# Epoch: 59/300, acc_D_A: 0.819, acc_D_B: 0.936
# Epoch: 59/300, loss_gan: 0.656, loss_cyc: 9.218, loss_dep: 0.009
# ****************************************
# Trained epoch 60 in 7.0296 seconds
# ---------------train metrics---------------
# Epoch: 60/300, loss_D_A: 0.226, loss_D_B: 0.192, loss_G: 9.754
# Epoch: 60/300, acc_D_A: 0.619, acc_D_B: 0.704
# Epoch: 60/300, loss_gan: 0.714, loss_cyc: 9.031, loss_dep: 0.010
# --------------- test metrics---------------
# Epoch: 60/300, loss_D_A: 0.268, loss_D_B: 0.189, loss_G: 10.091
# Epoch: 60/300, acc_D_A: 0.500, acc_D_B: 0.571
# Epoch: 60/300, loss_gan: 0.838, loss_cyc: 9.244, loss_dep: 0.009
# ****************************************
# Trained epoch 61 in 7.0292 seconds
# ---------------train metrics---------------
# Epoch: 61/300, loss_D_A: 0.211, loss_D_B: 0.220, loss_G: 9.609
# Epoch: 61/300, acc_D_A: 0.676, acc_D_B: 0.614
# Epoch: 61/300, loss_gan: 0.698, loss_cyc: 8.902, loss_dep: 0.008
# --------------- test metrics---------------
# Epoch: 61/300, loss_D_A: 0.200, loss_D_B: 0.168, loss_G: 9.730
# Epoch: 61/300, acc_D_A: 0.739, acc_D_B: 0.942
# Epoch: 61/300, loss_gan: 0.627, loss_cyc: 9.096, loss_dep: 0.007
# ****************************************
# Trained epoch 62 in 7.0322 seconds
# ---------------train metrics---------------
# Epoch: 62/300, loss_D_A: 0.220, loss_D_B: 0.204, loss_G: 9.795
# Epoch: 62/300, acc_D_A: 0.700, acc_D_B: 0.675
# Epoch: 62/300, loss_gan: 0.797, loss_cyc: 8.990, loss_dep: 0.009
# --------------- test metrics---------------
# Epoch: 62/300, loss_D_A: 0.233, loss_D_B: 0.168, loss_G: 9.584
# Epoch: 62/300, acc_D_A: 0.503, acc_D_B: 0.939
# Epoch: 62/300, loss_gan: 0.599, loss_cyc: 8.976, loss_dep: 0.009
# ****************************************
# Trained epoch 63 in 7.0276 seconds
# ---------------train metrics---------------
# Epoch: 63/300, loss_D_A: 0.235, loss_D_B: 0.207, loss_G: 9.680
# Epoch: 63/300, acc_D_A: 0.639, acc_D_B: 0.715
# Epoch: 63/300, loss_gan: 0.736, loss_cyc: 8.935, loss_dep: 0.009
# --------------- test metrics---------------
# Epoch: 63/300, loss_D_A: 0.242, loss_D_B: 0.167, loss_G: 9.832
# Epoch: 63/300, acc_D_A: 0.491, acc_D_B: 0.712
# Epoch: 63/300, loss_gan: 0.716, loss_cyc: 9.107, loss_dep: 0.009
# ****************************************
# Trained epoch 64 in 7.0360 seconds
# ---------------train metrics---------------
# Epoch: 64/300, loss_D_A: 0.224, loss_D_B: 0.200, loss_G: 9.772
# Epoch: 64/300, acc_D_A: 0.547, acc_D_B: 0.647
# Epoch: 64/300, loss_gan: 0.794, loss_cyc: 8.969, loss_dep: 0.009
# --------------- test metrics---------------
# Epoch: 64/300, loss_D_A: 0.235, loss_D_B: 0.171, loss_G: 9.929
# Epoch: 64/300, acc_D_A: 0.497, acc_D_B: 0.702
# Epoch: 64/300, loss_gan: 0.733, loss_cyc: 9.188, loss_dep: 0.008
# ****************************************
# Trained epoch 65 in 7.0326 seconds
# ---------------train metrics---------------
# Epoch: 65/300, loss_D_A: 0.207, loss_D_B: 0.212, loss_G: 9.712
# Epoch: 65/300, acc_D_A: 0.572, acc_D_B: 0.608
# Epoch: 65/300, loss_gan: 0.776, loss_cyc: 8.929, loss_dep: 0.007
# --------------- test metrics---------------
# Epoch: 65/300, loss_D_A: 0.186, loss_D_B: 0.156, loss_G: 9.673
# Epoch: 65/300, acc_D_A: 0.804, acc_D_B: 0.954
# Epoch: 65/300, loss_gan: 0.673, loss_cyc: 8.994, loss_dep: 0.006
# ****************************************
# Trained epoch 66 in 7.0354 seconds
# ---------------train metrics---------------
# Epoch: 66/300, loss_D_A: 0.223, loss_D_B: 0.245, loss_G: 9.790
# Epoch: 66/300, acc_D_A: 0.665, acc_D_B: 0.720
# Epoch: 66/300, loss_gan: 0.871, loss_cyc: 8.911, loss_dep: 0.008
# --------------- test metrics---------------
# Epoch: 66/300, loss_D_A: 0.219, loss_D_B: 0.210, loss_G: 9.586
# Epoch: 66/300, acc_D_A: 0.724, acc_D_B: 0.656
# Epoch: 66/300, loss_gan: 0.557, loss_cyc: 9.022, loss_dep: 0.007
# ****************************************
# Trained epoch 67 in 7.0315 seconds
# ---------------train metrics---------------
# Epoch: 67/300, loss_D_A: 0.224, loss_D_B: 0.189, loss_G: 9.634
# Epoch: 67/300, acc_D_A: 0.579, acc_D_B: 0.760
# Epoch: 67/300, loss_gan: 0.735, loss_cyc: 8.892, loss_dep: 0.008
# --------------- test metrics---------------
# Epoch: 67/300, loss_D_A: 0.170, loss_D_B: 0.309, loss_G: 9.902
# Epoch: 67/300, acc_D_A: 0.610, acc_D_B: 0.500
# Epoch: 67/300, loss_gan: 0.746, loss_cyc: 9.150, loss_dep: 0.006
# ****************************************
# Trained epoch 68 in 7.0068 seconds
# ---------------train metrics---------------
# Epoch: 68/300, loss_D_A: 0.214, loss_D_B: 0.238, loss_G: 9.721
# Epoch: 68/300, acc_D_A: 0.658, acc_D_B: 0.635
# Epoch: 68/300, loss_gan: 0.814, loss_cyc: 8.900, loss_dep: 0.007
# --------------- test metrics---------------
# Epoch: 68/300, loss_D_A: 0.153, loss_D_B: 0.177, loss_G: 9.822
# Epoch: 68/300, acc_D_A: 0.859, acc_D_B: 0.899
# Epoch: 68/300, loss_gan: 0.742, loss_cyc: 9.074, loss_dep: 0.006
# ****************************************
# Trained epoch 69 in 7.0126 seconds
# ---------------train metrics---------------
# Epoch: 69/300, loss_D_A: 0.247, loss_D_B: 0.195, loss_G: 9.553
# Epoch: 69/300, acc_D_A: 0.626, acc_D_B: 0.727
# Epoch: 69/300, loss_gan: 0.731, loss_cyc: 8.814, loss_dep: 0.007
# --------------- test metrics---------------
# Epoch: 69/300, loss_D_A: 0.168, loss_D_B: 0.167, loss_G: 9.544
# Epoch: 69/300, acc_D_A: 0.945, acc_D_B: 0.957
# Epoch: 69/300, loss_gan: 0.712, loss_cyc: 8.826, loss_dep: 0.006
# ****************************************
# Trained epoch 70 in 7.0129 seconds
# ---------------train metrics---------------
# Epoch: 70/300, loss_D_A: 0.201, loss_D_B: 0.211, loss_G: 9.590
# Epoch: 70/300, acc_D_A: 0.661, acc_D_B: 0.713
# Epoch: 70/300, loss_gan: 0.762, loss_cyc: 8.822, loss_dep: 0.007
# --------------- test metrics---------------
# Epoch: 70/300, loss_D_A: 0.190, loss_D_B: 0.168, loss_G: 9.771
# Epoch: 70/300, acc_D_A: 0.752, acc_D_B: 0.948
# Epoch: 70/300, loss_gan: 0.759, loss_cyc: 9.006, loss_dep: 0.007
# ****************************************
# Trained epoch 71 in 7.0172 seconds
# ---------------train metrics---------------
# Epoch: 71/300, loss_D_A: 0.245, loss_D_B: 0.204, loss_G: 9.455
# Epoch: 71/300, acc_D_A: 0.597, acc_D_B: 0.713
# Epoch: 71/300, loss_gan: 0.680, loss_cyc: 8.768, loss_dep: 0.008
# --------------- test metrics---------------
# Epoch: 71/300, loss_D_A: 0.269, loss_D_B: 0.203, loss_G: 9.385
# Epoch: 71/300, acc_D_A: 0.288, acc_D_B: 0.724
# Epoch: 71/300, loss_gan: 0.580, loss_cyc: 8.800, loss_dep: 0.006
# ****************************************
# Trained epoch 72 in 7.0194 seconds
# ---------------train metrics---------------
# Epoch: 72/300, loss_D_A: 0.206, loss_D_B: 0.216, loss_G: 9.523
# Epoch: 72/300, acc_D_A: 0.648, acc_D_B: 0.651
# Epoch: 72/300, loss_gan: 0.754, loss_cyc: 8.763, loss_dep: 0.006
# --------------- test metrics---------------
# Epoch: 72/300, loss_D_A: 0.246, loss_D_B: 0.161, loss_G: 9.853
# Epoch: 72/300, acc_D_A: 0.494, acc_D_B: 0.853
# Epoch: 72/300, loss_gan: 0.621, loss_cyc: 9.226, loss_dep: 0.006
# ****************************************
# Trained epoch 73 in 7.0220 seconds
# ---------------train metrics---------------
# Epoch: 73/300, loss_D_A: 0.235, loss_D_B: 0.220, loss_G: 9.525
# Epoch: 73/300, acc_D_A: 0.610, acc_D_B: 0.614
# Epoch: 73/300, loss_gan: 0.683, loss_cyc: 8.835, loss_dep: 0.007
# --------------- test metrics---------------
# Epoch: 73/300, loss_D_A: 0.236, loss_D_B: 0.181, loss_G: 9.713
# Epoch: 73/300, acc_D_A: 0.515, acc_D_B: 0.598
# Epoch: 73/300, loss_gan: 0.886, loss_cyc: 8.821, loss_dep: 0.006
# ****************************************
# Trained epoch 74 in 7.0138 seconds
# ---------------train metrics---------------
# Epoch: 74/300, loss_D_A: 0.253, loss_D_B: 0.199, loss_G: 9.574
# Epoch: 74/300, acc_D_A: 0.608, acc_D_B: 0.652
# Epoch: 74/300, loss_gan: 0.824, loss_cyc: 8.743, loss_dep: 0.007
# --------------- test metrics---------------
# Epoch: 74/300, loss_D_A: 0.225, loss_D_B: 0.199, loss_G: 9.268
# Epoch: 74/300, acc_D_A: 0.718, acc_D_B: 0.813
# Epoch: 74/300, loss_gan: 0.541, loss_cyc: 8.722, loss_dep: 0.005
# ****************************************
# Trained epoch 75 in 7.0192 seconds
# ---------------train metrics---------------
# Epoch: 75/300, loss_D_A: 0.224, loss_D_B: 0.240, loss_G: 9.411
# Epoch: 75/300, acc_D_A: 0.651, acc_D_B: 0.599
# Epoch: 75/300, loss_gan: 0.718, loss_cyc: 8.687, loss_dep: 0.006
# --------------- test metrics---------------
# Epoch: 75/300, loss_D_A: 0.185, loss_D_B: 0.334, loss_G: 9.588
# Epoch: 75/300, acc_D_A: 0.610, acc_D_B: 0.500
# Epoch: 75/300, loss_gan: 0.592, loss_cyc: 8.990, loss_dep: 0.006
# ****************************************
# Trained epoch 76 in 7.0181 seconds
# ---------------train metrics---------------
# Epoch: 76/300, loss_D_A: 0.214, loss_D_B: 0.190, loss_G: 9.380
# Epoch: 76/300, acc_D_A: 0.567, acc_D_B: 0.773
# Epoch: 76/300, loss_gan: 0.697, loss_cyc: 8.676, loss_dep: 0.007
# --------------- test metrics---------------
# Epoch: 76/300, loss_D_A: 0.197, loss_D_B: 0.156, loss_G: 9.677
# Epoch: 76/300, acc_D_A: 0.678, acc_D_B: 0.917
# Epoch: 76/300, loss_gan: 0.811, loss_cyc: 8.860, loss_dep: 0.006
# ****************************************
# Trained epoch 77 in 7.0205 seconds
# ---------------train metrics---------------
# Epoch: 77/300, loss_D_A: 0.248, loss_D_B: 0.225, loss_G: 9.586
# Epoch: 77/300, acc_D_A: 0.549, acc_D_B: 0.711
# Epoch: 77/300, loss_gan: 0.781, loss_cyc: 8.799, loss_dep: 0.006
# --------------- test metrics---------------
# Epoch: 77/300, loss_D_A: 0.180, loss_D_B: 0.182, loss_G: 9.461
# Epoch: 77/300, acc_D_A: 0.877, acc_D_B: 0.874
# Epoch: 77/300, loss_gan: 0.747, loss_cyc: 8.710, loss_dep: 0.005
# ****************************************
# Trained epoch 78 in 7.0213 seconds
# ---------------train metrics---------------
# Epoch: 78/300, loss_D_A: 0.230, loss_D_B: 0.214, loss_G: 9.439
# Epoch: 78/300, acc_D_A: 0.645, acc_D_B: 0.600
# Epoch: 78/300, loss_gan: 0.760, loss_cyc: 8.673, loss_dep: 0.006
# --------------- test metrics---------------
# Epoch: 78/300, loss_D_A: 0.165, loss_D_B: 0.210, loss_G: 9.310
# Epoch: 78/300, acc_D_A: 0.945, acc_D_B: 0.503
# Epoch: 78/300, loss_gan: 0.563, loss_cyc: 8.742, loss_dep: 0.005
# ****************************************
# Trained epoch 79 in 7.0184 seconds
# ---------------train metrics---------------
# Epoch: 79/300, loss_D_A: 0.207, loss_D_B: 0.208, loss_G: 9.320
# Epoch: 79/300, acc_D_A: 0.696, acc_D_B: 0.669
# Epoch: 79/300, loss_gan: 0.709, loss_cyc: 8.604, loss_dep: 0.006
# --------------- test metrics---------------
# Epoch: 79/300, loss_D_A: 0.242, loss_D_B: 0.173, loss_G: 9.679
# Epoch: 79/300, acc_D_A: 0.506, acc_D_B: 0.620
# Epoch: 79/300, loss_gan: 0.924, loss_cyc: 8.750, loss_dep: 0.005
# ****************************************
# Trained epoch 80 in 7.0231 seconds
# ---------------train metrics---------------
# Epoch: 80/300, loss_D_A: 0.242, loss_D_B: 0.234, loss_G: 9.486
# Epoch: 80/300, acc_D_A: 0.522, acc_D_B: 0.559
# Epoch: 80/300, loss_gan: 0.790, loss_cyc: 8.689, loss_dep: 0.007
# --------------- test metrics---------------
# Epoch: 80/300, loss_D_A: 0.239, loss_D_B: 0.163, loss_G: 9.297
# Epoch: 80/300, acc_D_A: 0.500, acc_D_B: 0.853
# Epoch: 80/300, loss_gan: 0.588, loss_cyc: 8.702, loss_dep: 0.007
# ****************************************
# Trained epoch 81 in 7.0212 seconds
# ---------------train metrics---------------
# Epoch: 81/300, loss_D_A: 0.216, loss_D_B: 0.190, loss_G: 9.276
# Epoch: 81/300, acc_D_A: 0.635, acc_D_B: 0.761
# Epoch: 81/300, loss_gan: 0.705, loss_cyc: 8.564, loss_dep: 0.007
# --------------- test metrics---------------
# Epoch: 81/300, loss_D_A: 0.206, loss_D_B: 0.231, loss_G: 9.792
# Epoch: 81/300, acc_D_A: 0.558, acc_D_B: 0.509
# Epoch: 81/300, loss_gan: 0.881, loss_cyc: 8.906, loss_dep: 0.005
# ****************************************
# Trained epoch 82 in 7.0198 seconds
# ---------------train metrics---------------
# Epoch: 82/300, loss_D_A: 0.212, loss_D_B: 0.208, loss_G: 9.413
# Epoch: 82/300, acc_D_A: 0.683, acc_D_B: 0.592
# Epoch: 82/300, loss_gan: 0.774, loss_cyc: 8.633, loss_dep: 0.006
# --------------- test metrics---------------
# Epoch: 82/300, loss_D_A: 0.209, loss_D_B: 0.276, loss_G: 9.617
# Epoch: 82/300, acc_D_A: 0.521, acc_D_B: 0.500
# Epoch: 82/300, loss_gan: 0.729, loss_cyc: 8.883, loss_dep: 0.005
# ****************************************
# Trained epoch 83 in 7.0197 seconds
# ---------------train metrics---------------
# Epoch: 83/300, loss_D_A: 0.231, loss_D_B: 0.236, loss_G: 9.341
# Epoch: 83/300, acc_D_A: 0.644, acc_D_B: 0.618
# Epoch: 83/300, loss_gan: 0.768, loss_cyc: 8.567, loss_dep: 0.006
# --------------- test metrics---------------
# Epoch: 83/300, loss_D_A: 0.196, loss_D_B: 0.245, loss_G: 9.291
# Epoch: 83/300, acc_D_A: 0.620, acc_D_B: 0.500
# Epoch: 83/300, loss_gan: 0.614, loss_cyc: 8.672, loss_dep: 0.005
# ****************************************
# Trained epoch 84 in 7.0182 seconds
# ---------------train metrics---------------
# Epoch: 84/300, loss_D_A: 0.232, loss_D_B: 0.217, loss_G: 9.314
# Epoch: 84/300, acc_D_A: 0.553, acc_D_B: 0.559
# Epoch: 84/300, loss_gan: 0.718, loss_cyc: 8.590, loss_dep: 0.006
# --------------- test metrics---------------
# Epoch: 84/300, loss_D_A: 0.207, loss_D_B: 0.249, loss_G: 9.161
# Epoch: 84/300, acc_D_A: 0.663, acc_D_B: 0.500
# Epoch: 84/300, loss_gan: 0.561, loss_cyc: 8.595, loss_dep: 0.004
# ****************************************
# Trained epoch 85 in 6.9978 seconds
# ---------------train metrics---------------
# Epoch: 85/300, loss_D_A: 0.214, loss_D_B: 0.211, loss_G: 9.159
# Epoch: 85/300, acc_D_A: 0.690, acc_D_B: 0.670
# Epoch: 85/300, loss_gan: 0.653, loss_cyc: 8.500, loss_dep: 0.006
# --------------- test metrics---------------
# Epoch: 85/300, loss_D_A: 0.255, loss_D_B: 0.264, loss_G: 9.666
# Epoch: 85/300, acc_D_A: 0.506, acc_D_B: 0.479
# Epoch: 85/300, loss_gan: 0.854, loss_cyc: 8.806, loss_dep: 0.005
# ****************************************
# Trained epoch 86 in 7.0074 seconds
# ---------------train metrics---------------
# Epoch: 86/300, loss_D_A: 0.231, loss_D_B: 0.218, loss_G: 9.333
# Epoch: 86/300, acc_D_A: 0.712, acc_D_B: 0.618
# Epoch: 86/300, loss_gan: 0.724, loss_cyc: 8.604, loss_dep: 0.005
# --------------- test metrics---------------
# Epoch: 86/300, loss_D_A: 0.192, loss_D_B: 0.162, loss_G: 9.269
# Epoch: 86/300, acc_D_A: 0.788, acc_D_B: 0.905
# Epoch: 86/300, loss_gan: 0.676, loss_cyc: 8.589, loss_dep: 0.004
# ****************************************
# Trained epoch 87 in 7.0137 seconds
# ---------------train metrics---------------
# Epoch: 87/300, loss_D_A: 0.255, loss_D_B: 0.273, loss_G: 9.404
# Epoch: 87/300, acc_D_A: 0.664, acc_D_B: 0.707
# Epoch: 87/300, loss_gan: 0.821, loss_cyc: 8.578, loss_dep: 0.006
# --------------- test metrics---------------
# Epoch: 87/300, loss_D_A: 0.153, loss_D_B: 0.159, loss_G: 9.669
# Epoch: 87/300, acc_D_A: 0.975, acc_D_B: 0.653
# Epoch: 87/300, loss_gan: 1.092, loss_cyc: 8.572, loss_dep: 0.005
# ****************************************
# Trained epoch 88 in 7.0167 seconds
# ---------------train metrics---------------
# Epoch: 88/300, loss_D_A: 0.197, loss_D_B: 0.193, loss_G: 9.026
# Epoch: 88/300, acc_D_A: 0.733, acc_D_B: 0.733
# Epoch: 88/300, loss_gan: 0.689, loss_cyc: 8.331, loss_dep: 0.005
# --------------- test metrics---------------
# Epoch: 88/300, loss_D_A: 0.168, loss_D_B: 0.217, loss_G: 9.312
# Epoch: 88/300, acc_D_A: 0.739, acc_D_B: 0.515
# Epoch: 88/300, loss_gan: 0.688, loss_cyc: 8.620, loss_dep: 0.004
# ****************************************
# Trained epoch 89 in 7.0149 seconds
# ---------------train metrics---------------
# Epoch: 89/300, loss_D_A: 0.209, loss_D_B: 0.194, loss_G: 9.176
# Epoch: 89/300, acc_D_A: 0.579, acc_D_B: 0.736
# Epoch: 89/300, loss_gan: 0.708, loss_cyc: 8.463, loss_dep: 0.005
# --------------- test metrics---------------
# Epoch: 89/300, loss_D_A: 0.164, loss_D_B: 0.221, loss_G: 9.488
# Epoch: 89/300, acc_D_A: 0.715, acc_D_B: 0.518
# Epoch: 89/300, loss_gan: 0.744, loss_cyc: 8.740, loss_dep: 0.005
# ****************************************
# Trained epoch 90 in 7.0172 seconds
# ---------------train metrics---------------
# Epoch: 90/300, loss_D_A: 0.250, loss_D_B: 0.233, loss_G: 9.228
# Epoch: 90/300, acc_D_A: 0.620, acc_D_B: 0.660
# Epoch: 90/300, loss_gan: 0.794, loss_cyc: 8.429, loss_dep: 0.005
# --------------- test metrics---------------
# Epoch: 90/300, loss_D_A: 0.212, loss_D_B: 0.228, loss_G: 9.115
# Epoch: 90/300, acc_D_A: 0.604, acc_D_B: 0.515
# Epoch: 90/300, loss_gan: 0.622, loss_cyc: 8.490, loss_dep: 0.004
# ****************************************
# Trained epoch 91 in 7.0178 seconds
# ---------------train metrics---------------
# Epoch: 91/300, loss_D_A: 0.202, loss_D_B: 0.225, loss_G: 9.072
# Epoch: 91/300, acc_D_A: 0.681, acc_D_B: 0.621
# Epoch: 91/300, loss_gan: 0.671, loss_cyc: 8.395, loss_dep: 0.005
# --------------- test metrics---------------
# Epoch: 91/300, loss_D_A: 0.168, loss_D_B: 0.217, loss_G: 9.365
# Epoch: 91/300, acc_D_A: 0.890, acc_D_B: 0.638
# Epoch: 91/300, loss_gan: 0.645, loss_cyc: 8.713, loss_dep: 0.006
# ****************************************
# Trained epoch 92 in 7.0165 seconds
# ---------------train metrics---------------
# Epoch: 92/300, loss_D_A: 0.274, loss_D_B: 0.221, loss_G: 9.420
# Epoch: 92/300, acc_D_A: 0.619, acc_D_B: 0.595
# Epoch: 92/300, loss_gan: 0.856, loss_cyc: 8.558, loss_dep: 0.006
# --------------- test metrics---------------
# Epoch: 92/300, loss_D_A: 0.209, loss_D_B: 0.163, loss_G: 9.102
# Epoch: 92/300, acc_D_A: 0.500, acc_D_B: 0.905
# Epoch: 92/300, loss_gan: 0.588, loss_cyc: 8.511, loss_dep: 0.004
# ****************************************
# Trained epoch 93 in 7.0159 seconds
# ---------------train metrics---------------
# Epoch: 93/300, loss_D_A: 0.207, loss_D_B: 0.198, loss_G: 8.989
# Epoch: 93/300, acc_D_A: 0.758, acc_D_B: 0.771
# Epoch: 93/300, loss_gan: 0.624, loss_cyc: 8.360, loss_dep: 0.005
# --------------- test metrics---------------
# Epoch: 93/300, loss_D_A: 0.175, loss_D_B: 0.159, loss_G: 9.400
# Epoch: 93/300, acc_D_A: 0.960, acc_D_B: 0.917
# Epoch: 93/300, loss_gan: 0.661, loss_cyc: 8.735, loss_dep: 0.004
# ****************************************
# Trained epoch 94 in 7.0169 seconds
# ---------------train metrics---------------
# ...
# Epoch: 270/300, loss_gan: 0.865, loss_cyc: 6.669, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 270/300, loss_D_A: 0.183, loss_D_B: 0.184, loss_G: 8.012
# Epoch: 270/300, acc_D_A: 0.736, acc_D_B: 0.788
# Epoch: 270/300, loss_gan: 0.897, loss_cyc: 7.112, loss_dep: 0.003
# ****************************************
# Trained epoch 271 in 7.0881 seconds
# ---------------train metrics---------------
# Epoch: 271/300, loss_D_A: 0.134, loss_D_B: 0.138, loss_G: 7.501
# Epoch: 271/300, acc_D_A: 0.955, acc_D_B: 0.962
# Epoch: 271/300, loss_gan: 0.833, loss_cyc: 6.663, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 271/300, loss_D_A: 0.166, loss_D_B: 0.173, loss_G: 7.926
# Epoch: 271/300, acc_D_A: 0.859, acc_D_B: 0.810
# Epoch: 271/300, loss_gan: 0.841, loss_cyc: 7.082, loss_dep: 0.003
# ****************************************
# Trained epoch 272 in 7.0921 seconds
# ---------------train metrics---------------
# Epoch: 272/300, loss_D_A: 0.139, loss_D_B: 0.136, loss_G: 7.471
# Epoch: 272/300, acc_D_A: 0.944, acc_D_B: 0.952
# Epoch: 272/300, loss_gan: 0.824, loss_cyc: 6.643, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 272/300, loss_D_A: 0.180, loss_D_B: 0.182, loss_G: 8.023
# Epoch: 272/300, acc_D_A: 0.724, acc_D_B: 0.776
# Epoch: 272/300, loss_gan: 0.924, loss_cyc: 7.095, loss_dep: 0.003
# ****************************************
# Trained epoch 273 in 7.0970 seconds
# ---------------train metrics---------------
# Epoch: 273/300, loss_D_A: 0.129, loss_D_B: 0.134, loss_G: 7.495
# Epoch: 273/300, acc_D_A: 0.968, acc_D_B: 0.956
# Epoch: 273/300, loss_gan: 0.852, loss_cyc: 6.639, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 273/300, loss_D_A: 0.169, loss_D_B: 0.169, loss_G: 8.085
# Epoch: 273/300, acc_D_A: 0.767, acc_D_B: 0.776
# Epoch: 273/300, loss_gan: 0.997, loss_cyc: 7.085, loss_dep: 0.003
# ****************************************
# Trained epoch 274 in 7.0957 seconds
# ---------------train metrics---------------
# Epoch: 274/300, loss_D_A: 0.130, loss_D_B: 0.131, loss_G: 7.500
# Epoch: 274/300, acc_D_A: 0.955, acc_D_B: 0.960
# Epoch: 274/300, loss_gan: 0.855, loss_cyc: 6.640, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 274/300, loss_D_A: 0.160, loss_D_B: 0.177, loss_G: 7.956
# Epoch: 274/300, acc_D_A: 0.862, acc_D_B: 0.761
# Epoch: 274/300, loss_gan: 0.911, loss_cyc: 7.043, loss_dep: 0.003
# ****************************************
# Trained epoch 275 in 7.0984 seconds
# ---------------train metrics---------------
# Epoch: 275/300, loss_D_A: 0.128, loss_D_B: 0.132, loss_G: 7.453
# Epoch: 275/300, acc_D_A: 0.964, acc_D_B: 0.965
# Epoch: 275/300, loss_gan: 0.850, loss_cyc: 6.599, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 275/300, loss_D_A: 0.192, loss_D_B: 0.187, loss_G: 7.986
# Epoch: 275/300, acc_D_A: 0.736, acc_D_B: 0.739
# Epoch: 275/300, loss_gan: 0.927, loss_cyc: 7.056, loss_dep: 0.003
# ****************************************
# Trained epoch 276 in 7.0982 seconds
# ---------------train metrics---------------
# Epoch: 276/300, loss_D_A: 0.133, loss_D_B: 0.139, loss_G: 7.437
# Epoch: 276/300, acc_D_A: 0.957, acc_D_B: 0.959
# Epoch: 276/300, loss_gan: 0.836, loss_cyc: 6.596, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 276/300, loss_D_A: 0.157, loss_D_B: 0.168, loss_G: 8.009
# Epoch: 276/300, acc_D_A: 0.819, acc_D_B: 0.828
# Epoch: 276/300, loss_gan: 0.939, loss_cyc: 7.066, loss_dep: 0.003
# ****************************************
# Trained epoch 277 in 7.0926 seconds
# ---------------train metrics---------------
# Epoch: 277/300, loss_D_A: 0.119, loss_D_B: 0.131, loss_G: 7.458
# Epoch: 277/300, acc_D_A: 0.980, acc_D_B: 0.975
# Epoch: 277/300, loss_gan: 0.865, loss_cyc: 6.589, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 277/300, loss_D_A: 0.160, loss_D_B: 0.183, loss_G: 8.019
# Epoch: 277/300, acc_D_A: 0.794, acc_D_B: 0.755
# Epoch: 277/300, loss_gan: 0.980, loss_cyc: 7.037, loss_dep: 0.003
# ****************************************
# Trained epoch 278 in 7.0964 seconds
# ---------------train metrics---------------
# Epoch: 278/300, loss_D_A: 0.118, loss_D_B: 0.132, loss_G: 7.433
# Epoch: 278/300, acc_D_A: 0.981, acc_D_B: 0.971
# Epoch: 278/300, loss_gan: 0.864, loss_cyc: 6.565, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 278/300, loss_D_A: 0.158, loss_D_B: 0.182, loss_G: 7.977
# Epoch: 278/300, acc_D_A: 0.837, acc_D_B: 0.739
# Epoch: 278/300, loss_gan: 0.972, loss_cyc: 7.002, loss_dep: 0.003
# ****************************************
# Trained epoch 279 in 7.0920 seconds
# ---------------train metrics---------------
# Epoch: 279/300, loss_D_A: 0.124, loss_D_B: 0.130, loss_G: 7.397
# Epoch: 279/300, acc_D_A: 0.975, acc_D_B: 0.976
# Epoch: 279/300, loss_gan: 0.860, loss_cyc: 6.533, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 279/300, loss_D_A: 0.173, loss_D_B: 0.175, loss_G: 7.981
# Epoch: 279/300, acc_D_A: 0.767, acc_D_B: 0.748
# Epoch: 279/300, loss_gan: 0.996, loss_cyc: 6.982, loss_dep: 0.003
# ****************************************
# Trained epoch 280 in 7.0907 seconds
# ---------------train metrics---------------
# Epoch: 280/300, loss_D_A: 0.121, loss_D_B: 0.125, loss_G: 7.403
# Epoch: 280/300, acc_D_A: 0.987, acc_D_B: 0.982
# Epoch: 280/300, loss_gan: 0.876, loss_cyc: 6.523, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 280/300, loss_D_A: 0.164, loss_D_B: 0.183, loss_G: 8.007
# Epoch: 280/300, acc_D_A: 0.791, acc_D_B: 0.730
# Epoch: 280/300, loss_gan: 0.974, loss_cyc: 7.030, loss_dep: 0.003
# ****************************************
# Trained epoch 281 in 7.0983 seconds
# ---------------train metrics---------------
# Epoch: 281/300, loss_D_A: 0.120, loss_D_B: 0.133, loss_G: 7.411
# Epoch: 281/300, acc_D_A: 0.974, acc_D_B: 0.974
# Epoch: 281/300, loss_gan: 0.866, loss_cyc: 6.541, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 281/300, loss_D_A: 0.166, loss_D_B: 0.175, loss_G: 8.018
# Epoch: 281/300, acc_D_A: 0.782, acc_D_B: 0.745
# Epoch: 281/300, loss_gan: 0.997, loss_cyc: 7.017, loss_dep: 0.003
# ****************************************
# Trained epoch 282 in 7.0972 seconds
# ---------------train metrics---------------
# Epoch: 282/300, loss_D_A: 0.124, loss_D_B: 0.119, loss_G: 7.433
# Epoch: 282/300, acc_D_A: 0.969, acc_D_B: 0.987
# Epoch: 282/300, loss_gan: 0.878, loss_cyc: 6.551, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 282/300, loss_D_A: 0.171, loss_D_B: 0.165, loss_G: 8.001
# Epoch: 282/300, acc_D_A: 0.779, acc_D_B: 0.804
# Epoch: 282/300, loss_gan: 0.968, loss_cyc: 7.030, loss_dep: 0.003
# ****************************************
# Trained epoch 283 in 7.1038 seconds
# ---------------train metrics---------------
# Epoch: 283/300, loss_D_A: 0.128, loss_D_B: 0.126, loss_G: 7.394
# Epoch: 283/300, acc_D_A: 0.963, acc_D_B: 0.983
# Epoch: 283/300, loss_gan: 0.856, loss_cyc: 6.534, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 283/300, loss_D_A: 0.171, loss_D_B: 0.178, loss_G: 7.985
# Epoch: 283/300, acc_D_A: 0.761, acc_D_B: 0.785
# Epoch: 283/300, loss_gan: 0.964, loss_cyc: 7.017, loss_dep: 0.003
# ****************************************
# Trained epoch 284 in 7.0982 seconds
# ---------------train metrics---------------
# Epoch: 284/300, loss_D_A: 0.128, loss_D_B: 0.129, loss_G: 7.390
# Epoch: 284/300, acc_D_A: 0.967, acc_D_B: 0.980
# Epoch: 284/300, loss_gan: 0.855, loss_cyc: 6.531, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 284/300, loss_D_A: 0.172, loss_D_B: 0.173, loss_G: 7.965
# Epoch: 284/300, acc_D_A: 0.770, acc_D_B: 0.758
# Epoch: 284/300, loss_gan: 0.970, loss_cyc: 6.992, loss_dep: 0.003
# ****************************************
# Trained epoch 285 in 7.0971 seconds
# ---------------train metrics---------------
# Epoch: 285/300, loss_D_A: 0.128, loss_D_B: 0.121, loss_G: 7.399
# Epoch: 285/300, acc_D_A: 0.967, acc_D_B: 0.989
# Epoch: 285/300, loss_gan: 0.870, loss_cyc: 6.525, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 285/300, loss_D_A: 0.165, loss_D_B: 0.164, loss_G: 7.964
# Epoch: 285/300, acc_D_A: 0.807, acc_D_B: 0.798
# Epoch: 285/300, loss_gan: 0.965, loss_cyc: 6.996, loss_dep: 0.003
# ****************************************
# Trained epoch 286 in 7.0997 seconds
# ---------------train metrics---------------
# Epoch: 286/300, loss_D_A: 0.121, loss_D_B: 0.121, loss_G: 7.400
# Epoch: 286/300, acc_D_A: 0.970, acc_D_B: 0.989
# Epoch: 286/300, loss_gan: 0.879, loss_cyc: 6.517, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 286/300, loss_D_A: 0.162, loss_D_B: 0.171, loss_G: 7.961
# Epoch: 286/300, acc_D_A: 0.831, acc_D_B: 0.785
# Epoch: 286/300, loss_gan: 0.971, loss_cyc: 6.987, loss_dep: 0.003
# ****************************************
# Trained epoch 287 in 7.1024 seconds
# ---------------train metrics---------------
# Epoch: 287/300, loss_D_A: 0.122, loss_D_B: 0.123, loss_G: 7.379
# Epoch: 287/300, acc_D_A: 0.963, acc_D_B: 0.987
# Epoch: 287/300, loss_gan: 0.873, loss_cyc: 6.501, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 287/300, loss_D_A: 0.170, loss_D_B: 0.172, loss_G: 8.013
# Epoch: 287/300, acc_D_A: 0.779, acc_D_B: 0.727
# Epoch: 287/300, loss_gan: 1.030, loss_cyc: 6.980, loss_dep: 0.003
# ****************************************
# Trained epoch 288 in 7.1033 seconds
# ---------------train metrics---------------
# Epoch: 288/300, loss_D_A: 0.121, loss_D_B: 0.120, loss_G: 7.372
# Epoch: 288/300, acc_D_A: 0.963, acc_D_B: 0.987
# Epoch: 288/300, loss_gan: 0.890, loss_cyc: 6.478, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 288/300, loss_D_A: 0.157, loss_D_B: 0.168, loss_G: 8.013
# Epoch: 288/300, acc_D_A: 0.788, acc_D_B: 0.773
# Epoch: 288/300, loss_gan: 1.033, loss_cyc: 6.977, loss_dep: 0.003
# ****************************************
# Trained epoch 289 in 7.1009 seconds
# ---------------train metrics---------------
# Epoch: 289/300, loss_D_A: 0.113, loss_D_B: 0.120, loss_G: 7.381
# Epoch: 289/300, acc_D_A: 0.981, acc_D_B: 0.989
# Epoch: 289/300, loss_gan: 0.903, loss_cyc: 6.474, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 289/300, loss_D_A: 0.159, loss_D_B: 0.170, loss_G: 8.009
# Epoch: 289/300, acc_D_A: 0.791, acc_D_B: 0.773
# Epoch: 289/300, loss_gan: 1.030, loss_cyc: 6.975, loss_dep: 0.003
# ****************************************
# Trained epoch 290 in 7.1007 seconds
# ---------------train metrics---------------
# Epoch: 290/300, loss_D_A: 0.117, loss_D_B: 0.121, loss_G: 7.360
# Epoch: 290/300, acc_D_A: 0.984, acc_D_B: 0.990
# Epoch: 290/300, loss_gan: 0.887, loss_cyc: 6.469, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 290/300, loss_D_A: 0.165, loss_D_B: 0.166, loss_G: 8.019
# Epoch: 290/300, acc_D_A: 0.755, acc_D_B: 0.761
# Epoch: 290/300, loss_gan: 1.061, loss_cyc: 6.956, loss_dep: 0.003
# ****************************************
# Trained epoch 291 in 7.1021 seconds
# ---------------train metrics---------------
# Epoch: 291/300, loss_D_A: 0.119, loss_D_B: 0.114, loss_G: 7.356
# Epoch: 291/300, acc_D_A: 0.982, acc_D_B: 0.995
# Epoch: 291/300, loss_gan: 0.898, loss_cyc: 6.454, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 291/300, loss_D_A: 0.161, loss_D_B: 0.158, loss_G: 8.022
# Epoch: 291/300, acc_D_A: 0.758, acc_D_B: 0.788
# Epoch: 291/300, loss_gan: 1.066, loss_cyc: 6.953, loss_dep: 0.003
# ****************************************
# Trained epoch 292 in 7.0954 seconds
# ---------------train metrics---------------
# Epoch: 292/300, loss_D_A: 0.113, loss_D_B: 0.114, loss_G: 7.354
# Epoch: 292/300, acc_D_A: 0.987, acc_D_B: 0.995
# Epoch: 292/300, loss_gan: 0.912, loss_cyc: 6.438, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 292/300, loss_D_A: 0.152, loss_D_B: 0.162, loss_G: 8.006
# Epoch: 292/300, acc_D_A: 0.810, acc_D_B: 0.782
# Epoch: 292/300, loss_gan: 1.060, loss_cyc: 6.943, loss_dep: 0.003
# ****************************************
# Trained epoch 293 in 7.1007 seconds
# ---------------train metrics---------------
# Epoch: 293/300, loss_D_A: 0.109, loss_D_B: 0.120, loss_G: 7.332
# Epoch: 293/300, acc_D_A: 0.987, acc_D_B: 0.990
# Epoch: 293/300, loss_gan: 0.905, loss_cyc: 6.423, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 293/300, loss_D_A: 0.154, loss_D_B: 0.171, loss_G: 8.008
# Epoch: 293/300, acc_D_A: 0.794, acc_D_B: 0.752
# Epoch: 293/300, loss_gan: 1.069, loss_cyc: 6.936, loss_dep: 0.003
# ****************************************
# Trained epoch 294 in 7.0971 seconds
# ---------------train metrics---------------
# Epoch: 294/300, loss_D_A: 0.112, loss_D_B: 0.123, loss_G: 7.316
# Epoch: 294/300, acc_D_A: 0.986, acc_D_B: 0.987
# Epoch: 294/300, loss_gan: 0.894, loss_cyc: 6.418, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 294/300, loss_D_A: 0.161, loss_D_B: 0.173, loss_G: 7.987
# Epoch: 294/300, acc_D_A: 0.764, acc_D_B: 0.733
# Epoch: 294/300, loss_gan: 1.052, loss_cyc: 6.931, loss_dep: 0.003
# ****************************************
# Trained epoch 295 in 7.0968 seconds
# ---------------train metrics---------------
# Epoch: 295/300, loss_D_A: 0.118, loss_D_B: 0.122, loss_G: 7.311
# Epoch: 295/300, acc_D_A: 0.984, acc_D_B: 0.988
# Epoch: 295/300, loss_gan: 0.887, loss_cyc: 6.419, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 295/300, loss_D_A: 0.167, loss_D_B: 0.169, loss_G: 7.982
# Epoch: 295/300, acc_D_A: 0.736, acc_D_B: 0.779
# Epoch: 295/300, loss_gan: 1.042, loss_cyc: 6.937, loss_dep: 0.003
# ****************************************
# Trained epoch 296 in 7.1036 seconds
# ---------------train metrics---------------
# Epoch: 296/300, loss_D_A: 0.120, loss_D_B: 0.120, loss_G: 7.308
# Epoch: 296/300, acc_D_A: 0.983, acc_D_B: 0.991
# Epoch: 296/300, loss_gan: 0.887, loss_cyc: 6.416, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 296/300, loss_D_A: 0.166, loss_D_B: 0.166, loss_G: 7.971
# Epoch: 296/300, acc_D_A: 0.745, acc_D_B: 0.758
# Epoch: 296/300, loss_gan: 1.042, loss_cyc: 6.926, loss_dep: 0.003
# ****************************************
# Trained epoch 297 in 7.1094 seconds
# ---------------train metrics---------------
# Epoch: 297/300, loss_D_A: 0.120, loss_D_B: 0.117, loss_G: 7.298
# Epoch: 297/300, acc_D_A: 0.987, acc_D_B: 0.994
# Epoch: 297/300, loss_gan: 0.887, loss_cyc: 6.407, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 297/300, loss_D_A: 0.165, loss_D_B: 0.164, loss_G: 7.984
# Epoch: 297/300, acc_D_A: 0.742, acc_D_B: 0.770
# Epoch: 297/300, loss_gan: 1.061, loss_cyc: 6.920, loss_dep: 0.003
# ****************************************
# Trained epoch 298 in 7.0830 seconds
# ---------------train metrics---------------
# Epoch: 298/300, loss_D_A: 0.119, loss_D_B: 0.115, loss_G: 7.305
# Epoch: 298/300, acc_D_A: 0.989, acc_D_B: 0.994
# Epoch: 298/300, loss_gan: 0.896, loss_cyc: 6.405, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 298/300, loss_D_A: 0.163, loss_D_B: 0.163, loss_G: 7.990
# Epoch: 298/300, acc_D_A: 0.748, acc_D_B: 0.764
# Epoch: 298/300, loss_gan: 1.071, loss_cyc: 6.917, loss_dep: 0.003
# ****************************************
# Trained epoch 299 in 6.9719 seconds
# ---------------train metrics---------------
# Epoch: 299/300, loss_D_A: 0.116, loss_D_B: 0.114, loss_G: 7.301
# Epoch: 299/300, acc_D_A: 0.992, acc_D_B: 0.995
# Epoch: 299/300, loss_gan: 0.899, loss_cyc: 6.398, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 299/300, loss_D_A: 0.162, loss_D_B: 0.162, loss_G: 7.998
# Epoch: 299/300, acc_D_A: 0.742, acc_D_B: 0.764
# Epoch: 299/300, loss_gan: 1.080, loss_cyc: 6.915, loss_dep: 0.003
# ****************************************
# Trained epoch 300 in 6.9660 seconds
# ---------------train metrics---------------
# Epoch: 300/300, loss_D_A: 0.115, loss_D_B: 0.114, loss_G: 7.309
# Epoch: 300/300, acc_D_A: 0.989, acc_D_B: 0.994
# Epoch: 300/300, loss_gan: 0.904, loss_cyc: 6.401, loss_dep: 0.004
# --------------- test metrics---------------
# Epoch: 300/300, loss_D_A: 0.161, loss_D_B: 0.162, loss_G: 8.002
# Epoch: 300/300, acc_D_A: 0.745, acc_D_B: 0.767
# Epoch: 300/300, loss_gan: 1.085, loss_cyc: 6.913, loss_dep: 0.003
# ****************************************
# Training complete. Results saved to ./saved_model/sleep_daf/

# %%
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 1)
plt.plot(range(nepoch), train_G_loss, label='Train G')
plt.plot(range(nepoch), train_DA_loss, label='Train D_A')
plt.plot(range(nepoch), train_DB_loss, label='Train D_B')
plt.title('Training Losses')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.ylim(0, 1)

plt.subplot(2, 2, 2)
plt.plot(range(nepoch), test_G_loss, label='Test G')
plt.plot(range(nepoch), test_DA_loss, label='Test D_A')
plt.plot(range(nepoch), test_DB_loss, label='Test D_B')
plt.title('Testing Losses')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.ylim(0, 3)

# Plot accuracy curves
plt.subplot(2, 2, 3)
plt.plot(range(nepoch), train_DA_acc, label='Train D_A')
plt.plot(range(nepoch), train_DB_acc, label='Train D_B')
plt.title('Training Accuracies')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
# plt.ylim(0, 1)

plt.subplot(2, 2, 4)
plt.plot(range(nepoch), test_DA_acc, label='Test D_A')
plt.plot(range(nepoch), test_DB_acc, label='Test D_B')
plt.title('Testing Accuracies')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
# plt.ylim(0, 1)

plt.tight_layout()
plt.show()

# %%
for epoch in range(300):
    if train_DA_acc[epoch] < 0.6 and train_DB_acc[epoch]< 0.6:
        print(epoch)
        print(train_DA_acc[epoch])
        print(train_DB_acc[epoch])
# Out:
# 50
# 0.5690104141831398
# 0.5953776016831398
# 79
# 0.5221294956281781
# 0.5592447891831398
# 83
# 0.553497868279616
# 0.5593335671971241
# 102
# 0.5888967762390772
# 0.5690104141831398

# %%
import sys
import torch
import random
import time
from models import *
from utils import *
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from torch.utils.data.sampler import SubsetRandomSampler
import os
import logging
logging.basicConfig(filename='./logs/daf-sleep.log', level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
def set_seed(seed_value=973028):
    """Set seed for reproducibility."""
    random.seed(seed_value)  # Python random module
    np.random.seed(seed_value)  # Numpy module
    torch.manual_seed(seed_value)  # PyTorch
    os.environ['PYTHONHASHSEED'] = str(seed_value)  # Python hash seed
    
    # CUDA reproducibility
    torch.cuda.manual_seed(seed_value)
    torch.cuda.manual_seed_all(seed_value)  # if use multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed()

# %% [markdown]
# # Unsupervised DAF

# %% [markdown]
# ## Load brain connectome data
#
# (adjacency matrices)

# %%
dat_abcd = loadmat('../abcd/new_abcd_cog.mat')
dat_hcp = loadmat('../hcp/HCP_subcortical_CMData_desikan.mat')
tensor_abcd = dat_abcd['count_network']
tensor_hcp = dat_hcp['loaded_tensor_sub']

# %%
# whether to apply log transformation to the adjacency matrices)
log=True

# %%
set_seed(1972014)
# np.random.seed(123456)
# orders = np.random.permutation(np.arange(68))
# offset = 18994
net_abcd = []
for i in range(tensor_abcd.shape[2]):
    ith = np.float32(tensor_abcd[:,:,i])
    if log:
        ith = np.log(ith+1)
    ith = ith.reshape(68*68)
    net_abcd.append(ith)
n_abcd = len(net_abcd)

net_hcp = []
for i in range(tensor_hcp.shape[3]):
    ith = np.float32(tensor_hcp[:,:,0,i] + np.transpose(tensor_hcp[:,:,0,i]))
    ith = ith[18:86, 18:86]
    if log:
        ith = np.log(ith+1)
#     np.fill_diagonal(ith,np.mean(ith, 0))
    ith = ith.reshape(68*68)
    net_hcp.append(ith)
n_hcp = len(net_hcp)

# %% [markdown]
# For similicity, sample from ABCD and HCP

# %%
_, id_abcd = train_test_split(range(n_abcd), test_size=892/n_abcd, random_state=42) # big 5079, small 173
_, id_hcp = train_test_split(range(n_hcp), test_size=173/n_hcp, random_state=42) # big 5079, small 173

print('abcd',len(id_abcd))
print('hcp',len(id_hcp))
# Out:
# abcd 892
# hcp 173

# %%
net_abcd = [net_abcd[i] for i in id_abcd]
net_hcp = [net_hcp[i] for i in id_hcp]
net_all = net_abcd + net_hcp

# %% [markdown]
# ## preprocess

# %%
if log:
    net_all = torch.stack([torch.Tensor(i) for i in net_all]).view(-1,1,68,68)
else:
    # If no log transformation, scale data to range [0,1] (default in cycle gan)
    offset = np.max(net_all)/2 # 9497
    net_all = torch.stack([torch.Tensor((i-offset)/offset) for i in net_all]).view(-1,1,68,68)

n_abcd, n_hcp = len(id_abcd), len(id_hcp)
n = n_abcd + n_hcp
# domain label: ABCD(0) HCP(1)
labels = torch.cat((torch.tensor([0]).expand(n_abcd,1), torch.tensor([1]).expand(n_hcp,1)))

# %% [markdown]
# ## Data loader

# %%
set_seed(1972034)
nepoch = 300
dataset = utils.TensorDataset(net_all, labels)
# split train and validataion 
train_id, test_id = train_test_split(list(range(n)),train_size=0.9, random_state=42)
train_dataset = utils.Subset(dataset, train_id)
test_dataset = utils.Subset(dataset, test_id)
train_loader = utils.DataLoader(train_dataset, batch_size=128, shuffle=True)
test_loader = utils.DataLoader(test_dataset, batch_size=len(test_id), shuffle=False)

# %% [markdown]
# ## DAF model configuration

# %%
# Networks
set_seed(1972014)
netG_A2B = Generator(input_nc=1, output_nc=1, init_depth=48, s_depth=10, n_residual_blocks=5).to(device)
netG_B2A = Generator(input_nc=1, output_nc=1, init_depth=48, s_depth=10, n_residual_blocks=5).to(device)
netD_A = Discriminator(input_nc=1, init_depth=48).to(device)
netD_B = Discriminator(input_nc=1, init_depth=48).to(device)

# Lossess
criterion_GAN = torch.nn.MSELoss()
criterion_cycle = torch.nn.L1Loss()

# Optimizers & LR schedulers
optimizer_G = torch.optim.Adam(itertools.chain(netG_A2B.parameters(), netG_B2A.parameters()),
                                lr=0.0002, betas=(0.5, 0.999))
optimizer_D_A = torch.optim.Adam(netD_A.parameters(), lr=0.0002, betas=(0.5, 0.999))
optimizer_D_B = torch.optim.Adam(netD_B.parameters(), lr=0.0002, betas=(0.5, 0.999))

lr_scheduler_G = torch.optim.lr_scheduler.LambdaLR(optimizer_G, lr_lambda=LambdaLR(nepoch, 0, nepoch/2).step)
lr_scheduler_D_A = torch.optim.lr_scheduler.LambdaLR(optimizer_D_A, lr_lambda=LambdaLR(nepoch, 0, nepoch/2).step)
lr_scheduler_D_B = torch.optim.lr_scheduler.LambdaLR(optimizer_D_B, lr_lambda=LambdaLR(nepoch, 0, nepoch/2).step)

# %% [markdown]
# ## Train

# %%
train_G_loss=[]
test_G_loss=[]
train_DA_loss=[]
test_DA_loss=[]
train_DB_loss=[]
test_DB_loss=[]
# frequency to monitor test loss
evaluate_every = 1

for epoch in range(0, nepoch):
    
    G_losses=[]
    DA_losses=[]
    DB_losses=[]
    iden=[]
    gan=[]
    cyc=[]
    dep=[]

    tic = time.perf_counter()
    for i, (A, s) in enumerate(train_loader):
        
        # Set model input
        real_A = A.to(device)
        real_B = A.to(device)
        s = s.to(device)
        bs = real_A.shape[0]
        
        # Inputs & targets memory allocation
        Tensor = torch.FloatTensor
        target_real = Variable(Tensor(bs,1).fill_(1.0), requires_grad=False).to(device)
        target_fake = Variable(Tensor(bs,1).fill_(0.0), requires_grad=False).to(device)
        
        ###### Generators A2B and B2A ######
        optimizer_G.zero_grad()
        
        # GAN loss 
        fake_B, _ = netG_A2B(real_A, s)
        pred_fake = netD_B(fake_B)
        loss_GAN_A2B = criterion_GAN(pred_fake, target_real)
        
        fake_A, _ = netG_B2A(real_B, s)
        pred_fake = netD_A(fake_A)
        loss_GAN_B2A = criterion_GAN(pred_fake, target_real)
        
        # Cycle loss
        recovered_A, _ = netG_B2A(fake_B, s)
        loss_cycle_ABA = criterion_cycle(recovered_A, real_A)*10.0

        recovered_B, _ = netG_A2B(fake_A, s)
        loss_cycle_BAB = criterion_cycle(recovered_B, real_B)*10.0
        
        # Dependence loss
        xt = fake_B.view(bs, -1)
        s = s.view(bs, 1)
        DLR = dependence(xt, s, sig=20, device=device) 

        loss_G = loss_GAN_A2B + loss_GAN_B2A + loss_cycle_ABA + loss_cycle_BAB + DLR   #+ loss_pred#if feed_iden else loss_GAN_A2B + loss_GAN_B2A + loss_cycle_ABA + loss_cycle_BAB
        loss_G.backward()
        
        optimizer_G.step()
        ###################################

        ###### Discriminator A ######
        optimizer_D_A.zero_grad()

        # Real loss
        pred_real = netD_A(real_A)
        loss_D_real = criterion_GAN(pred_real, target_real)

        # Fake loss
        pred_fake = netD_A(fake_A.detach())
        loss_D_fake = criterion_GAN(pred_fake, target_fake)

        # Total loss
        loss_D_A = (loss_D_real + loss_D_fake)*0.5
        loss_D_A.backward()

        optimizer_D_A.step()
        ###################################

        ###### Discriminator B ######
        optimizer_D_B.zero_grad()

        # Real loss
        pred_real = netD_B(real_B)
        loss_D_real = criterion_GAN(pred_real, target_real)
        
        # Fake loss
        pred_fake = netD_B(fake_B.detach())
        loss_D_fake = criterion_GAN(pred_fake, target_fake)

        # Total loss
        loss_D_B = (loss_D_real + loss_D_fake)*0.5
        loss_D_B.backward()

        optimizer_D_B.step()
        ###################################
        
        # collect loss
        G_losses.append(loss_G.data.item())
        DA_losses.append(loss_D_A.data.item())
        DB_losses.append(loss_D_B.data.item())
        ####
        gan.append(loss_GAN_A2B.data.item() + loss_GAN_B2A.data.item())
        cyc.append(loss_cycle_ABA.data.item() + loss_cycle_BAB.data.item())
        dep.append(DLR.data.item())
        
    # Update learning rates
    lr_scheduler_G.step()
    lr_scheduler_D_A.step()
    lr_scheduler_D_B.step()
    
    G_loss_epoch =  torch.mean(torch.FloatTensor(G_losses))
    DA_loss_epoch =  torch.mean(torch.FloatTensor(DA_losses))
    DB_loss_epoch =  torch.mean(torch.FloatTensor(DB_losses))
    #####
    gan_epoch =  torch.mean(torch.FloatTensor(gan))
    cyc_epoch =  torch.mean(torch.FloatTensor(cyc))
    dep_epoch =  torch.mean(torch.FloatTensor(dep))
    toc = time.perf_counter()
    print(f"trained epoch in {toc - tic:0.4f} seconds") 
    
    if (epoch + 1) % evaluate_every == 0:
        G_loss_test, DA_loss_test, DB_loss_test, gan_test, cyc_test, dep_test = evaluate(netG_A2B, netG_B2A, netD_A, netD_B, 
                                                                                         test_loader, epoch, device, save = True, plot=True,
                                                                                         root='./saved_model/unsup_daf/')
    
    logging.info('-'*15+'train loss'+'-'*15)    
    logging.info(f"Epoch: {epoch + 1}/{nepoch}, loss_D_A: {DA_loss_epoch:.3f}, loss_D_B: {DB_loss_epoch:.3f}, loss_G: {G_loss_epoch:.3f}")
    logging.info(f"Epoch: {epoch + 1}/{nepoch}, loss_gan: {gan_epoch:.3f}, loss_cyc: {cyc_epoch:.3f}, loss_dep: {dep_epoch:.3f}")
    logging.info('-'*15+' test loss'+'-'*15)   
    logging.info(f"Epoch: {epoch + 1}/{nepoch}, loss_D_A: {DA_loss_test:.3f}, loss_D_B: {DB_loss_test:.3f}, loss_G: {G_loss_test:.3f}")
    logging.info(f"Epoch: {epoch + 1}/{nepoch}, loss_gan: {gan_test:.3f}, loss_cyc: {cyc_test:.3f}, loss_dep: {dep_test:.3f}")
    logging.info('*'*40)

    print('-'*15+'train loss'+'-'*15)    
    print(f"Epoch: {epoch + 1}/{nepoch}, loss_D_A: {DA_loss_epoch:.3f}, loss_D_B: {DB_loss_epoch:.3f}, loss_G: {G_loss_epoch:.3f}")
    print(f"Epoch: {epoch + 1}/{nepoch}, loss_gan: {gan_epoch:.3f}, loss_cyc: {cyc_epoch:.3f}, loss_dep: {dep_epoch:.3f}")
    print('-'*15+' test loss'+'-'*15)   
    print(f"Epoch: {epoch + 1}/{nepoch}, loss_D_A: {DA_loss_test:.3f}, loss_D_B: {DB_loss_test:.3f}, loss_G: {G_loss_test:.3f}")
    print(f"Epoch: {epoch + 1}/{nepoch}, loss_gan: {gan_test:.3f}, loss_cyc: {cyc_test:.3f}, loss_dep: {dep_test:.3f}")
    print('*'*40)
    
    train_G_loss.append(G_loss_epoch.item())
    test_G_loss.append(G_loss_test)
    train_DA_loss.append(DA_loss_epoch.item())
    test_DA_loss.append(DA_loss_test)
    train_DB_loss.append(DB_loss_epoch.item())
    test_DB_loss.append(DB_loss_test)
# Out:
# trained epoch in 2.3773 seconds
# Directory './saved_model/unsup_daf/' was created.
# Directory './saved_model/unsup_daf/figs/' was created.
# ---------------train loss---------------
# Epoch: 1/300, loss_D_A: 0.168, loss_D_B: 0.106, loss_G: 36.120
# Epoch: 1/300, loss_gan: 1.182, loss_cyc: 34.897, loss_dep: 0.040
# --------------- test loss---------------
# Epoch: 1/300, loss_D_A: 0.026, loss_D_B: 0.024, loss_G: 34.159
# Epoch: 1/300, loss_gan: 1.412, loss_cyc: 32.714, loss_dep: 0.033
# ****************************************
# trained epoch in 1.6452 seconds
# ---------------train loss---------------
# Epoch: 2/300, loss_D_A: 0.105, loss_D_B: 0.188, loss_G: 33.504
# Epoch: 2/300, loss_gan: 1.775, loss_cyc: 31.670, loss_dep: 0.059
# --------------- test loss---------------
# Epoch: 2/300, loss_D_A: 0.087, loss_D_B: 0.100, loss_G: 31.264
# Epoch: 2/300, loss_gan: 1.807, loss_cyc: 29.418, loss_dep: 0.039
# ****************************************
# trained epoch in 1.6464 seconds
# ---------------train loss---------------
# Epoch: 3/300, loss_D_A: 0.062, loss_D_B: 0.042, loss_G: 29.562
# Epoch: 3/300, loss_gan: 1.589, loss_cyc: 27.909, loss_dep: 0.063
# --------------- test loss---------------
# Epoch: 3/300, loss_D_A: 0.029, loss_D_B: 0.028, loss_G: 26.921
# Epoch: 3/300, loss_gan: 1.637, loss_cyc: 25.247, loss_dep: 0.037
# ****************************************
# trained epoch in 1.6513 seconds
# ---------------train loss---------------
# Epoch: 4/300, loss_D_A: 0.027, loss_D_B: 0.028, loss_G: 27.418
# Epoch: 4/300, loss_gan: 1.563, loss_cyc: 25.792, loss_dep: 0.064
# --------------- test loss---------------
# Epoch: 4/300, loss_D_A: 0.106, loss_D_B: 0.018, loss_G: 25.582
# Epoch: 4/300, loss_gan: 1.373, loss_cyc: 24.171, loss_dep: 0.038
# ****************************************
# trained epoch in 1.6516 seconds
# ---------------train loss---------------
# Epoch: 5/300, loss_D_A: 0.161, loss_D_B: 0.161, loss_G: 25.721
# Epoch: 5/300, loss_gan: 1.776, loss_cyc: 23.879, loss_dep: 0.066
# --------------- test loss---------------
# Epoch: 5/300, loss_D_A: 0.019, loss_D_B: 0.020, loss_G: 23.301
# Epoch: 5/300, loss_gan: 1.477, loss_cyc: 21.788, loss_dep: 0.037
# ****************************************
# trained epoch in 1.6511 seconds
# ---------------train loss---------------
# Epoch: 6/300, loss_D_A: 0.029, loss_D_B: 0.032, loss_G: 22.942
# Epoch: 6/300, loss_gan: 1.462, loss_cyc: 21.418, loss_dep: 0.062
# --------------- test loss---------------
# Epoch: 6/300, loss_D_A: 0.040, loss_D_B: 0.106, loss_G: 21.106
# Epoch: 6/300, loss_gan: 0.977, loss_cyc: 20.094, loss_dep: 0.035
# ****************************************
# trained epoch in 1.6505 seconds
# ---------------train loss---------------
# Epoch: 7/300, loss_D_A: 0.175, loss_D_B: 0.119, loss_G: 21.907
# Epoch: 7/300, loss_gan: 1.588, loss_cyc: 20.260, loss_dep: 0.058
# --------------- test loss---------------
# Epoch: 7/300, loss_D_A: 0.053, loss_D_B: 0.043, loss_G: 19.579
# Epoch: 7/300, loss_gan: 1.786, loss_cyc: 17.760, loss_dep: 0.033
# ****************************************
# trained epoch in 1.6512 seconds
# ---------------train loss---------------
# Epoch: 8/300, loss_D_A: 0.032, loss_D_B: 0.198, loss_G: 19.699
# Epoch: 8/300, loss_gan: 1.450, loss_cyc: 18.193, loss_dep: 0.056
# --------------- test loss---------------
# Epoch: 8/300, loss_D_A: 0.032, loss_D_B: 0.092, loss_G: 18.703
# Epoch: 8/300, loss_gan: 1.959, loss_cyc: 16.711, loss_dep: 0.033
# ****************************************
# trained epoch in 1.6541 seconds
# ---------------train loss---------------
# Epoch: 9/300, loss_D_A: 0.156, loss_D_B: 0.058, loss_G: 18.522
# Epoch: 9/300, loss_gan: 1.416, loss_cyc: 17.049, loss_dep: 0.056
# --------------- test loss---------------
# Epoch: 9/300, loss_D_A: 0.053, loss_D_B: 0.048, loss_G: 16.172
# Epoch: 9/300, loss_gan: 1.303, loss_cyc: 14.837, loss_dep: 0.032
# ****************************************
# trained epoch in 1.6548 seconds
# ---------------train loss---------------
# Epoch: 10/300, loss_D_A: 0.092, loss_D_B: 0.138, loss_G: 16.985
# Epoch: 10/300, loss_gan: 1.393, loss_cyc: 15.539, loss_dep: 0.052
# --------------- test loss---------------
# Epoch: 10/300, loss_D_A: 0.150, loss_D_B: 0.256, loss_G: 15.787
# Epoch: 10/300, loss_gan: 1.657, loss_cyc: 14.100, loss_dep: 0.030
# ****************************************
# trained epoch in 1.6538 seconds
# ---------------train loss---------------
# Epoch: 11/300, loss_D_A: 0.082, loss_D_B: 0.127, loss_G: 15.887
# Epoch: 11/300, loss_gan: 1.208, loss_cyc: 14.627, loss_dep: 0.052
# --------------- test loss---------------
# Epoch: 11/300, loss_D_A: 0.143, loss_D_B: 0.087, loss_G: 14.973
# Epoch: 11/300, loss_gan: 1.675, loss_cyc: 13.269, loss_dep: 0.030
# ****************************************
# trained epoch in 1.6581 seconds
# ---------------train loss---------------
# Epoch: 12/300, loss_D_A: 0.162, loss_D_B: 0.107, loss_G: 15.318
# Epoch: 12/300, loss_gan: 1.318, loss_cyc: 13.948, loss_dep: 0.052
# --------------- test loss---------------
# Epoch: 12/300, loss_D_A: 0.083, loss_D_B: 0.644, loss_G: 13.734
# Epoch: 12/300, loss_gan: 0.497, loss_cyc: 13.207, loss_dep: 0.030
# ****************************************
# trained epoch in 1.6573 seconds
# ---------------train loss---------------
# Epoch: 13/300, loss_D_A: 0.139, loss_D_B: 0.234, loss_G: 14.596
# Epoch: 13/300, loss_gan: 1.215, loss_cyc: 13.327, loss_dep: 0.054
# --------------- test loss---------------
# Epoch: 13/300, loss_D_A: 0.220, loss_D_B: 0.091, loss_G: 13.664
# Epoch: 13/300, loss_gan: 0.715, loss_cyc: 12.920, loss_dep: 0.030
# ****************************************
# trained epoch in 1.6580 seconds
# ---------------train loss---------------
# Epoch: 14/300, loss_D_A: 0.152, loss_D_B: 0.088, loss_G: 13.896
# Epoch: 14/300, loss_gan: 1.041, loss_cyc: 12.807, loss_dep: 0.049
# --------------- test loss---------------
# Epoch: 14/300, loss_D_A: 0.106, loss_D_B: 0.092, loss_G: 13.224
# Epoch: 14/300, loss_gan: 0.992, loss_cyc: 12.204, loss_dep: 0.028
# ****************************************
# trained epoch in 1.6588 seconds
# ---------------train loss---------------
# Epoch: 15/300, loss_D_A: 0.150, loss_D_B: 0.220, loss_G: 13.576
# Epoch: 15/300, loss_gan: 1.095, loss_cyc: 12.433, loss_dep: 0.047
# --------------- test loss---------------
# Epoch: 15/300, loss_D_A: 0.503, loss_D_B: 0.136, loss_G: 14.592
# Epoch: 15/300, loss_gan: 2.718, loss_cyc: 11.848, loss_dep: 0.027
# ****************************************
# trained epoch in 1.6583 seconds
# ---------------train loss---------------
# Epoch: 16/300, loss_D_A: 0.219, loss_D_B: 0.105, loss_G: 13.207
# Epoch: 16/300, loss_gan: 1.164, loss_cyc: 11.999, loss_dep: 0.045
# --------------- test loss---------------
# Epoch: 16/300, loss_D_A: 0.111, loss_D_B: 0.110, loss_G: 12.264
# Epoch: 16/300, loss_gan: 0.828, loss_cyc: 11.410, loss_dep: 0.026
# ****************************************
# trained epoch in 1.6640 seconds
# ---------------train loss---------------
# Epoch: 17/300, loss_D_A: 0.107, loss_D_B: 0.105, loss_G: 12.877
# Epoch: 17/300, loss_gan: 1.037, loss_cyc: 11.797, loss_dep: 0.043
# --------------- test loss---------------
# Epoch: 17/300, loss_D_A: 0.128, loss_D_B: 0.215, loss_G: 12.026
# Epoch: 17/300, loss_gan: 0.462, loss_cyc: 11.540, loss_dep: 0.024
# ****************************************
# trained epoch in 1.6645 seconds
# ---------------train loss---------------
# Epoch: 18/300, loss_D_A: 0.220, loss_D_B: 0.158, loss_G: 12.991
# Epoch: 18/300, loss_gan: 1.087, loss_cyc: 11.863, loss_dep: 0.041
# --------------- test loss---------------
# Epoch: 18/300, loss_D_A: 0.125, loss_D_B: 0.099, loss_G: 12.696
# Epoch: 18/300, loss_gan: 0.955, loss_cyc: 11.718, loss_dep: 0.024
# ****************************************
# trained epoch in 1.6609 seconds
# ---------------train loss---------------
# Epoch: 19/300, loss_D_A: 0.120, loss_D_B: 0.127, loss_G: 12.535
# Epoch: 19/300, loss_gan: 0.889, loss_cyc: 11.606, loss_dep: 0.040
# --------------- test loss---------------
# Epoch: 19/300, loss_D_A: 0.100, loss_D_B: 0.282, loss_G: 13.338
# Epoch: 19/300, loss_gan: 1.843, loss_cyc: 11.475, loss_dep: 0.020
# ****************************************
# trained epoch in 1.6668 seconds
# ---------------train loss---------------
# Epoch: 20/300, loss_D_A: 0.117, loss_D_B: 0.301, loss_G: 12.858
# Epoch: 20/300, loss_gan: 1.176, loss_cyc: 11.644, loss_dep: 0.039
# --------------- test loss---------------
# Epoch: 20/300, loss_D_A: 0.336, loss_D_B: 0.121, loss_G: 11.661
# Epoch: 20/300, loss_gan: 0.502, loss_cyc: 11.136, loss_dep: 0.023
# ****************************************
# trained epoch in 1.6672 seconds
# ---------------train loss---------------
# Epoch: 21/300, loss_D_A: 0.336, loss_D_B: 0.128, loss_G: 12.295
# Epoch: 21/300, loss_gan: 1.060, loss_cyc: 11.195, loss_dep: 0.039
# --------------- test loss---------------
# Epoch: 21/300, loss_D_A: 0.151, loss_D_B: 0.114, loss_G: 11.482
# Epoch: 21/300, loss_gan: 0.749, loss_cyc: 10.713, loss_dep: 0.020
# ****************************************
# trained epoch in 1.6688 seconds
# ---------------train loss---------------
# Epoch: 22/300, loss_D_A: 0.143, loss_D_B: 0.127, loss_G: 11.952
# Epoch: 22/300, loss_gan: 0.853, loss_cyc: 11.066, loss_dep: 0.032
# --------------- test loss---------------
# Epoch: 22/300, loss_D_A: 0.125, loss_D_B: 0.133, loss_G: 12.036
# Epoch: 22/300, loss_gan: 1.057, loss_cyc: 10.962, loss_dep: 0.016
# ****************************************
# trained epoch in 1.6688 seconds
# ---------------train loss---------------
# Epoch: 23/300, loss_D_A: 0.132, loss_D_B: 0.167, loss_G: 12.244
# Epoch: 23/300, loss_gan: 0.916, loss_cyc: 11.299, loss_dep: 0.029
# --------------- test loss---------------
# Epoch: 23/300, loss_D_A: 0.141, loss_D_B: 0.257, loss_G: 12.133
# Epoch: 23/300, loss_gan: 1.361, loss_cyc: 10.755, loss_dep: 0.017
# ****************************************
# trained epoch in 1.6703 seconds
# ---------------train loss---------------
# Epoch: 24/300, loss_D_A: 0.179, loss_D_B: 0.234, loss_G: 12.153
# Epoch: 24/300, loss_gan: 1.044, loss_cyc: 11.078, loss_dep: 0.030
# --------------- test loss---------------
# Epoch: 24/300, loss_D_A: 0.133, loss_D_B: 0.129, loss_G: 11.503
# Epoch: 24/300, loss_gan: 0.861, loss_cyc: 10.626, loss_dep: 0.017
# ****************************************
# trained epoch in 1.6673 seconds
# ---------------train loss---------------
# Epoch: 25/300, loss_D_A: 0.152, loss_D_B: 0.139, loss_G: 11.943
# Epoch: 25/300, loss_gan: 0.866, loss_cyc: 11.048, loss_dep: 0.029
# --------------- test loss---------------
# Epoch: 25/300, loss_D_A: 0.279, loss_D_B: 0.093, loss_G: 11.899
# Epoch: 25/300, loss_gan: 0.725, loss_cyc: 11.158, loss_dep: 0.016
# ****************************************
# trained epoch in 1.6728 seconds
# ---------------train loss---------------
# Epoch: 26/300, loss_D_A: 0.246, loss_D_B: 0.159, loss_G: 12.312
# Epoch: 26/300, loss_gan: 1.147, loss_cyc: 11.138, loss_dep: 0.027
# --------------- test loss---------------
# Epoch: 26/300, loss_D_A: 0.099, loss_D_B: 0.099, loss_G: 11.483
# Epoch: 26/300, loss_gan: 0.943, loss_cyc: 10.526, loss_dep: 0.014
# ****************************************
# trained epoch in 1.6732 seconds
# ---------------train loss---------------
# Epoch: 27/300, loss_D_A: 0.188, loss_D_B: 0.248, loss_G: 11.949
# Epoch: 27/300, loss_gan: 1.006, loss_cyc: 10.919, loss_dep: 0.024
# --------------- test loss---------------
# Epoch: 27/300, loss_D_A: 0.137, loss_D_B: 0.137, loss_G: 11.316
# Epoch: 27/300, loss_gan: 0.990, loss_cyc: 10.312, loss_dep: 0.014
# ****************************************
# trained epoch in 1.6748 seconds
# ---------------train loss---------------
# Epoch: 28/300, loss_D_A: 0.136, loss_D_B: 0.136, loss_G: 11.603
# Epoch: 28/300, loss_gan: 0.845, loss_cyc: 10.735, loss_dep: 0.024
# --------------- test loss---------------
# Epoch: 28/300, loss_D_A: 0.113, loss_D_B: 0.110, loss_G: 11.566
# Epoch: 28/300, loss_gan: 0.855, loss_cyc: 10.697, loss_dep: 0.013
# ****************************************
# trained epoch in 1.6741 seconds
# ---------------train loss---------------
# Epoch: 29/300, loss_D_A: 0.254, loss_D_B: 0.215, loss_G: 12.438
# Epoch: 29/300, loss_gan: 1.196, loss_cyc: 11.217, loss_dep: 0.025
# --------------- test loss---------------
# Epoch: 29/300, loss_D_A: 0.158, loss_D_B: 0.151, loss_G: 10.964
# Epoch: 29/300, loss_gan: 0.445, loss_cyc: 10.503, loss_dep: 0.016
# ****************************************
# trained epoch in 1.6750 seconds
# ---------------train loss---------------
# Epoch: 30/300, loss_D_A: 0.154, loss_D_B: 0.149, loss_G: 11.420
# Epoch: 30/300, loss_gan: 0.826, loss_cyc: 10.569, loss_dep: 0.024
# --------------- test loss---------------
# Epoch: 30/300, loss_D_A: 0.174, loss_D_B: 0.242, loss_G: 10.966
# Epoch: 30/300, loss_gan: 0.556, loss_cyc: 10.396, loss_dep: 0.014
# ****************************************
# trained epoch in 1.6737 seconds
# ---------------train loss---------------
# Epoch: 31/300, loss_D_A: 0.156, loss_D_B: 0.172, loss_G: 11.587
# Epoch: 31/300, loss_gan: 0.828, loss_cyc: 10.739, loss_dep: 0.021
# --------------- test loss---------------
# Epoch: 31/300, loss_D_A: 0.156, loss_D_B: 0.276, loss_G: 11.663
# Epoch: 31/300, loss_gan: 0.826, loss_cyc: 10.826, loss_dep: 0.012
# ****************************************
# trained epoch in 1.6773 seconds
# ---------------train loss---------------
# Epoch: 32/300, loss_D_A: 0.194, loss_D_B: 0.220, loss_G: 11.813
# Epoch: 32/300, loss_gan: 0.994, loss_cyc: 10.800, loss_dep: 0.020
# --------------- test loss---------------
# Epoch: 32/300, loss_D_A: 0.127, loss_D_B: 0.134, loss_G: 10.990
# Epoch: 32/300, loss_gan: 0.783, loss_cyc: 10.196, loss_dep: 0.012
# ****************************************
# trained epoch in 1.6739 seconds
# ---------------train loss---------------
# Epoch: 33/300, loss_D_A: 0.162, loss_D_B: 0.148, loss_G: 11.310
# Epoch: 33/300, loss_gan: 0.780, loss_cyc: 10.511, loss_dep: 0.019
# --------------- test loss---------------
# Epoch: 33/300, loss_D_A: 0.137, loss_D_B: 0.180, loss_G: 11.642
# Epoch: 33/300, loss_gan: 0.898, loss_cyc: 10.732, loss_dep: 0.012
# ****************************************
# trained epoch in 1.6777 seconds
# ---------------train loss---------------
# Epoch: 34/300, loss_D_A: 0.285, loss_D_B: 0.267, loss_G: 12.044
# Epoch: 34/300, loss_gan: 1.165, loss_cyc: 10.859, loss_dep: 0.020
# --------------- test loss---------------
# Epoch: 34/300, loss_D_A: 0.146, loss_D_B: 0.119, loss_G: 11.104
# Epoch: 34/300, loss_gan: 0.875, loss_cyc: 10.217, loss_dep: 0.013
# ****************************************
# trained epoch in 1.6789 seconds
# ---------------train loss---------------
# Epoch: 35/300, loss_D_A: 0.138, loss_D_B: 0.159, loss_G: 11.054
# Epoch: 35/300, loss_gan: 0.800, loss_cyc: 10.234, loss_dep: 0.019
# --------------- test loss---------------
# Epoch: 35/300, loss_D_A: 0.192, loss_D_B: 0.160, loss_G: 10.968
# Epoch: 35/300, loss_gan: 0.698, loss_cyc: 10.261, loss_dep: 0.009
# ****************************************
# trained epoch in 1.6795 seconds
# ---------------train loss---------------
# Epoch: 36/300, loss_D_A: 0.138, loss_D_B: 0.157, loss_G: 11.387
# Epoch: 36/300, loss_gan: 0.817, loss_cyc: 10.556, loss_dep: 0.014
# --------------- test loss---------------
# Epoch: 36/300, loss_D_A: 0.155, loss_D_B: 0.255, loss_G: 13.297
# Epoch: 36/300, loss_gan: 1.684, loss_cyc: 11.604, loss_dep: 0.009
# ****************************************
# trained epoch in 1.6814 seconds
# ---------------train loss---------------
# Epoch: 37/300, loss_D_A: 0.228, loss_D_B: 0.212, loss_G: 11.706
# Epoch: 37/300, loss_gan: 1.139, loss_cyc: 10.551, loss_dep: 0.016
# --------------- test loss---------------
# Epoch: 37/300, loss_D_A: 0.146, loss_D_B: 0.151, loss_G: 11.439
# Epoch: 37/300, loss_gan: 1.063, loss_cyc: 10.367, loss_dep: 0.009
# ****************************************
# trained epoch in 1.6810 seconds
# ---------------train loss---------------
# Epoch: 38/300, loss_D_A: 0.191, loss_D_B: 0.205, loss_G: 11.107
# Epoch: 38/300, loss_gan: 0.797, loss_cyc: 10.294, loss_dep: 0.015
# --------------- test loss---------------
# Epoch: 38/300, loss_D_A: 0.189, loss_D_B: 0.201, loss_G: 10.682
# Epoch: 38/300, loss_gan: 0.622, loss_cyc: 10.052, loss_dep: 0.008
# ****************************************
# trained epoch in 1.6822 seconds
# ---------------train loss---------------
# Epoch: 39/300, loss_D_A: 0.148, loss_D_B: 0.152, loss_G: 11.206
# Epoch: 39/300, loss_gan: 0.805, loss_cyc: 10.388, loss_dep: 0.013
# --------------- test loss---------------
# Epoch: 39/300, loss_D_A: 0.181, loss_D_B: 0.126, loss_G: 11.230
# Epoch: 39/300, loss_gan: 0.873, loss_cyc: 10.349, loss_dep: 0.008
# ****************************************
# trained epoch in 1.6825 seconds
# ---------------train loss---------------
# Epoch: 40/300, loss_D_A: 0.193, loss_D_B: 0.220, loss_G: 11.722
# Epoch: 40/300, loss_gan: 1.158, loss_cyc: 10.549, loss_dep: 0.015
# --------------- test loss---------------
# Epoch: 40/300, loss_D_A: 0.096, loss_D_B: 0.127, loss_G: 11.097
# Epoch: 40/300, loss_gan: 1.012, loss_cyc: 10.076, loss_dep: 0.009
# ****************************************
# trained epoch in 1.6848 seconds
# ---------------train loss---------------
# Epoch: 41/300, loss_D_A: 0.177, loss_D_B: 0.166, loss_G: 11.371
# Epoch: 41/300, loss_gan: 0.910, loss_cyc: 10.447, loss_dep: 0.014
# --------------- test loss---------------
# Epoch: 41/300, loss_D_A: 0.136, loss_D_B: 0.188, loss_G: 10.975
# Epoch: 41/300, loss_gan: 0.872, loss_cyc: 10.097, loss_dep: 0.007
# ****************************************
# trained epoch in 1.6841 seconds
# ---------------train loss---------------
# Epoch: 42/300, loss_D_A: 0.189, loss_D_B: 0.203, loss_G: 11.181
# Epoch: 42/300, loss_gan: 0.902, loss_cyc: 10.268, loss_dep: 0.012
# --------------- test loss---------------
# Epoch: 42/300, loss_D_A: 0.181, loss_D_B: 0.344, loss_G: 11.302
# Epoch: 42/300, loss_gan: 0.935, loss_cyc: 10.359, loss_dep: 0.007
# ****************************************
# trained epoch in 1.6810 seconds
# ---------------train loss---------------
# Epoch: 43/300, loss_D_A: 0.174, loss_D_B: 0.187, loss_G: 11.129
# Epoch: 43/300, loss_gan: 0.858, loss_cyc: 10.259, loss_dep: 0.012
# --------------- test loss---------------
# Epoch: 43/300, loss_D_A: 0.140, loss_D_B: 0.196, loss_G: 11.290
# Epoch: 43/300, loss_gan: 0.940, loss_cyc: 10.343, loss_dep: 0.007
# ****************************************
# trained epoch in 1.6864 seconds
# ---------------train loss---------------
# Epoch: 44/300, loss_D_A: 0.170, loss_D_B: 0.196, loss_G: 11.276
# Epoch: 44/300, loss_gan: 0.968, loss_cyc: 10.295, loss_dep: 0.013
# --------------- test loss---------------
# Epoch: 44/300, loss_D_A: 0.122, loss_D_B: 0.244, loss_G: 11.037
# Epoch: 44/300, loss_gan: 0.706, loss_cyc: 10.324, loss_dep: 0.007
# ****************************************
# trained epoch in 1.6864 seconds
# ---------------train loss---------------
# Epoch: 45/300, loss_D_A: 0.233, loss_D_B: 0.195, loss_G: 11.227
# Epoch: 45/300, loss_gan: 0.978, loss_cyc: 10.236, loss_dep: 0.013
# --------------- test loss---------------
# Epoch: 45/300, loss_D_A: 0.171, loss_D_B: 0.170, loss_G: 10.824
# Epoch: 45/300, loss_gan: 0.663, loss_cyc: 10.154, loss_dep: 0.007
# ****************************************
# trained epoch in 1.6858 seconds
# ---------------train loss---------------
# Epoch: 46/300, loss_D_A: 0.195, loss_D_B: 0.205, loss_G: 11.170
# Epoch: 46/300, loss_gan: 0.863, loss_cyc: 10.295, loss_dep: 0.012
# --------------- test loss---------------
# Epoch: 46/300, loss_D_A: 0.220, loss_D_B: 0.425, loss_G: 11.552
# Epoch: 46/300, loss_gan: 1.063, loss_cyc: 10.482, loss_dep: 0.007
# ****************************************
# trained epoch in 1.6858 seconds
# ---------------train loss---------------
# Epoch: 47/300, loss_D_A: 0.179, loss_D_B: 0.187, loss_G: 10.973
# Epoch: 47/300, loss_gan: 0.884, loss_cyc: 10.079, loss_dep: 0.011
# --------------- test loss---------------
# Epoch: 47/300, loss_D_A: 0.316, loss_D_B: 0.170, loss_G: 11.039
# Epoch: 47/300, loss_gan: 0.632, loss_cyc: 10.401, loss_dep: 0.006
# ****************************************
# trained epoch in 1.6916 seconds
# ---------------train loss---------------
# Epoch: 48/300, loss_D_A: 0.227, loss_D_B: 0.194, loss_G: 10.883
# Epoch: 48/300, loss_gan: 0.806, loss_cyc: 10.067, loss_dep: 0.010
# --------------- test loss---------------
# Epoch: 48/300, loss_D_A: 0.221, loss_D_B: 0.149, loss_G: 10.848
# Epoch: 48/300, loss_gan: 0.728, loss_cyc: 10.114, loss_dep: 0.006
# ****************************************
# trained epoch in 1.6889 seconds
# ---------------train loss---------------
# Epoch: 49/300, loss_D_A: 0.219, loss_D_B: 0.218, loss_G: 10.936
# Epoch: 49/300, loss_gan: 0.826, loss_cyc: 10.099, loss_dep: 0.011
# --------------- test loss---------------
# Epoch: 49/300, loss_D_A: 0.162, loss_D_B: 0.136, loss_G: 10.637
# Epoch: 49/300, loss_gan: 0.823, loss_cyc: 9.808, loss_dep: 0.007
# ****************************************
# trained epoch in 1.6877 seconds
# ---------------train loss---------------
# Epoch: 50/300, loss_D_A: 0.193, loss_D_B: 0.184, loss_G: 10.919
# Epoch: 50/300, loss_gan: 0.799, loss_cyc: 10.110, loss_dep: 0.010
# --------------- test loss---------------
# Epoch: 50/300, loss_D_A: 0.270, loss_D_B: 0.154, loss_G: 11.067
# Epoch: 50/300, loss_gan: 1.097, loss_cyc: 9.964, loss_dep: 0.006
# ****************************************
# trained epoch in 1.6911 seconds
# ---------------train loss---------------
# Epoch: 51/300, loss_D_A: 0.199, loss_D_B: 0.189, loss_G: 10.916
# Epoch: 51/300, loss_gan: 0.856, loss_cyc: 10.050, loss_dep: 0.010
# --------------- test loss---------------
# Epoch: 51/300, loss_D_A: 0.287, loss_D_B: 0.200, loss_G: 10.702
# Epoch: 51/300, loss_gan: 0.769, loss_cyc: 9.928, loss_dep: 0.005
# ****************************************
# trained epoch in 1.6892 seconds
# ---------------train loss---------------
# Epoch: 52/300, loss_D_A: 0.198, loss_D_B: 0.187, loss_G: 10.621
# Epoch: 52/300, loss_gan: 0.742, loss_cyc: 9.871, loss_dep: 0.008
# --------------- test loss---------------
# Epoch: 52/300, loss_D_A: 0.242, loss_D_B: 0.142, loss_G: 10.784
# Epoch: 52/300, loss_gan: 0.799, loss_cyc: 9.980, loss_dep: 0.005
# ****************************************
# trained epoch in 1.6887 seconds
# ---------------train loss---------------
# Epoch: 53/300, loss_D_A: 0.202, loss_D_B: 0.197, loss_G: 10.971
# Epoch: 53/300, loss_gan: 0.922, loss_cyc: 10.041, loss_dep: 0.008
# --------------- test loss---------------
# Epoch: 53/300, loss_D_A: 0.354, loss_D_B: 0.278, loss_G: 11.635
# Epoch: 53/300, loss_gan: 1.543, loss_cyc: 10.087, loss_dep: 0.005
# ****************************************
# trained epoch in 1.6896 seconds
# ---------------train loss---------------
# Epoch: 54/300, loss_D_A: 0.185, loss_D_B: 0.174, loss_G: 10.826
# Epoch: 54/300, loss_gan: 0.926, loss_cyc: 9.892, loss_dep: 0.008
# --------------- test loss---------------
# Epoch: 54/300, loss_D_A: 0.225, loss_D_B: 0.170, loss_G: 10.738
# Epoch: 54/300, loss_gan: 0.637, loss_cyc: 10.096, loss_dep: 0.005
# ****************************************
# trained epoch in 1.6886 seconds
# ---------------train loss---------------
# Epoch: 55/300, loss_D_A: 0.225, loss_D_B: 0.231, loss_G: 10.749
# Epoch: 55/300, loss_gan: 0.829, loss_cyc: 9.912, loss_dep: 0.008
# --------------- test loss---------------
# Epoch: 55/300, loss_D_A: 0.189, loss_D_B: 0.188, loss_G: 10.145
# Epoch: 55/300, loss_gan: 0.568, loss_cyc: 9.572, loss_dep: 0.005
# ****************************************
# trained epoch in 1.6889 seconds
# ---------------train loss---------------
# Epoch: 56/300, loss_D_A: 0.173, loss_D_B: 0.156, loss_G: 10.548
# Epoch: 56/300, loss_gan: 0.755, loss_cyc: 9.783, loss_dep: 0.009
# --------------- test loss---------------
# Epoch: 56/300, loss_D_A: 0.129, loss_D_B: 0.115, loss_G: 10.507
# Epoch: 56/300, loss_gan: 0.860, loss_cyc: 9.641, loss_dep: 0.006
# ****************************************
# trained epoch in 1.6922 seconds
# ---------------train loss---------------
# Epoch: 57/300, loss_D_A: 0.253, loss_D_B: 0.271, loss_G: 11.392
# Epoch: 57/300, loss_gan: 1.213, loss_cyc: 10.169, loss_dep: 0.010
# --------------- test loss---------------
# Epoch: 57/300, loss_D_A: 0.137, loss_D_B: 0.108, loss_G: 10.679
# Epoch: 57/300, loss_gan: 0.955, loss_cyc: 9.718, loss_dep: 0.006
# ****************************************
# trained epoch in 1.6901 seconds
# ---------------train loss---------------
# Epoch: 58/300, loss_D_A: 0.177, loss_D_B: 0.142, loss_G: 10.578
# Epoch: 58/300, loss_gan: 0.789, loss_cyc: 9.780, loss_dep: 0.009
# --------------- test loss---------------
# Epoch: 58/300, loss_D_A: 0.221, loss_D_B: 0.189, loss_G: 10.670
# Epoch: 58/300, loss_gan: 0.875, loss_cyc: 9.789, loss_dep: 0.006
# ****************************************
# trained epoch in 1.6880 seconds
# ---------------train loss---------------
# Epoch: 59/300, loss_D_A: 0.203, loss_D_B: 0.173, loss_G: 10.426
# Epoch: 59/300, loss_gan: 0.734, loss_cyc: 9.684, loss_dep: 0.008
# --------------- test loss---------------
# Epoch: 59/300, loss_D_A: 0.163, loss_D_B: 0.185, loss_G: 10.469
# Epoch: 59/300, loss_gan: 0.751, loss_cyc: 9.714, loss_dep: 0.004
# ****************************************
# trained epoch in 1.6856 seconds
# ---------------train loss---------------
# Epoch: 60/300, loss_D_A: 0.194, loss_D_B: 0.225, loss_G: 10.883
# Epoch: 60/300, loss_gan: 1.000, loss_cyc: 9.876, loss_dep: 0.007
# --------------- test loss---------------
# Epoch: 60/300, loss_D_A: 0.170, loss_D_B: 0.123, loss_G: 10.826
# Epoch: 60/300, loss_gan: 1.187, loss_cyc: 9.634, loss_dep: 0.005
# ****************************************
# trained epoch in 1.6884 seconds
# ---------------train loss---------------
# Epoch: 61/300, loss_D_A: 0.166, loss_D_B: 0.150, loss_G: 10.533
# Epoch: 61/300, loss_gan: 0.801, loss_cyc: 9.725, loss_dep: 0.007
# --------------- test loss---------------
# Epoch: 61/300, loss_D_A: 0.319, loss_D_B: 0.160, loss_G: 11.342
# Epoch: 61/300, loss_gan: 1.009, loss_cyc: 10.329, loss_dep: 0.005
# ****************************************
# trained epoch in 1.6873 seconds
# ---------------train loss---------------
# Epoch: 62/300, loss_D_A: 0.278, loss_D_B: 0.191, loss_G: 10.801
# Epoch: 62/300, loss_gan: 0.984, loss_cyc: 9.810, loss_dep: 0.007
# --------------- test loss---------------
# Epoch: 62/300, loss_D_A: 0.199, loss_D_B: 0.177, loss_G: 10.164
# Epoch: 62/300, loss_gan: 0.587, loss_cyc: 9.573, loss_dep: 0.004
# ****************************************
# trained epoch in 1.6873 seconds
# ---------------train loss---------------
# Epoch: 63/300, loss_D_A: 0.212, loss_D_B: 0.159, loss_G: 10.516
# Epoch: 63/300, loss_gan: 0.789, loss_cyc: 9.721, loss_dep: 0.006
# --------------- test loss---------------
# Epoch: 63/300, loss_D_A: 0.196, loss_D_B: 0.202, loss_G: 10.286
# Epoch: 63/300, loss_gan: 0.480, loss_cyc: 9.802, loss_dep: 0.004
# ****************************************
# trained epoch in 1.6844 seconds
# ---------------train loss---------------
# Epoch: 64/300, loss_D_A: 0.207, loss_D_B: 0.213, loss_G: 10.677
# Epoch: 64/300, loss_gan: 0.853, loss_cyc: 9.818, loss_dep: 0.007
# --------------- test loss---------------
# Epoch: 64/300, loss_D_A: 0.148, loss_D_B: 0.160, loss_G: 10.533
# Epoch: 64/300, loss_gan: 0.826, loss_cyc: 9.702, loss_dep: 0.005
# ****************************************
# trained epoch in 1.6857 seconds
# ---------------train loss---------------
# Epoch: 65/300, loss_D_A: 0.204, loss_D_B: 0.140, loss_G: 10.559
# Epoch: 65/300, loss_gan: 0.794, loss_cyc: 9.757, loss_dep: 0.007
# --------------- test loss---------------
# Epoch: 65/300, loss_D_A: 0.204, loss_D_B: 0.238, loss_G: 10.626
# Epoch: 65/300, loss_gan: 0.955, loss_cyc: 9.666, loss_dep: 0.005
# ****************************************
# trained epoch in 1.6853 seconds
# ---------------train loss---------------
# Epoch: 66/300, loss_D_A: 0.206, loss_D_B: 0.174, loss_G: 10.452
# Epoch: 66/300, loss_gan: 0.877, loss_cyc: 9.568, loss_dep: 0.007
# --------------- test loss---------------
# Epoch: 66/300, loss_D_A: 0.165, loss_D_B: 0.162, loss_G: 10.900
# Epoch: 66/300, loss_gan: 0.878, loss_cyc: 10.018, loss_dep: 0.004
# ****************************************
# trained epoch in 1.6885 seconds
# ---------------train loss---------------
# Epoch: 67/300, loss_D_A: 0.227, loss_D_B: 0.241, loss_G: 10.773
# Epoch: 67/300, loss_gan: 0.935, loss_cyc: 9.831, loss_dep: 0.007
# --------------- test loss---------------
# Epoch: 67/300, loss_D_A: 0.168, loss_D_B: 0.125, loss_G: 10.354
# Epoch: 67/300, loss_gan: 0.820, loss_cyc: 9.530, loss_dep: 0.004
# ****************************************
# trained epoch in 1.6835 seconds
# ---------------train loss---------------
# Epoch: 68/300, loss_D_A: 0.205, loss_D_B: 0.135, loss_G: 10.380
# Epoch: 68/300, loss_gan: 0.795, loss_cyc: 9.579, loss_dep: 0.006
# --------------- test loss---------------
# Epoch: 68/300, loss_D_A: 0.189, loss_D_B: 0.170, loss_G: 10.632
# Epoch: 68/300, loss_gan: 1.019, loss_cyc: 9.609, loss_dep: 0.004
# ****************************************
# trained epoch in 1.6843 seconds
# ---------------train loss---------------
# Epoch: 69/300, loss_D_A: 0.199, loss_D_B: 0.208, loss_G: 10.693
# Epoch: 69/300, loss_gan: 0.972, loss_cyc: 9.715, loss_dep: 0.006
# --------------- test loss---------------
# Epoch: 69/300, loss_D_A: 0.155, loss_D_B: 0.135, loss_G: 10.416
# Epoch: 69/300, loss_gan: 0.874, loss_cyc: 9.538, loss_dep: 0.004
# ****************************************
# trained epoch in 1.6857 seconds
# ---------------train loss---------------
# Epoch: 70/300, loss_D_A: 0.212, loss_D_B: 0.133, loss_G: 10.485
# Epoch: 70/300, loss_gan: 0.851, loss_cyc: 9.628, loss_dep: 0.006
# --------------- test loss---------------
# Epoch: 70/300, loss_D_A: 0.169, loss_D_B: 0.226, loss_G: 10.143
# Epoch: 70/300, loss_gan: 0.531, loss_cyc: 9.607, loss_dep: 0.004
# ****************************************
# trained epoch in 1.6830 seconds
# ---------------train loss---------------
# Epoch: 71/300, loss_D_A: 0.204, loss_D_B: 0.196, loss_G: 10.472
# Epoch: 71/300, loss_gan: 0.839, loss_cyc: 9.628, loss_dep: 0.006
# --------------- test loss---------------
# Epoch: 71/300, loss_D_A: 0.163, loss_D_B: 0.130, loss_G: 10.358
# Epoch: 71/300, loss_gan: 1.015, loss_cyc: 9.338, loss_dep: 0.004
# ****************************************
# trained epoch in 1.6856 seconds
# ---------------train loss---------------
# Epoch: 72/300, loss_D_A: 0.199, loss_D_B: 0.160, loss_G: 10.503
# Epoch: 72/300, loss_gan: 0.866, loss_cyc: 9.631, loss_dep: 0.006
# --------------- test loss---------------
# Epoch: 72/300, loss_D_A: 0.219, loss_D_B: 0.198, loss_G: 10.760
# Epoch: 72/300, loss_gan: 1.153, loss_cyc: 9.602, loss_dep: 0.005
# ****************************************
# trained epoch in 1.6824 seconds
# ---------------train loss---------------
# Epoch: 73/300, loss_D_A: 0.194, loss_D_B: 0.141, loss_G: 10.593
# Epoch: 73/300, loss_gan: 0.957, loss_cyc: 9.630, loss_dep: 0.007
# --------------- test loss---------------
# Epoch: 73/300, loss_D_A: 0.178, loss_D_B: 0.123, loss_G: 10.714
# Epoch: 73/300, loss_gan: 1.090, loss_cyc: 9.621, loss_dep: 0.004
# ****************************************
# trained epoch in 1.6844 seconds
# ---------------train loss---------------
# Epoch: 74/300, loss_D_A: 0.209, loss_D_B: 0.239, loss_G: 10.745
# Epoch: 74/300, loss_gan: 1.076, loss_cyc: 9.662, loss_dep: 0.007
# --------------- test loss---------------
# Epoch: 74/300, loss_D_A: 0.147, loss_D_B: 0.103, loss_G: 10.398
# Epoch: 74/300, loss_gan: 0.994, loss_cyc: 9.400, loss_dep: 0.004
# ****************************************
# trained epoch in 1.6815 seconds
# ---------------train loss---------------
# Epoch: 75/300, loss_D_A: 0.198, loss_D_B: 0.143, loss_G: 10.317
# Epoch: 75/300, loss_gan: 0.764, loss_cyc: 9.546, loss_dep: 0.007
# --------------- test loss---------------
# Epoch: 75/300, loss_D_A: 0.189, loss_D_B: 0.130, loss_G: 10.311
# Epoch: 75/300, loss_gan: 0.957, loss_cyc: 9.351, loss_dep: 0.004
# ****************************************
# trained epoch in 1.6814 seconds
# ---------------train loss---------------
# Epoch: 76/300, loss_D_A: 0.254, loss_D_B: 0.128, loss_G: 10.501
# Epoch: 76/300, loss_gan: 0.929, loss_cyc: 9.566, loss_dep: 0.006
# --------------- test loss---------------
# Epoch: 76/300, loss_D_A: 0.233, loss_D_B: 0.208, loss_G: 11.085
# Epoch: 76/300, loss_gan: 1.288, loss_cyc: 9.792, loss_dep: 0.004
# ****************************************
# trained epoch in 1.6814 seconds
# ---------------train loss---------------
# Epoch: 77/300, loss_D_A: 0.168, loss_D_B: 0.158, loss_G: 10.429
# Epoch: 77/300, loss_gan: 0.958, loss_cyc: 9.465, loss_dep: 0.006
# --------------- test loss---------------
# Epoch: 77/300, loss_D_A: 0.194, loss_D_B: 0.112, loss_G: 10.124
# Epoch: 77/300, loss_gan: 0.796, loss_cyc: 9.324, loss_dep: 0.004
# ****************************************
# trained epoch in 1.6791 seconds
# ---------------train loss---------------
# Epoch: 78/300, loss_D_A: 0.202, loss_D_B: 0.130, loss_G: 10.391
# Epoch: 78/300, loss_gan: 0.841, loss_cyc: 9.545, loss_dep: 0.006
# --------------- test loss---------------
# Epoch: 78/300, loss_D_A: 0.245, loss_D_B: 0.131, loss_G: 10.244
# Epoch: 78/300, loss_gan: 0.758, loss_cyc: 9.483, loss_dep: 0.004
# ****************************************
# trained epoch in 1.6809 seconds
# ---------------train loss---------------
# Epoch: 79/300, loss_D_A: 0.196, loss_D_B: 0.157, loss_G: 10.469
# Epoch: 79/300, loss_gan: 0.919, loss_cyc: 9.545, loss_dep: 0.005
# --------------- test loss---------------
# Epoch: 79/300, loss_D_A: 0.367, loss_D_B: 0.098, loss_G: 10.474
# Epoch: 79/300, loss_gan: 0.935, loss_cyc: 9.536, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6808 seconds
# ---------------train loss---------------
# Epoch: 80/300, loss_D_A: 0.201, loss_D_B: 0.188, loss_G: 10.603
# Epoch: 80/300, loss_gan: 1.055, loss_cyc: 9.543, loss_dep: 0.005
# --------------- test loss---------------
# Epoch: 80/300, loss_D_A: 0.193, loss_D_B: 0.121, loss_G: 9.984
# Epoch: 80/300, loss_gan: 0.557, loss_cyc: 9.424, loss_dep: 0.004
# ****************************************
# trained epoch in 1.6797 seconds
# ---------------train loss---------------
# Epoch: 81/300, loss_D_A: 0.223, loss_D_B: 0.125, loss_G: 10.494
# Epoch: 81/300, loss_gan: 0.901, loss_cyc: 9.588, loss_dep: 0.005
# --------------- test loss---------------
# Epoch: 81/300, loss_D_A: 0.393, loss_D_B: 0.113, loss_G: 10.196
# Epoch: 81/300, loss_gan: 0.603, loss_cyc: 9.589, loss_dep: 0.004
# ****************************************
# trained epoch in 1.6795 seconds
# ---------------train loss---------------
# Epoch: 82/300, loss_D_A: 0.210, loss_D_B: 0.127, loss_G: 10.414
# Epoch: 82/300, loss_gan: 0.913, loss_cyc: 9.496, loss_dep: 0.005
# --------------- test loss---------------
# Epoch: 82/300, loss_D_A: 0.193, loss_D_B: 0.282, loss_G: 10.324
# Epoch: 82/300, loss_gan: 0.788, loss_cyc: 9.532, loss_dep: 0.004
# ****************************************
# trained epoch in 1.6810 seconds
# ---------------train loss---------------
# Epoch: 83/300, loss_D_A: 0.179, loss_D_B: 0.176, loss_G: 10.319
# Epoch: 83/300, loss_gan: 0.925, loss_cyc: 9.389, loss_dep: 0.005
# --------------- test loss---------------
# Epoch: 83/300, loss_D_A: 0.177, loss_D_B: 0.156, loss_G: 10.439
# Epoch: 83/300, loss_gan: 0.912, loss_cyc: 9.522, loss_dep: 0.004
# ****************************************
# trained epoch in 1.6783 seconds
# ---------------train loss---------------
# Epoch: 84/300, loss_D_A: 0.286, loss_D_B: 0.164, loss_G: 10.397
# Epoch: 84/300, loss_gan: 0.979, loss_cyc: 9.413, loss_dep: 0.006
# --------------- test loss---------------
# Epoch: 84/300, loss_D_A: 0.164, loss_D_B: 0.106, loss_G: 9.955
# Epoch: 84/300, loss_gan: 0.799, loss_cyc: 9.152, loss_dep: 0.004
# ****************************************
# trained epoch in 1.6810 seconds
# ---------------train loss---------------
# Epoch: 85/300, loss_D_A: 0.175, loss_D_B: 0.112, loss_G: 10.145
# Epoch: 85/300, loss_gan: 0.882, loss_cyc: 9.259, loss_dep: 0.005
# --------------- test loss---------------
# Epoch: 85/300, loss_D_A: 0.155, loss_D_B: 0.128, loss_G: 10.452
# Epoch: 85/300, loss_gan: 0.881, loss_cyc: 9.568, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6766 seconds
# ---------------train loss---------------
# Epoch: 86/300, loss_D_A: 0.169, loss_D_B: 0.124, loss_G: 10.400
# Epoch: 86/300, loss_gan: 0.983, loss_cyc: 9.413, loss_dep: 0.004
# --------------- test loss---------------
# Epoch: 86/300, loss_D_A: 0.180, loss_D_B: 0.221, loss_G: 10.802
# Epoch: 86/300, loss_gan: 1.086, loss_cyc: 9.713, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6789 seconds
# ---------------train loss---------------
# Epoch: 87/300, loss_D_A: 0.188, loss_D_B: 0.135, loss_G: 10.380
# Epoch: 87/300, loss_gan: 1.003, loss_cyc: 9.372, loss_dep: 0.005
# --------------- test loss---------------
# Epoch: 87/300, loss_D_A: 0.181, loss_D_B: 0.145, loss_G: 10.218
# Epoch: 87/300, loss_gan: 0.851, loss_cyc: 9.364, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6781 seconds
# ---------------train loss---------------
# Epoch: 88/300, loss_D_A: 0.227, loss_D_B: 0.201, loss_G: 10.460
# Epoch: 88/300, loss_gan: 1.071, loss_cyc: 9.385, loss_dep: 0.004
# --------------- test loss---------------
# Epoch: 88/300, loss_D_A: 0.176, loss_D_B: 0.087, loss_G: 10.107
# Epoch: 88/300, loss_gan: 0.897, loss_cyc: 9.207, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6792 seconds
# ---------------train loss---------------
# Epoch: 89/300, loss_D_A: 0.185, loss_D_B: 0.124, loss_G: 10.191
# Epoch: 89/300, loss_gan: 0.887, loss_cyc: 9.300, loss_dep: 0.004
# --------------- test loss---------------
# Epoch: 89/300, loss_D_A: 0.191, loss_D_B: 0.147, loss_G: 10.259
# Epoch: 89/300, loss_gan: 0.980, loss_cyc: 9.275, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6777 seconds
# ---------------train loss---------------
# Epoch: 90/300, loss_D_A: 0.275, loss_D_B: 0.181, loss_G: 10.532
# Epoch: 90/300, loss_gan: 1.073, loss_cyc: 9.454, loss_dep: 0.006
# --------------- test loss---------------
# Epoch: 90/300, loss_D_A: 0.266, loss_D_B: 0.093, loss_G: 9.934
# Epoch: 90/300, loss_gan: 0.687, loss_cyc: 9.242, loss_dep: 0.004
# ****************************************
# trained epoch in 1.6804 seconds
# ---------------train loss---------------
# Epoch: 91/300, loss_D_A: 0.173, loss_D_B: 0.106, loss_G: 10.054
# Epoch: 91/300, loss_gan: 0.900, loss_cyc: 9.148, loss_dep: 0.005
# --------------- test loss---------------
# Epoch: 91/300, loss_D_A: 0.193, loss_D_B: 0.125, loss_G: 10.263
# Epoch: 91/300, loss_gan: 0.987, loss_cyc: 9.272, loss_dep: 0.004
# ****************************************
# trained epoch in 1.6772 seconds
# ---------------train loss---------------
# Epoch: 92/300, loss_D_A: 0.187, loss_D_B: 0.130, loss_G: 10.282
# Epoch: 92/300, loss_gan: 0.988, loss_cyc: 9.289, loss_dep: 0.005
# --------------- test loss---------------
# Epoch: 92/300, loss_D_A: 0.177, loss_D_B: 0.100, loss_G: 10.208
# Epoch: 92/300, loss_gan: 0.970, loss_cyc: 9.235, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6790 seconds
# ---------------train loss---------------
# Epoch: 93/300, loss_D_A: 0.212, loss_D_B: 0.116, loss_G: 10.275
# Epoch: 93/300, loss_gan: 0.921, loss_cyc: 9.350, loss_dep: 0.004
# --------------- test loss---------------
# Epoch: 93/300, loss_D_A: 0.191, loss_D_B: 0.125, loss_G: 10.706
# Epoch: 93/300, loss_gan: 1.281, loss_cyc: 9.422, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6809 seconds
# ---------------train loss---------------
# Epoch: 94/300, loss_D_A: 0.178, loss_D_B: 0.139, loss_G: 10.341
# Epoch: 94/300, loss_gan: 1.018, loss_cyc: 9.319, loss_dep: 0.004
# --------------- test loss---------------
# Epoch: 94/300, loss_D_A: 0.177, loss_D_B: 0.139, loss_G: 10.133
# Epoch: 94/300, loss_gan: 0.764, loss_cyc: 9.366, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6777 seconds
# ---------------train loss---------------
# Epoch: 95/300, loss_D_A: 0.236, loss_D_B: 0.117, loss_G: 10.400
# Epoch: 95/300, loss_gan: 1.014, loss_cyc: 9.381, loss_dep: 0.005
# --------------- test loss---------------
# Epoch: 95/300, loss_D_A: 0.169, loss_D_B: 0.105, loss_G: 10.115
# Epoch: 95/300, loss_gan: 0.979, loss_cyc: 9.133, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6787 seconds
# ---------------train loss---------------
# Epoch: 96/300, loss_D_A: 0.197, loss_D_B: 0.127, loss_G: 10.194
# Epoch: 96/300, loss_gan: 0.916, loss_cyc: 9.274, loss_dep: 0.004
# --------------- test loss---------------
# Epoch: 96/300, loss_D_A: 0.284, loss_D_B: 0.277, loss_G: 10.885
# Epoch: 96/300, loss_gan: 1.712, loss_cyc: 9.170, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6790 seconds
# ---------------train loss---------------
# Epoch: 97/300, loss_D_A: 0.198, loss_D_B: 0.161, loss_G: 10.348
# Epoch: 97/300, loss_gan: 1.102, loss_cyc: 9.242, loss_dep: 0.004
# --------------- test loss---------------
# Epoch: 97/300, loss_D_A: 0.336, loss_D_B: 0.097, loss_G: 9.827
# Epoch: 97/300, loss_gan: 0.681, loss_cyc: 9.142, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6749 seconds
# ---------------train loss---------------
# Epoch: 98/300, loss_D_A: 0.233, loss_D_B: 0.121, loss_G: 10.107
# Epoch: 98/300, loss_gan: 0.968, loss_cyc: 9.135, loss_dep: 0.004
# --------------- test loss---------------
# Epoch: 98/300, loss_D_A: 0.223, loss_D_B: 0.113, loss_G: 10.113
# Epoch: 98/300, loss_gan: 0.826, loss_cyc: 9.284, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6797 seconds
# ---------------train loss---------------
# Epoch: 99/300, loss_D_A: 0.189, loss_D_B: 0.111, loss_G: 10.165
# Epoch: 99/300, loss_gan: 0.933, loss_cyc: 9.228, loss_dep: 0.004
# --------------- test loss---------------
# Epoch: 99/300, loss_D_A: 0.232, loss_D_B: 0.105, loss_G: 10.102
# Epoch: 99/300, loss_gan: 0.867, loss_cyc: 9.233, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6767 seconds
# ---------------train loss---------------
# Epoch: 100/300, loss_D_A: 0.219, loss_D_B: 0.161, loss_G: 10.245
# Epoch: 100/300, loss_gan: 0.998, loss_cyc: 9.244, loss_dep: 0.004
# --------------- test loss---------------
# Epoch: 100/300, loss_D_A: 0.193, loss_D_B: 0.108, loss_G: 9.916
# Epoch: 100/300, loss_gan: 0.828, loss_cyc: 9.085, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6756 seconds
# ---------------train loss---------------
# Epoch: 101/300, loss_D_A: 0.193, loss_D_B: 0.102, loss_G: 10.069
# Epoch: 101/300, loss_gan: 0.899, loss_cyc: 9.166, loss_dep: 0.004
# --------------- test loss---------------
# Epoch: 101/300, loss_D_A: 0.238, loss_D_B: 0.135, loss_G: 10.375
# Epoch: 101/300, loss_gan: 1.092, loss_cyc: 9.280, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6785 seconds
# ---------------train loss---------------
# Epoch: 102/300, loss_D_A: 0.285, loss_D_B: 0.162, loss_G: 10.580
# Epoch: 102/300, loss_gan: 1.107, loss_cyc: 9.468, loss_dep: 0.006
# --------------- test loss---------------
# Epoch: 102/300, loss_D_A: 0.167, loss_D_B: 0.092, loss_G: 10.033
# Epoch: 102/300, loss_gan: 1.018, loss_cyc: 9.011, loss_dep: 0.004
# ****************************************
# trained epoch in 1.6758 seconds
# ---------------train loss---------------
# Epoch: 103/300, loss_D_A: 0.190, loss_D_B: 0.104, loss_G: 10.094
# Epoch: 103/300, loss_gan: 0.940, loss_cyc: 9.149, loss_dep: 0.005
# --------------- test loss---------------
# Epoch: 103/300, loss_D_A: 0.192, loss_D_B: 0.104, loss_G: 10.009
# Epoch: 103/300, loss_gan: 0.867, loss_cyc: 9.139, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6749 seconds
# ---------------train loss---------------
# Epoch: 104/300, loss_D_A: 0.180, loss_D_B: 0.109, loss_G: 10.073
# Epoch: 104/300, loss_gan: 0.904, loss_cyc: 9.165, loss_dep: 0.004
# --------------- test loss---------------
# Epoch: 104/300, loss_D_A: 0.181, loss_D_B: 0.101, loss_G: 9.996
# Epoch: 104/300, loss_gan: 0.864, loss_cyc: 9.129, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6766 seconds
# ---------------train loss---------------
# Epoch: 105/300, loss_D_A: 0.272, loss_D_B: 0.139, loss_G: 10.200
# Epoch: 105/300, loss_gan: 1.026, loss_cyc: 9.170, loss_dep: 0.004
# --------------- test loss---------------
# Epoch: 105/300, loss_D_A: 0.178, loss_D_B: 0.106, loss_G: 10.143
# Epoch: 105/300, loss_gan: 1.181, loss_cyc: 8.959, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6731 seconds
# ---------------train loss---------------
# Epoch: 106/300, loss_D_A: 0.173, loss_D_B: 0.120, loss_G: 9.936
# Epoch: 106/300, loss_gan: 0.933, loss_cyc: 9.000, loss_dep: 0.004
# --------------- test loss---------------
# Epoch: 106/300, loss_D_A: 0.177, loss_D_B: 0.105, loss_G: 10.066
# Epoch: 106/300, loss_gan: 1.025, loss_cyc: 9.038, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6746 seconds
# ---------------train loss---------------
# Epoch: 107/300, loss_D_A: 0.203, loss_D_B: 0.144, loss_G: 9.987
# Epoch: 107/300, loss_gan: 0.927, loss_cyc: 9.057, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 107/300, loss_D_A: 0.207, loss_D_B: 0.143, loss_G: 10.523
# Epoch: 107/300, loss_gan: 1.102, loss_cyc: 9.417, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6722 seconds
# ---------------train loss---------------
# Epoch: 108/300, loss_D_A: 0.196, loss_D_B: 0.103, loss_G: 9.968
# Epoch: 108/300, loss_gan: 0.947, loss_cyc: 9.017, loss_dep: 0.004
# --------------- test loss---------------
# Epoch: 108/300, loss_D_A: 0.209, loss_D_B: 0.097, loss_G: 10.130
# Epoch: 108/300, loss_gan: 0.975, loss_cyc: 9.152, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6762 seconds
# ---------------train loss---------------
# Epoch: 109/300, loss_D_A: 0.207, loss_D_B: 0.114, loss_G: 10.005
# Epoch: 109/300, loss_gan: 0.976, loss_cyc: 9.026, loss_dep: 0.004
# --------------- test loss---------------
# Epoch: 109/300, loss_D_A: 0.491, loss_D_B: 0.106, loss_G: 9.973
# Epoch: 109/300, loss_gan: 0.788, loss_cyc: 9.182, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6771 seconds
# ---------------train loss---------------
# Epoch: 110/300, loss_D_A: 0.279, loss_D_B: 0.109, loss_G: 10.131
# Epoch: 110/300, loss_gan: 1.079, loss_cyc: 9.049, loss_dep: 0.004
# --------------- test loss---------------
# Epoch: 110/300, loss_D_A: 0.187, loss_D_B: 0.089, loss_G: 9.771
# Epoch: 110/300, loss_gan: 0.853, loss_cyc: 8.915, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6726 seconds
# ---------------train loss---------------
# Epoch: 111/300, loss_D_A: 0.182, loss_D_B: 0.139, loss_G: 9.924
# Epoch: 111/300, loss_gan: 0.937, loss_cyc: 8.983, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 111/300, loss_D_A: 0.186, loss_D_B: 0.294, loss_G: 10.803
# Epoch: 111/300, loss_gan: 1.883, loss_cyc: 8.917, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6708 seconds
# ---------------train loss---------------
# Epoch: 112/300, loss_D_A: 0.190, loss_D_B: 0.148, loss_G: 9.967
# Epoch: 112/300, loss_gan: 1.041, loss_cyc: 8.923, loss_dep: 0.004
# --------------- test loss---------------
# Epoch: 112/300, loss_D_A: 0.233, loss_D_B: 0.127, loss_G: 9.374
# Epoch: 112/300, loss_gan: 0.566, loss_cyc: 8.806, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6757 seconds
# ---------------train loss---------------
# Epoch: 113/300, loss_D_A: 0.221, loss_D_B: 0.104, loss_G: 9.885
# Epoch: 113/300, loss_gan: 0.969, loss_cyc: 8.912, loss_dep: 0.004
# --------------- test loss---------------
# Epoch: 113/300, loss_D_A: 0.212, loss_D_B: 0.097, loss_G: 9.874
# Epoch: 113/300, loss_gan: 0.953, loss_cyc: 8.918, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6769 seconds
# ---------------train loss---------------
# Epoch: 114/300, loss_D_A: 0.192, loss_D_B: 0.104, loss_G: 9.981
# Epoch: 114/300, loss_gan: 0.989, loss_cyc: 8.989, loss_dep: 0.004
# --------------- test loss---------------
# Epoch: 114/300, loss_D_A: 0.308, loss_D_B: 0.110, loss_G: 9.517
# Epoch: 114/300, loss_gan: 0.515, loss_cyc: 8.999, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6780 seconds
# ---------------train loss---------------
# Epoch: 115/300, loss_D_A: 0.213, loss_D_B: 0.116, loss_G: 9.839
# Epoch: 115/300, loss_gan: 0.929, loss_cyc: 8.907, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 115/300, loss_D_A: 0.224, loss_D_B: 0.206, loss_G: 10.377
# Epoch: 115/300, loss_gan: 1.462, loss_cyc: 8.912, loss_dep: 0.003
# ****************************************
# trained epoch in 1.6754 seconds
# ---------------train loss---------------
# Epoch: 116/300, loss_D_A: 0.233, loss_D_B: 0.163, loss_G: 9.982
# Epoch: 116/300, loss_gan: 1.075, loss_cyc: 8.904, loss_dep: 0.003
# --------------- test loss---------------
# ...
# --------------- test loss---------------
# Epoch: 262/300, loss_D_A: 0.155, loss_D_B: 0.181, loss_G: 8.747
# Epoch: 262/300, loss_gan: 0.871, loss_cyc: 7.874, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6700 seconds
# ---------------train loss---------------
# Epoch: 263/300, loss_D_A: 0.134, loss_D_B: 0.160, loss_G: 8.359
# Epoch: 263/300, loss_gan: 0.819, loss_cyc: 7.538, loss_dep: 0.002
# --------------- test loss---------------
# Epoch: 263/300, loss_D_A: 0.172, loss_D_B: 0.187, loss_G: 8.698
# Epoch: 263/300, loss_gan: 0.831, loss_cyc: 7.865, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6688 seconds
# ---------------train loss---------------
# Epoch: 264/300, loss_D_A: 0.139, loss_D_B: 0.174, loss_G: 8.304
# Epoch: 264/300, loss_gan: 0.781, loss_cyc: 7.520, loss_dep: 0.002
# --------------- test loss---------------
# Epoch: 264/300, loss_D_A: 0.176, loss_D_B: 0.183, loss_G: 8.682
# Epoch: 264/300, loss_gan: 0.837, loss_cyc: 7.843, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6731 seconds
# ---------------train loss---------------
# Epoch: 265/300, loss_D_A: 0.142, loss_D_B: 0.151, loss_G: 8.321
# Epoch: 265/300, loss_gan: 0.815, loss_cyc: 7.504, loss_dep: 0.002
# --------------- test loss---------------
# Epoch: 265/300, loss_D_A: 0.168, loss_D_B: 0.168, loss_G: 8.715
# Epoch: 265/300, loss_gan: 0.887, loss_cyc: 7.826, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6731 seconds
# ---------------train loss---------------
# Epoch: 266/300, loss_D_A: 0.131, loss_D_B: 0.146, loss_G: 8.364
# Epoch: 266/300, loss_gan: 0.845, loss_cyc: 7.516, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 266/300, loss_D_A: 0.186, loss_D_B: 0.162, loss_G: 8.710
# Epoch: 266/300, loss_gan: 0.860, loss_cyc: 7.848, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6751 seconds
# ---------------train loss---------------
# Epoch: 267/300, loss_D_A: 0.146, loss_D_B: 0.141, loss_G: 8.353
# Epoch: 267/300, loss_gan: 0.836, loss_cyc: 7.515, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 267/300, loss_D_A: 0.169, loss_D_B: 0.171, loss_G: 8.718
# Epoch: 267/300, loss_gan: 0.885, loss_cyc: 7.831, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6711 seconds
# ---------------train loss---------------
# Epoch: 268/300, loss_D_A: 0.134, loss_D_B: 0.155, loss_G: 8.348
# Epoch: 268/300, loss_gan: 0.835, loss_cyc: 7.510, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 268/300, loss_D_A: 0.187, loss_D_B: 0.179, loss_G: 8.689
# Epoch: 268/300, loss_gan: 0.854, loss_cyc: 7.833, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6720 seconds
# ---------------train loss---------------
# Epoch: 269/300, loss_D_A: 0.145, loss_D_B: 0.144, loss_G: 8.352
# Epoch: 269/300, loss_gan: 0.832, loss_cyc: 7.517, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 269/300, loss_D_A: 0.173, loss_D_B: 0.151, loss_G: 8.666
# Epoch: 269/300, loss_gan: 0.825, loss_cyc: 7.839, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6727 seconds
# ---------------train loss---------------
# Epoch: 270/300, loss_D_A: 0.136, loss_D_B: 0.144, loss_G: 8.344
# Epoch: 270/300, loss_gan: 0.837, loss_cyc: 7.505, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 270/300, loss_D_A: 0.170, loss_D_B: 0.173, loss_G: 8.645
# Epoch: 270/300, loss_gan: 0.819, loss_cyc: 7.824, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6735 seconds
# ---------------train loss---------------
# Epoch: 271/300, loss_D_A: 0.131, loss_D_B: 0.148, loss_G: 8.352
# Epoch: 271/300, loss_gan: 0.839, loss_cyc: 7.511, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 271/300, loss_D_A: 0.170, loss_D_B: 0.172, loss_G: 8.668
# Epoch: 271/300, loss_gan: 0.853, loss_cyc: 7.813, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6724 seconds
# ---------------train loss---------------
# Epoch: 272/300, loss_D_A: 0.138, loss_D_B: 0.153, loss_G: 8.304
# Epoch: 272/300, loss_gan: 0.823, loss_cyc: 7.478, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 272/300, loss_D_A: 0.183, loss_D_B: 0.186, loss_G: 8.598
# Epoch: 272/300, loss_gan: 0.777, loss_cyc: 7.820, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6701 seconds
# ---------------train loss---------------
# Epoch: 273/300, loss_D_A: 0.133, loss_D_B: 0.160, loss_G: 8.279
# Epoch: 273/300, loss_gan: 0.813, loss_cyc: 7.464, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 273/300, loss_D_A: 0.165, loss_D_B: 0.182, loss_G: 8.714
# Epoch: 273/300, loss_gan: 0.912, loss_cyc: 7.800, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6690 seconds
# ---------------train loss---------------
# Epoch: 274/300, loss_D_A: 0.130, loss_D_B: 0.146, loss_G: 8.299
# Epoch: 274/300, loss_gan: 0.851, loss_cyc: 7.446, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 274/300, loss_D_A: 0.178, loss_D_B: 0.171, loss_G: 8.626
# Epoch: 274/300, loss_gan: 0.826, loss_cyc: 7.797, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6694 seconds
# ---------------train loss---------------
# Epoch: 275/300, loss_D_A: 0.132, loss_D_B: 0.149, loss_G: 8.298
# Epoch: 275/300, loss_gan: 0.841, loss_cyc: 7.454, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 275/300, loss_D_A: 0.153, loss_D_B: 0.178, loss_G: 8.716
# Epoch: 275/300, loss_gan: 0.923, loss_cyc: 7.791, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6739 seconds
# ---------------train loss---------------
# Epoch: 276/300, loss_D_A: 0.121, loss_D_B: 0.150, loss_G: 8.332
# Epoch: 276/300, loss_gan: 0.864, loss_cyc: 7.466, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 276/300, loss_D_A: 0.155, loss_D_B: 0.176, loss_G: 8.723
# Epoch: 276/300, loss_gan: 0.923, loss_cyc: 7.798, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6715 seconds
# ---------------train loss---------------
# Epoch: 277/300, loss_D_A: 0.118, loss_D_B: 0.146, loss_G: 8.313
# Epoch: 277/300, loss_gan: 0.875, loss_cyc: 7.435, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 277/300, loss_D_A: 0.161, loss_D_B: 0.166, loss_G: 8.701
# Epoch: 277/300, loss_gan: 0.911, loss_cyc: 7.787, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6722 seconds
# ---------------train loss---------------
# Epoch: 278/300, loss_D_A: 0.126, loss_D_B: 0.140, loss_G: 8.302
# Epoch: 278/300, loss_gan: 0.864, loss_cyc: 7.435, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 278/300, loss_D_A: 0.165, loss_D_B: 0.163, loss_G: 8.713
# Epoch: 278/300, loss_gan: 0.908, loss_cyc: 7.803, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6693 seconds
# ---------------train loss---------------
# Epoch: 279/300, loss_D_A: 0.120, loss_D_B: 0.143, loss_G: 8.314
# Epoch: 279/300, loss_gan: 0.868, loss_cyc: 7.443, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 279/300, loss_D_A: 0.156, loss_D_B: 0.172, loss_G: 8.730
# Epoch: 279/300, loss_gan: 0.928, loss_cyc: 7.801, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6736 seconds
# ---------------train loss---------------
# Epoch: 280/300, loss_D_A: 0.117, loss_D_B: 0.147, loss_G: 8.305
# Epoch: 280/300, loss_gan: 0.871, loss_cyc: 7.431, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 280/300, loss_D_A: 0.158, loss_D_B: 0.176, loss_G: 8.680
# Epoch: 280/300, loss_gan: 0.882, loss_cyc: 7.796, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6744 seconds
# ---------------train loss---------------
# Epoch: 281/300, loss_D_A: 0.124, loss_D_B: 0.149, loss_G: 8.288
# Epoch: 281/300, loss_gan: 0.851, loss_cyc: 7.434, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 281/300, loss_D_A: 0.168, loss_D_B: 0.175, loss_G: 8.677
# Epoch: 281/300, loss_gan: 0.889, loss_cyc: 7.786, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6752 seconds
# ---------------train loss---------------
# Epoch: 282/300, loss_D_A: 0.129, loss_D_B: 0.147, loss_G: 8.273
# Epoch: 282/300, loss_gan: 0.847, loss_cyc: 7.423, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 282/300, loss_D_A: 0.160, loss_D_B: 0.171, loss_G: 8.658
# Epoch: 282/300, loss_gan: 0.881, loss_cyc: 7.775, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6710 seconds
# ---------------train loss---------------
# Epoch: 283/300, loss_D_A: 0.119, loss_D_B: 0.140, loss_G: 8.276
# Epoch: 283/300, loss_gan: 0.875, loss_cyc: 7.399, loss_dep: 0.002
# --------------- test loss---------------
# Epoch: 283/300, loss_D_A: 0.146, loss_D_B: 0.160, loss_G: 8.717
# Epoch: 283/300, loss_gan: 0.959, loss_cyc: 7.755, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6718 seconds
# ---------------train loss---------------
# Epoch: 284/300, loss_D_A: 0.114, loss_D_B: 0.138, loss_G: 8.290
# Epoch: 284/300, loss_gan: 0.892, loss_cyc: 7.395, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 284/300, loss_D_A: 0.153, loss_D_B: 0.163, loss_G: 8.654
# Epoch: 284/300, loss_gan: 0.897, loss_cyc: 7.755, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6715 seconds
# ---------------train loss---------------
# Epoch: 285/300, loss_D_A: 0.124, loss_D_B: 0.140, loss_G: 8.280
# Epoch: 285/300, loss_gan: 0.867, loss_cyc: 7.410, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 285/300, loss_D_A: 0.167, loss_D_B: 0.160, loss_G: 8.664
# Epoch: 285/300, loss_gan: 0.919, loss_cyc: 7.743, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6733 seconds
# ---------------train loss---------------
# Epoch: 286/300, loss_D_A: 0.129, loss_D_B: 0.139, loss_G: 8.267
# Epoch: 286/300, loss_gan: 0.871, loss_cyc: 7.394, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 286/300, loss_D_A: 0.165, loss_D_B: 0.159, loss_G: 8.630
# Epoch: 286/300, loss_gan: 0.886, loss_cyc: 7.742, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6682 seconds
# ---------------train loss---------------
# Epoch: 287/300, loss_D_A: 0.125, loss_D_B: 0.139, loss_G: 8.274
# Epoch: 287/300, loss_gan: 0.870, loss_cyc: 7.401, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 287/300, loss_D_A: 0.165, loss_D_B: 0.167, loss_G: 8.649
# Epoch: 287/300, loss_gan: 0.905, loss_cyc: 7.742, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6688 seconds
# ---------------train loss---------------
# Epoch: 288/300, loss_D_A: 0.129, loss_D_B: 0.144, loss_G: 8.220
# Epoch: 288/300, loss_gan: 0.858, loss_cyc: 7.360, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 288/300, loss_D_A: 0.172, loss_D_B: 0.171, loss_G: 8.624
# Epoch: 288/300, loss_gan: 0.882, loss_cyc: 7.739, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6728 seconds
# ---------------train loss---------------
# Epoch: 289/300, loss_D_A: 0.132, loss_D_B: 0.146, loss_G: 8.228
# Epoch: 289/300, loss_gan: 0.850, loss_cyc: 7.375, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 289/300, loss_D_A: 0.174, loss_D_B: 0.172, loss_G: 8.612
# Epoch: 289/300, loss_gan: 0.878, loss_cyc: 7.732, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6712 seconds
# ---------------train loss---------------
# Epoch: 290/300, loss_D_A: 0.132, loss_D_B: 0.145, loss_G: 8.212
# Epoch: 290/300, loss_gan: 0.848, loss_cyc: 7.361, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 290/300, loss_D_A: 0.174, loss_D_B: 0.169, loss_G: 8.622
# Epoch: 290/300, loss_gan: 0.880, loss_cyc: 7.739, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6726 seconds
# ---------------train loss---------------
# Epoch: 291/300, loss_D_A: 0.130, loss_D_B: 0.142, loss_G: 8.191
# Epoch: 291/300, loss_gan: 0.851, loss_cyc: 7.337, loss_dep: 0.002
# --------------- test loss---------------
# Epoch: 291/300, loss_D_A: 0.170, loss_D_B: 0.165, loss_G: 8.654
# Epoch: 291/300, loss_gan: 0.919, loss_cyc: 7.733, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6700 seconds
# ---------------train loss---------------
# Epoch: 292/300, loss_D_A: 0.127, loss_D_B: 0.138, loss_G: 8.209
# Epoch: 292/300, loss_gan: 0.869, loss_cyc: 7.337, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 292/300, loss_D_A: 0.169, loss_D_B: 0.156, loss_G: 8.657
# Epoch: 292/300, loss_gan: 0.925, loss_cyc: 7.730, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6724 seconds
# ---------------train loss---------------
# Epoch: 293/300, loss_D_A: 0.128, loss_D_B: 0.133, loss_G: 8.208
# Epoch: 293/300, loss_gan: 0.877, loss_cyc: 7.329, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 293/300, loss_D_A: 0.171, loss_D_B: 0.151, loss_G: 8.654
# Epoch: 293/300, loss_gan: 0.921, loss_cyc: 7.730, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6709 seconds
# ---------------train loss---------------
# Epoch: 294/300, loss_D_A: 0.129, loss_D_B: 0.129, loss_G: 8.241
# Epoch: 294/300, loss_gan: 0.881, loss_cyc: 7.358, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 294/300, loss_D_A: 0.175, loss_D_B: 0.150, loss_G: 8.670
# Epoch: 294/300, loss_gan: 0.939, loss_cyc: 7.729, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6740 seconds
# ---------------train loss---------------
# Epoch: 295/300, loss_D_A: 0.132, loss_D_B: 0.130, loss_G: 8.219
# Epoch: 295/300, loss_gan: 0.883, loss_cyc: 7.333, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 295/300, loss_D_A: 0.176, loss_D_B: 0.150, loss_G: 8.635
# Epoch: 295/300, loss_gan: 0.912, loss_cyc: 7.720, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6723 seconds
# ---------------train loss---------------
# Epoch: 296/300, loss_D_A: 0.133, loss_D_B: 0.130, loss_G: 8.199
# Epoch: 296/300, loss_gan: 0.872, loss_cyc: 7.324, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 296/300, loss_D_A: 0.177, loss_D_B: 0.151, loss_G: 8.635
# Epoch: 296/300, loss_gan: 0.913, loss_cyc: 7.720, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6737 seconds
# ---------------train loss---------------
# Epoch: 297/300, loss_D_A: 0.132, loss_D_B: 0.131, loss_G: 8.231
# Epoch: 297/300, loss_gan: 0.872, loss_cyc: 7.356, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 297/300, loss_D_A: 0.177, loss_D_B: 0.153, loss_G: 8.655
# Epoch: 297/300, loss_gan: 0.934, loss_cyc: 7.719, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6738 seconds
# ---------------train loss---------------
# Epoch: 298/300, loss_D_A: 0.133, loss_D_B: 0.132, loss_G: 8.178
# Epoch: 298/300, loss_gan: 0.871, loss_cyc: 7.304, loss_dep: 0.002
# --------------- test loss---------------
# Epoch: 298/300, loss_D_A: 0.176, loss_D_B: 0.154, loss_G: 8.654
# Epoch: 298/300, loss_gan: 0.939, loss_cyc: 7.714, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6706 seconds
# ---------------train loss---------------
# Epoch: 299/300, loss_D_A: 0.132, loss_D_B: 0.132, loss_G: 8.200
# Epoch: 299/300, loss_gan: 0.880, loss_cyc: 7.317, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 299/300, loss_D_A: 0.175, loss_D_B: 0.154, loss_G: 8.647
# Epoch: 299/300, loss_gan: 0.931, loss_cyc: 7.714, loss_dep: 0.002
# ****************************************
# trained epoch in 1.6763 seconds
# ---------------train loss---------------
# Epoch: 300/300, loss_D_A: 0.131, loss_D_B: 0.132, loss_G: 8.208
# Epoch: 300/300, loss_gan: 0.876, loss_cyc: 7.329, loss_dep: 0.003
# --------------- test loss---------------
# Epoch: 300/300, loss_D_A: 0.174, loss_D_B: 0.154, loss_G: 8.648
# Epoch: 300/300, loss_gan: 0.932, loss_cyc: 7.713, loss_dep: 0.002
# ****************************************

# %% [markdown]
# Note: specify `plot=True` in `evaluate` to monitor the visualized generated and reconstructed data. Figures are saved in `saved_model/unsup_daf/figs/`.
#
# Figures are 3x6 grid.
#
# Row 1: observed, row 2: generated, row 3: reconstructed
#
# Column 1-3: ABCD matrices. Column 4-6: HCP matrices.

# %%
plt.plot(range(nepoch),train_G_loss)
plt.plot(range(nepoch),train_DA_loss)
plt.plot(range(nepoch),train_DB_loss)
# plt.ylim(0,3)

# %%
plt.plot(range(nepoch),test_G_loss)
plt.plot(range(nepoch),test_DA_loss)
plt.plot(range(nepoch),test_DB_loss)
plt.ylim(0,3)
# Out:
# (0.0, 3.0)

# %% [markdown]
# # DAF regression

# %% [markdown]
# ## Load traits

# %%
# Load trait data for ABCD
trait_abcd_all = dat_abcd['nih_cogn']

# Load trait data for HCP
phen_dat = loadmat('../hcp/HCP_Covariates.mat')

# Get subject IDs from both datasets
hcp_all_subject_ids = phen_dat['allsubject_id'].squeeze()  # All subjects in covariates file (1206 subjects)
hcp_connectome_subject_ids = dat_hcp['all_id'].squeeze()   # Subjects with connectome data (1065 subjects)

# Create mapping from HCP connectome subjects to their corresponding indices in the covariates file
# This finds the index in the covariates file for each subject in the connectome data
phen_idx = []
for subject_id in hcp_connectome_subject_ids:
    # Find where this subject appears in the full subject list
    idx = np.where(hcp_all_subject_ids == subject_id)[0]
    if len(idx) > 0:
        phen_idx.append(idx[0])
    else:
        # Handle case where subject not found (shouldn't happen based on our checks)
        print(f"Warning: Subject {subject_id} not found in covariates file")
        phen_idx.append(None)

# Extract only the traits for subjects that have connectome data
# This uses the mapping we created to get the right indices
trait_hcp_all = phen_dat['cog_measure'][:, phen_idx]  # shape: (num_traits, num_connectome_subjects)

# Then use the id_hcp indices which select which of the connectome subjects to use
# Note: If sample=False, id_hcp is all subjects, so this doesn't change anything
trait_hcp_all = trait_hcp_all[:, id_hcp]  # shape: (num_traits, num_selected_subjects)
trait_abcd_all = trait_abcd_all[id_abcd]  # shape: (num_selected_subjects, num_traits)

# Transpose the HCP traits to match the shape of ABCD traits (subjects x traits)
trait_hcp_all = trait_hcp_all.reshape(-1, n_hcp).transpose(1, 0)

# Handle missing values and normalize traits
col_means = np.nanmean(trait_abcd_all, axis=0)
inds = np.where(np.isnan(trait_abcd_all))
trait_abcd_all[inds] = np.take(col_means, inds[1])
means_abcd, stds_abcd = np.mean(trait_abcd_all, axis=0), np.std(trait_abcd_all, axis=0)
trait_abcd_all = (trait_abcd_all - means_abcd) / stds_abcd

col_means = np.nanmean(trait_hcp_all, axis=0)
inds = np.where(np.isnan(trait_hcp_all))
trait_hcp_all[inds] = np.take(col_means, inds[1])
means_hcp, stds_hcp = np.mean(trait_hcp_all, axis=0), np.std(trait_hcp_all, axis=0)
trait_hcp_all = (trait_hcp_all - means_hcp) / stds_hcp

# Handle specific trait if needed
trait_hcp_all[:, 137] = 0

trait_abcd_all = torch.from_numpy(trait_abcd_all)
trait_hcp_all = torch.from_numpy(trait_hcp_all)

print("HCP traits shape:", trait_hcp_all.shape)
print("ABCD traits shape:", trait_abcd_all.shape)
# Out:
# HCP traits shape: torch.Size([173, 175])
# ABCD traits shape: torch.Size([892, 30])
# /tmp/ipykernel_1726601/303806022.py:47: RuntimeWarning: invalid value encountered in divide
#   trait_hcp_all = (trait_hcp_all - means_hcp) / stds_hcp

# %% [markdown]
# ## Load trained DAF model and transform data

# %%
if log:
    net_abcd = torch.stack([torch.Tensor(i) for i in net_abcd]).view(-1,1,68,68)
    net_hcp = torch.stack([torch.Tensor(i) for i in net_hcp]).view(-1,1,68,68)
else:
    offset = np.max(net_s)/2 
    net_abcd = torch.stack([torch.Tensor((i-offset)/offset) for i in net_abcd]).view(-1,1,68,68)
    net_hcp = torch.stack([torch.Tensor((i-offset)/offset) for i in net_hcp]).view(-1,1,68,68)

d=48
netG_A2B = Generator(input_nc=1,output_nc=1,
                     init_depth=d,s_depth=10,
                     bc=True,
                     n_residual_blocks=5,domains=2).to(device)
netG_B2A = Generator(input_nc=1,output_nc=1,init_depth=d,s_depth=10,bc=True,n_residual_blocks=5,domains=2).to(device)
netG_A2B.load_state_dict(torch.load("saved_model/unsup_daf/G_A2B.pth"))
netG_B2A.load_state_dict(torch.load("saved_model/unsup_daf/G_B2A.pth"))
# Out:
# <All keys matched successfully>

# %%
with torch.no_grad():
    net1_abcd, z_abcd = netG_A2B(net_abcd.to(device), torch.tensor([0]).expand(n_abcd, 1).to(device))
    netr_abcd, z1_abcd = netG_B2A(net1_abcd.to(device), torch.tensor([0]).expand(n_abcd, 1).to(device))

    net1_hcp, z_hcp = netG_A2B(net_hcp.to(device), torch.tensor([1]).expand(n_hcp, 1).to(device))
    netr_hcp, z1_hcp = netG_B2A(net1_hcp.to(device), torch.tensor([1]).expand(n_hcp, 1).to(device))

    net1_abcd, z_abcd, z1_abcd = net1_abcd.cpu().view(-1, 68*68), z_abcd.cpu(), z1_abcd.cpu()
    net1_hcp, z_hcp, z1_hcp = net1_hcp.cpu().view(-1, 68*68), z_hcp.cpu(), z1_hcp.cpu()

torch.cuda.empty_cache()

# %%
# z1_hcp = torch.cat((z_hcp,z1_hcp),1)

# %% [markdown]
# ## MLP

# %%
# metric: coefficient of determination (R^2)
def coefod(yhat,y):
    return 1-(((y-yhat)**2).sum()/((y-y.mean())**2).sum())

# %%
def evaluate_MLP(model, x, y, epoch, save=False, root=None):
    model.eval()
    with torch.no_grad():
        x = x.to(device)
        yhat = model(x)
        yhat = yhat.detach().cpu().view(-1)

        loss = F.mse_loss(yhat, y, reduction="mean").item()
        corr = np.corrcoef(yhat,y)[0,1].item()
        cod = coefod(yhat, y).item()
    if save:
        if not os.path.exists(root):
            # Create the directory
            os.makedirs(root)
            print(f"Directory '{root}' was created.")
        torch.save(model.state_dict(), root+'e'+str(epoch)+'.pth')
    return loss, corr, cod

# %%
traits = [24] # trait index

# %%
# repetitions: in each repetition, randomly divide HCP dataset into K-shot (training) set and remaining (testing) set
rep = 30
num_traits = len(traits)
cor_reps = torch.zeros([rep, num_traits])
mse_reps = torch.zeros([rep, num_traits])
cod_reps = torch.zeros([rep, num_traits])
set_seed()
for t in range(len(traits)):
    
    trait_id = traits[t]
    trait_hcp = trait_hcp_all[:,trait_id].float()
    trait_abcd = trait_abcd_all.float()
    loss_test_list = torch.zeros(rep)
    corr_test_list = torch.zeros(rep)
    cod_test_list = torch.zeros(rep)
    random.seed(1972014)
    r = 0
    count = 0
    redo = False
    # while r < rep: #and count <= 100:
    for r in range(rep):
        id_kshot = random.sample(range(n_hcp), 50)
        id_remain = [ele for ele in list(range(n_hcp)) if ele not in id_kshot]

        trait_remain = trait_hcp[id_remain]
        n_kshot, n_remain = len(id_kshot), len(id_remain)

        print('%%%%%% Train on K-shot set')

        id_kshot_train, id_kshot_val = train_test_split(id_kshot, test_size=0.1, random_state=42)
        train_dataset = utils.TensorDataset(z1_hcp[id_kshot_train], trait_hcp[id_kshot_train])
        train_loader = utils.DataLoader(train_dataset, batch_size=len(id_kshot_train), shuffle=True)
        # val_dataset = utils.TensorDataset(z1_hcp[id_kshot_val], trait_hcp[id_kshot_val])
        # val_loader = utils.DataLoader(val_dataset, batch_size=len(id_kshot_val), shuffle=False)

        # Networks
        model_hcp = MLP(n_traits=1, input_dim=z1_hcp.shape[1]).to(device)

        # Lossess
        criterion_pred = torch.nn.MSELoss()

        # Optimizers & LR schedulers
        optimizer_C = torch.optim.AdamW(model_hcp.parameters(),lr=0.001, betas=(0.9, 0.999))
        nepoch = 100
        corr_val_list = []
        loss_val_list = []
        cod_val_list = []
        for epoch in range(0, nepoch):

            pred=[]

            for i, (A, y) in enumerate(train_loader):

                A = A.to(device)
                y = y.to(device)
                bs = A.shape[0]

                optimizer_C.zero_grad()
                yhat = model_hcp(A)

                # Prediction loss
                loss_pred = criterion_pred(yhat, y.view(bs,-1))# * alpha[epoch]
                loss_pred.backward()

                optimizer_C.step()

                # collect loss
                pred.append(loss_pred.data.item())
            
            # Update learning rates
            pred_epoch = torch.mean(torch.FloatTensor(pred))
            loss_val, corr_val, cod_val = evaluate_MLP(model_hcp, 
                                                          z1_hcp[id_kshot_val], 
                                                          trait_hcp[id_kshot_val], 
                                                          epoch, 
                                                          save=True, 
                                                          root='saved_model/mlp/')
            corr_val_list.append(corr_val)
            loss_val_list.append(loss_val)
            cod_val_list.append(cod_val)
            if epoch % 20==0:
                print('[%d/%d]: loss_train: %.5f, loss_val: %.5f' % ((epoch), nepoch, pred_epoch, loss_val))


        opt_epoch = np.argmin(loss_val_list)
        model_hcp.load_state_dict(torch.load(f'saved_model/mlp/e{opt_epoch}.pth'))
        print('%%%%%% Evaluate on remaining set')
        loss, corr, cod = evaluate_MLP(model_hcp, 
                                       z1_hcp[id_remain], 
                                       trait_hcp[id_remain], 
                                       0, 
                                       save=False)

        loss_test_list[r] = loss 
        corr_test_list[r] = corr
        cod_test_list[r] = cod
        print('loss: %.4f, corr: %.4f' % (loss_test_list[r], corr_test_list[r]))

    cor_reps[:,t] = corr_test_list
    mse_reps[:,t] = loss_test_list
    cod_reps[:,t] = cod_test_list
# Out:
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 1.38540, loss_val: 37.45156
# [20/100]: loss_train: 0.97879, loss_val: 2.42242
# [40/100]: loss_train: 0.72803, loss_val: 2.17823
# [60/100]: loss_train: 0.49663, loss_val: 2.10816
# [80/100]: loss_train: 0.17848, loss_val: 1.96626
# %%%%%% Evaluate on remaining set
# loss: 1.6363, corr: 0.1419
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 0.98555, loss_val: 46.93375
# [20/100]: loss_train: 0.81669, loss_val: 0.94197
# [40/100]: loss_train: 0.62389, loss_val: 0.76805
# [60/100]: loss_train: 0.54799, loss_val: 0.58004
# [80/100]: loss_train: 0.21109, loss_val: 0.50317
# %%%%%% Evaluate on remaining set
# loss: 1.2934, corr: 0.2346
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 1.37106, loss_val: 30.50185
# [20/100]: loss_train: 1.16005, loss_val: 0.24573
# [40/100]: loss_train: 0.78718, loss_val: 0.31741
# [60/100]: loss_train: 0.33233, loss_val: 0.36624
# [80/100]: loss_train: 0.11866, loss_val: 0.24082
# %%%%%% Evaluate on remaining set
# loss: 0.9053, corr: 0.3009
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 1.10796, loss_val: 38.59327
# [20/100]: loss_train: 1.14825, loss_val: 0.23622
# [40/100]: loss_train: 0.85539, loss_val: 0.21935
# [60/100]: loss_train: 0.38262, loss_val: 0.20968
# [80/100]: loss_train: 0.17040, loss_val: 0.05114
# %%%%%% Evaluate on remaining set
# loss: 1.3403, corr: 0.2151
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 1.40103, loss_val: 69.48614
# [20/100]: loss_train: 1.13430, loss_val: 1.19507
# [40/100]: loss_train: 0.92683, loss_val: 1.01930
# [60/100]: loss_train: 0.53170, loss_val: 1.26249
# [80/100]: loss_train: 0.28482, loss_val: 1.25206
# %%%%%% Evaluate on remaining set
# loss: 1.2205, corr: 0.1223
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 1.31576, loss_val: 14.58880
# [20/100]: loss_train: 1.24072, loss_val: 1.40434
# [40/100]: loss_train: 0.79652, loss_val: 1.48457
# [60/100]: loss_train: 0.51852, loss_val: 2.92141
# [80/100]: loss_train: 0.13523, loss_val: 2.85045
# %%%%%% Evaluate on remaining set
# loss: 1.1194, corr: 0.2748
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 1.27433, loss_val: 22.18066
# [20/100]: loss_train: 1.20664, loss_val: 0.33070
# [40/100]: loss_train: 0.70393, loss_val: 0.21214
# [60/100]: loss_train: 0.29558, loss_val: 0.43885
# [80/100]: loss_train: 0.12264, loss_val: 0.77680
# %%%%%% Evaluate on remaining set
# loss: 0.9059, corr: 0.2255
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 1.09602, loss_val: 44.45408
# [20/100]: loss_train: 0.99312, loss_val: 2.50528
# [40/100]: loss_train: 0.50398, loss_val: 1.18105
# [60/100]: loss_train: 0.28878, loss_val: 1.98920
# [80/100]: loss_train: 0.13277, loss_val: 1.85383
# %%%%%% Evaluate on remaining set
# loss: 1.2255, corr: 0.0284
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 0.53346, loss_val: 9.32805
# [20/100]: loss_train: 0.52858, loss_val: 0.93462
# [40/100]: loss_train: 0.47161, loss_val: 0.78434
# [60/100]: loss_train: 0.32792, loss_val: 0.70006
# [80/100]: loss_train: 0.15927, loss_val: 0.82966
# %%%%%% Evaluate on remaining set
# loss: 1.1927, corr: 0.1588
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 1.13321, loss_val: 6.97467
# [20/100]: loss_train: 0.97729, loss_val: 0.86765
# [40/100]: loss_train: 0.60321, loss_val: 0.71762
# [60/100]: loss_train: 0.16370, loss_val: 1.02654
# [80/100]: loss_train: 0.05091, loss_val: 2.40299
# %%%%%% Evaluate on remaining set
# loss: 1.0603, corr: 0.1942
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 1.16339, loss_val: 41.91839
# [20/100]: loss_train: 1.08401, loss_val: 1.20453
# [40/100]: loss_train: 0.90141, loss_val: 1.12629
# [60/100]: loss_train: 0.50840, loss_val: 1.17256
# [80/100]: loss_train: 0.36269, loss_val: 1.43938
# %%%%%% Evaluate on remaining set
# loss: 1.3838, corr: 0.1680
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 1.43556, loss_val: 25.88069
# [20/100]: loss_train: 1.43450, loss_val: 1.12121
# [40/100]: loss_train: 1.04500, loss_val: 1.20484
# [60/100]: loss_train: 0.50236, loss_val: 1.43661
# [80/100]: loss_train: 0.32498, loss_val: 1.20127
# %%%%%% Evaluate on remaining set
# loss: 1.3624, corr: 0.1778
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 1.02625, loss_val: 18.97377
# [20/100]: loss_train: 1.09957, loss_val: 0.12738
# [40/100]: loss_train: 0.91259, loss_val: 0.47766
# [60/100]: loss_train: 0.59272, loss_val: 0.58742
# [80/100]: loss_train: 0.62301, loss_val: 0.35474
# %%%%%% Evaluate on remaining set
# loss: 1.4681, corr: 0.2922
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 1.06418, loss_val: 47.63353
# [20/100]: loss_train: 1.13575, loss_val: 0.29886
# [40/100]: loss_train: 0.80993, loss_val: 0.21292
# [60/100]: loss_train: 0.87218, loss_val: 1.02940
# [80/100]: loss_train: 0.23537, loss_val: 0.42997
# %%%%%% Evaluate on remaining set
# loss: 1.2244, corr: 0.2212
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 1.09554, loss_val: 32.07055
# [20/100]: loss_train: 0.87577, loss_val: 0.68244
# [40/100]: loss_train: 0.56862, loss_val: 0.62402
# [60/100]: loss_train: 0.44431, loss_val: 0.59904
# [80/100]: loss_train: 0.19421, loss_val: 0.43882
# %%%%%% Evaluate on remaining set
# loss: 1.1317, corr: 0.2188
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 1.06888, loss_val: 12.57739
# [20/100]: loss_train: 1.20875, loss_val: 1.77103
# [40/100]: loss_train: 0.98219, loss_val: 1.74024
# [60/100]: loss_train: 0.55010, loss_val: 1.26782
# [80/100]: loss_train: 0.20531, loss_val: 1.83877
# %%%%%% Evaluate on remaining set
# loss: 0.8698, corr: 0.3259
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 0.82274, loss_val: 0.97479
# [20/100]: loss_train: 0.92482, loss_val: 0.92489
# [40/100]: loss_train: 0.75030, loss_val: 0.53786
# [60/100]: loss_train: 0.49509, loss_val: 0.30328
# [80/100]: loss_train: 0.23963, loss_val: 0.41218
# %%%%%% Evaluate on remaining set
# loss: 1.1014, corr: 0.2501
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 1.17771, loss_val: 52.96547
# [20/100]: loss_train: 0.96444, loss_val: 1.57415
# [40/100]: loss_train: 0.70462, loss_val: 1.09846
# [60/100]: loss_train: 0.27554, loss_val: 0.88523
# [80/100]: loss_train: 0.06735, loss_val: 1.59178
# %%%%%% Evaluate on remaining set
# loss: 1.0381, corr: 0.2604
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 0.80072, loss_val: 1.16537
# [20/100]: loss_train: 0.88641, loss_val: 0.95185
# [40/100]: loss_train: 0.62875, loss_val: 0.96570
# [60/100]: loss_train: 0.35323, loss_val: 1.27335
# [80/100]: loss_train: 0.15504, loss_val: 1.40130
# %%%%%% Evaluate on remaining set
# loss: 1.0992, corr: 0.1195
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 1.20910, loss_val: 26.62313
# [20/100]: loss_train: 1.03567, loss_val: 0.90016
# [40/100]: loss_train: 0.47597, loss_val: 2.17998
# [60/100]: loss_train: 0.19450, loss_val: 2.38527
# [80/100]: loss_train: 0.18997, loss_val: 3.01811
# %%%%%% Evaluate on remaining set
# loss: 1.2348, corr: 0.1806
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 0.97932, loss_val: 3.62935
# [20/100]: loss_train: 1.02110, loss_val: 0.39037
# [40/100]: loss_train: 0.84886, loss_val: 0.42417
# [60/100]: loss_train: 0.48366, loss_val: 0.63466
# [80/100]: loss_train: 0.28383, loss_val: 0.58137
# %%%%%% Evaluate on remaining set
# loss: 0.9868, corr: 0.3042
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 1.29898, loss_val: 46.87605
# [20/100]: loss_train: 1.18424, loss_val: 0.25586
# [40/100]: loss_train: 0.95883, loss_val: 0.33701
# [60/100]: loss_train: 0.95489, loss_val: 1.42327
# [80/100]: loss_train: 0.18767, loss_val: 0.60544
# %%%%%% Evaluate on remaining set
# loss: 1.1654, corr: 0.2461
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 0.93171, loss_val: 53.83260
# [20/100]: loss_train: 0.89817, loss_val: 0.41048
# [40/100]: loss_train: 0.71860, loss_val: 0.38957
# [60/100]: loss_train: 0.55196, loss_val: 0.41200
# [80/100]: loss_train: 0.69507, loss_val: 0.69131
# %%%%%% Evaluate on remaining set
# loss: 1.2881, corr: 0.1559
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 0.76094, loss_val: 12.74595
# [20/100]: loss_train: 0.77172, loss_val: 1.10575
# [40/100]: loss_train: 0.56082, loss_val: 1.00951
# [60/100]: loss_train: 0.24558, loss_val: 1.34442
# [80/100]: loss_train: 0.08996, loss_val: 1.16659
# %%%%%% Evaluate on remaining set
# loss: 1.2955, corr: 0.0768
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 1.12503, loss_val: 33.62244
# [20/100]: loss_train: 1.05666, loss_val: 0.74982
# [40/100]: loss_train: 0.93656, loss_val: 0.76644
# [60/100]: loss_train: 0.62822, loss_val: 0.74938
# [80/100]: loss_train: 0.24521, loss_val: 1.45335
# %%%%%% Evaluate on remaining set
# loss: 1.2429, corr: 0.1554
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 0.92902, loss_val: 37.77166
# [20/100]: loss_train: 0.79610, loss_val: 0.24314
# [40/100]: loss_train: 0.65411, loss_val: 0.61631
# [60/100]: loss_train: 0.46717, loss_val: 1.15224
# [80/100]: loss_train: 0.11402, loss_val: 0.32423
# %%%%%% Evaluate on remaining set
# loss: 1.6887, corr: 0.1525
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 1.04381, loss_val: 4.43824
# [20/100]: loss_train: 0.97464, loss_val: 1.00722
# [40/100]: loss_train: 0.82746, loss_val: 0.87539
# [60/100]: loss_train: 0.39649, loss_val: 0.95506
# [80/100]: loss_train: 0.09005, loss_val: 1.07704
# %%%%%% Evaluate on remaining set
# loss: 1.1015, corr: 0.2851
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 1.20607, loss_val: 1.17202
# [20/100]: loss_train: 1.11712, loss_val: 0.76590
# [40/100]: loss_train: 0.86594, loss_val: 1.01915
# [60/100]: loss_train: 0.39882, loss_val: 3.18416
# [80/100]: loss_train: 0.23185, loss_val: 1.76202
# %%%%%% Evaluate on remaining set
# loss: 1.2382, corr: 0.1425
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 1.06598, loss_val: 3.29681
# [20/100]: loss_train: 1.14368, loss_val: 1.21246
# [40/100]: loss_train: 1.00183, loss_val: 1.03849
# [60/100]: loss_train: 0.59775, loss_val: 1.14665
# [80/100]: loss_train: 0.16125, loss_val: 0.99363
# %%%%%% Evaluate on remaining set
# loss: 0.8969, corr: 0.3594
# %%%%%% Train on K-shot set
# [0/100]: loss_train: 0.85401, loss_val: 42.10894
# [20/100]: loss_train: 0.74495, loss_val: 1.29011
# [40/100]: loss_train: 0.62840, loss_val: 1.40299
# [60/100]: loss_train: 0.56888, loss_val: 1.41525
# [80/100]: loss_train: 0.11224, loss_val: 1.58880
# %%%%%% Evaluate on remaining set
# loss: 1.0871, corr: 0.2326

# %%
cor_reps.mean(0)
# Out:
# tensor([0.2154])

# %%
cor_reps.mean(0)
# Out:
# tensor([0.2234])

# %%
cor_reps.mean(0)
# Out:
# tensor([0.2074])
